# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import collections

# %% [markdown]
# # Analysing the data of Resident Advisor

# %%
Data = pd.read_csv("ClubData/EventsWithGenre.csv",encoding="UTF-8")
Data.head(4)
# Out:
#    Unnamed: 0    ClubID     ClubName                             Address  \
# 0           0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 1           1  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 2           2  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 3           3  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
#
#     EventID                                          EventName  \
# 0  707619.0  Light My Fridays: with Ariane Effect, DJ H-ERA...
# 1  673119.0                    Chris Ahn's 4AM Mixtape - Ep. 4
# 2  672938.0                Chris Ahn's 4AM Mixtape - Episode 1
# 3  707619.0  Light My Fridays: with Ariane Effect, DJ H-ERA...
#
#                  Date                                     LineUp   Genre  \
# 0      10 April 2015   ['DJ HERA', 'Ariane Effect', 'Chris Ahn']  techno
# 1   14 November 2014                               ['Chris Ahn']  techno
# 2        16 May 2014                               ['Chris Ahn']  techno
# 3      10 April 2015   ['DJ HERA', 'Ariane Effect', 'Chris Ahn']  techno
#
#                      All Genres
# 0  ['None', 'techno', 'techno']
# 1                    ['techno']
# 2                    ['techno']
# 3  ['None', 'techno', 'techno']

# %% [markdown]
# ## Analysis of genres

# %%
EventsGenre = Data["Genre"].values
gbars = collections.Counter(EventsGenre)
gbars
# Out:
# Counter({'drone': 6,
#          nan: 50,
#          'horror punk': 2,
#          'new tribe': 2,
#          'deep progressive trance': 2,
#          'schranz': 2,
#          'funk': 2,
#          'channel pop': 2,
#          'manele': 2,
#          'k-pop': 10,
#          'deep new americana': 2,
#          'ambeat': 2,
#          'mashup': 6,
#          'vapor soul': 6,
#          'electro music': 10,
#          'swedish punk': 2,
#          'scorecore': 2,
#          'bass music': 8,
#          'ethiopian pop': 2,
#          'house music': 698,
#          'argentine reggae': 2,
#          'soul': 4,
#          'danish pop': 2,
#          'quebecois': 4,
#          'downtempo': 58,
#          'country': 14,
#          'outsider': 2,
#          'flamenco': 8,
#          'turkish pop': 8,
#          'hardstyle': 6,
#          'japanese city pop': 2,
#          'r&b': 2,
#          'classical piano': 2,
#          'spanish pop': 4,
#          'new': 2,
#          'canterbury scene': 2,
#          'indie r&b': 2,
#          'drum and bass': 12,
#          'electronic rock': 42,
#          'trance music': 4,
#          'deep': 12,
#          'dubsteppe': 2,
#          'blues': 2,
#          'groove metal': 2,
#          'indie dream pop': 2,
#          'techno': 1505,
#          'hardcore': 2,
#          'swedish': 2,
#          'consort': 4,
#          'groove room': 2,
#          'redneck': 2,
#          'dark electro-industrial': 2,
#          'intelligent dance music': 2,
#          'cubaton': 2,
#          'None': 6383,
#          'funky breaks': 2,
#          'jazz': 2,
#          'classic polish pop': 12,
#          'rock': 32,
#          'psychobilly': 2,
#          'nu gaze': 2,
#          'classic colombian pop': 2,
#          'screamo': 2,
#          'disco': 248,
#          "children's music": 2,
#          'noise pop': 2,
#          'alternative metal': 6,
#          'classical': 10,
#          'madchester': 2,
#          'oi': 2,
#          'experimental': 2,
#          'makossa': 8,
#          'swedish folk pop': 2,
#          'ska': 4,
#          'progressive psytrance': 4,
#          'breakbeat': 10,
#          'post-disco': 2,
#          'indie': 10,
#          'substep': 2,
#          'classical guitar': 2,
#          'modern performance': 2,
#          'deep australian indie': 2,
#          'dutch pop': 2,
#          'chamber pop': 2,
#          'oshare kei': 2,
#          'new age': 2,
#          'indiecoustica': 2,
#          'modern': 2,
#          'christmas': 2,
#          'dub': 12,
#          'opm': 4,
#          'uk garage': 12,
#          'pop': 8,
#          'industrial music': 6,
#          'german show tunes': 2,
#          'escape room': 2,
#          'emo': 2,
#          'smooth jazz': 2,
#          'neo-psychedelic': 2,
#          'abstractro': 2,
#          'europop': 2,
#          'soukous': 2,
#          'fluxwork': 2,
#          'coverchill': 8,
#          'string quartet': 2,
#          'trap': 32,
#          'rap': 440,
#          'ninja': 2,
#          'dancehall': 4,
#          'banda': 10,
#          'cumbia': 2,
#          'idm': 20,
#          'persian pop': 2,
#          'ambient': 12,
#          'polynesian pop': 2,
#          'deep rai': 2,
#          'balearic': 2,
#          'retro electro': 2,
#          'reggaeton': 2,
#          'hip hop': 129,
#          'mandible': 10,
#          'jazz christmas': 2,
#          'comic': 2,
#          'electro': 2,
#          'arab pop': 2})
