# %% [markdown]
# # Plotting the Map of the clubs

# %%
import pandas as pd
import numpy as np
import folium
import matplotlib.pyplot as plt

# %%
ClubDataFrame = pd.read_csv("ClubDataGeo/ClubDataFrame.csv", encoding='utf-8')

#Drop Useless columns
ClubDataFrame = ClubDataFrame.drop('Unnamed: 0', 1)
ClubDataFrame = ClubDataFrame.drop_duplicates()
GeoPoints = ClubDataFrame[["ClubID","ClubName","Location","Date"]]

parseDate = (lambda x : x.split("-")[0])
GeoPoints["Year"] = GeoPoints["Date"].apply(parseDate)
GeoPoints = GeoPoints.drop_duplicates()
GeoPoints.head(5)
GeoPoints.Year.min()
# Out:
# C:\Users\Simon\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# '1993'

# %% [markdown]
# ## BaseMap

# %%
# Get a basic world map.
clubs_map = folium.Map(location=[46.7, 8], zoom_start=8)
#Add layer
t = folium.TileLayer('cartodbdark_matter')
clubs_map.add_child(t)

def GetFeatureGroup(year):
    
    feature_group = FeatureGroup(name=str(year),overlay=False)
    
    #Select clubs by year
    ClubThisYear = GeoPoints[GeoPoints.Year==str(year)]
    ClubThisYear = ClubThisYear[["ClubName","Location"]]
    ClubThisYear = ClubThisYear.drop_duplicates()
    
    for id,row in ClubThisYear.iterrows():
        loc = row["Location"].replace("(","").replace(")","").split(",")
        name = row["ClubName"]
        if(loc[0]!='None'):
            lat = float(loc[0])
            lng = float(loc[1])
            c = folium.CircleMarker(location=[lat, lng], radius = 30, popup=name,color="red")
            feature_group.add_children(c)
    
    t = folium.TileLayer('cartodbdark_matter')
    feature_group.add_child(t)
    return feature_group

# %%
foliumDir = "Folium/"
clubs_map = folium.Map(location=[46.7, 8], zoom_start=8,tiles=None)
basemap = folium.FeatureGroup(name="Base Map",control=False)
basemap.add_children(folium.TileLayer('cartodbdark_matter'))
clubs_map.add_children(basemap)

f1 =folium.FeatureGroup(name="Base Map",control=True)

for i in range(1993,2017):
    print(i)
    group = GetFeatureGroup(i)
    clubs_map.add_children(group)

LC = folium.map.LayerControl()

clubs_map.add_children(LC)
clubs_map
# Out:
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
path="index.html"
clubs_map.save(path)

# %%
from IPython.core.display import HTML,display
import os
dir = str(os.getcwd())
for i in range (1990,2017):
    filename=dir+'/Folium/Map'+str(i)+'.html'
    webbrowser.open_new_tab(filename)

# %%
s = Slider
clubs_map.add_child(sl)

# %%
d = folium.element.Div()
features = folium.FeatureGroup(name=str(1992))
ls = ["HELLO","HEHEH"]
features.add_child(foliumls)
d.add_children(features)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-189de8eb0fbe> in <module>()
#       2 features = folium.FeatureGroup(name=str(1992))
#       3 ls = ["HELLO","HEHEH"]
# ----> 4 features.add_child(ls)
#       5 d.add_children(features)
#
# C:\Users\Simon\Anaconda3\lib\site-packages\folium\element.py in add_child(self, child, name, index)
#      90         """Add a child."""
#      91         if name is None:
# ---> 92             name = child.get_name()
#      93         if index is None:
#      94             self._children[name] = child
#
# AttributeError: 'list' object has no attribute 'get_name'

# %%
import folium
from folium.map import *
map = folium.Map()
feature_group = FeatureGroup(name='My feature group')
feature_group.add_children(Marker([45,-30],popup=Popup('-30')))
feature_group.add_children(Marker([45, 30],popup=Popup('30')))
map.add_children(feature_group)
map.add_children(folium.map.LayerControl())
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
