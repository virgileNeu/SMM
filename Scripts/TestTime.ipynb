# %%
import numpy as np
import pandas as pd
import folium
import os
import matplotlib

# %%
Map = folium.Map()

# %%
from folium import plugins


m = folium.Map([45, 3], zoom_start=4)

control = folium.LayerControl()
m.add_children(control)
m.add_children(plugins.TimestampedGeoJson(None))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
map = folium.map.LegacyMap(location=[45.523, -122.675], width=750, height=500)

map = folium.map.LegacyMap(location=[45.523, -122.675],
                           tiles='Mapbox Control Room')
'''
map = folium.LegacyMap(location=(45.523, -122.675), max_zoom=20,
                           tiles='Cloudmade', API_key='YourKey')
map = folium.LegacyMap(location=[45.523, -122.675], zoom_start=2,
                           tiles=('http://{s}.tiles.mapbox.com/v3/'
                                  'mapbox.control-room/{z}/{x}/{y}.png'),
                            attr='Mapbox attribution')
                            '''
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
a = open("TODO_Error_genre.txt")
a.write("ahah",m)
# Out:
# <_io.TextIOWrapper name='TODO_Error_genre.txt' mode='r' encoding='cp1252'>
