# %%
import numpy as np
import ArtistExtractor as AE
import pandas as pd
import glob
import os
import LocationUtils as LU
from ExtractGenreClubs import SplitLineup
from ast import literal_eval

# %%
import ArtistExtractor as AE

begin = 0
end = 45378
path = "FullData/ArtistDataframe.csv"
df = pd.read_csv(path)
df

i=0
AllGenresDownloaded = []
print("Populating dictionnary with other genres:")
print("Reading all genres from dataframe : "+path)
for id,row in df.iterrows():
    listGenres = literal_eval(row[2])
    if(listGenres!=None):
        AllGenresDownloaded+=listGenres
print("All genre extracted from dataframe. Updating dictionnary..")
dic = AE.createDictionnary()
dic = AE.updateDictionnary(AllGenresDownloaded,dic,debug=True)
LU.saveDictionary(dic,"FullData/AllGenresDic",enc="utf-8")
print("Dictionnary of genre saved.")
# Out:
# Populating dictionnary with other genres:
# Reading all genres from dataframe : FullData/ArtistDataframe.csv
# All genre extracted from dataframe. Updating dictionnary..
# added : dic{german metal : rock}
# added : dic{neue deutsche harte : rock}
# added : dic{deep german hip hop : hip hop}
# added : dic{german hip hop : hip hop}
# added : dic{classical piano : orchestral}
# missing genre : concert piano
# missing genre : comic
# added : dic{german pop : pop}
# added : dic{german pop rock : rock}
# added : dic{atmospheric black metal : rock}
# added : dic{avantgarde metal : rock}
# added : dic{jazz metal : rock}
# added : dic{metal : rock}
# added : dic{norwegian metal : rock}
# added : dic{pagan black metal : rock}
# added : dic{dark black metal : rock}
# missing genre : voidgaze
# added : dic{contemporary jazz : jazz}
# added : dic{contemporary post-bop : jazz}
# added : dic{jazz funk : r&b and soul}
# added : dic{electroacoustic improvisation : jazz}
# added : dic{hungarian pop : pop}
# added : dic{hungarian rock : rock}
# added : dic{celtic : folk}
# added : dic{celtic christmas : folk}
# added : dic{celtic rock : rock}
# added : dic{pipe band : jazz}
# added : dic{deep german jazz : jazz}
# added : dic{deep jazz piano : jazz}
# added : dic{jazz bass : electronic}
# added : dic{oi : electronic}
# added : dic{traditional scottish folk : folk}
# added : dic{dancehall : caribbean and caribbean-influenced}
# added : dic{french reggae : hip hop}
# added : dic{reggae : hip hop}
# added : dic{reggae fusion : jazz}
# added : dic{roots reggae : hip hop}
# added : dic{classical christmas : orchestral}
# added : dic{deep orchestral : orchestral}
# added : dic{neo mellow : jazz}
# missing genre : pixie
# added : dic{pop emo : rock}
# added : dic{post-teen pop : pop}
# added : dic{viral pop : pop}
# missing genre : pixie
# added : dic{post-screamo : rock}
# added : dic{alternative emo : rock}
# added : dic{anthem emo : rock}
# added : dic{melodic hardcore : electronic}
# missing genre : pixie
# added : dic{punk christmas : rock}
# missing genre : pixie
# added : dic{post-post-hardcore : electronic}
# added : dic{alternative pop rock : rock}
# missing genre : pixie
# added : dic{classical performance : orchestral}
# missing genre : polka
# added : dic{dance rock : rock}
# added : dic{new romantic : pop}
# added : dic{new wave pop : pop}
# added : dic{permanent wave : electronic}
# missing genre : pixie
# added : dic{spanish punk : rock}
# added : dic{power blues-rock : rock}
# added : dic{indie anthem-folk : folk}
# added : dic{dirty south rap : hip hop}
# added : dic{chamber pop : pop}
# added : dic{folk-pop : pop}
# added : dic{stomp and holler : jazz}
# added : dic{deep german pop rock : rock}
# added : dic{traditional ska : rock}
# added : dic{desert blues : blues}
# added : dic{mande pop : pop}
# added : dic{world : rock}
# missing genre : choral
# added : dic{opera : hip hop}
# added : dic{deep indie r&b : r&b and soul}
# added : dic{indie r&b : r&b and soul}
# added : dic{german punk : rock}
# missing genre : kabarett
# missing genre : liedermacher
# added : dic{garage psych : folk}
# added : dic{neo-psychedelic : folk}
# added : dic{noise pop : pop}
# added : dic{nu gaze : rock}
# added : dic{psych gaze : rock}
# added : dic{garage pop : pop}
# added : dic{indie punk : rock}
# added : dic{australian alternative rock : rock}
# added : dic{australian pop : pop}
# added : dic{icelandic pop : pop}
# added : dic{metropopolis : pop}
# added : dic{canadian pop : pop}
# added : dic{dance pop : pop}
# added : dic{edm : blues}
# added : dic{house : electronic}
# added : dic{jazz brass : jazz}
# added : dic{jazz christmas : jazz}
# added : dic{modern blues : blues}
# added : dic{arab folk : folk}
# added : dic{compositional ambient : electronic}
# added : dic{dark jazz : jazz}
# added : dic{fourth world : rock}
# added : dic{indie jazz : jazz}
# missing genre : ninja
# missing genre : violin
# added : dic{norwegian indie : rock}
# added : dic{norwegian jazz : jazz}
# missing genre : dreamo
# added : dic{heavy christmas : rock}
# added : dic{medieval rock : rock}
# added : dic{piano blues : blues}
# added : dic{escape room : electronic}
# added : dic{gangster rap : hip hop}
# added : dic{trap music : avant-garde}
# added : dic{album rock : rock}
# added : dic{mellow gold : hip hop}
# missing genre : mallet
# added : dic{italian punk : rock}
# missing genre : violin
# added : dic{dutch pop : pop}
# missing genre : choral
# added : dic{minimal : electronic}
# missing genre : violin
# added : dic{cabaret : rock}
# missing genre : choral
# missing genre : harpsichord
# missing genre : violin
# missing genre : concert piano
# added : dic{urban contemporary : pop}
# added : dic{discofox : r&b and soul}
# added : dic{swiss hip hop : hip hop}
# missing genre : volksmusik
# missing genre : balkan brass
# added : dic{polish jazz : jazz}
# added : dic{experimental : avant-garde}
# added : dic{italian arena pop : pop}
# added : dic{italian pop : pop}
# added : dic{new americana : country}
# added : dic{old-time : jazz}
# added : dic{danish pop : pop}
# added : dic{microhouse : electronic}
# added : dic{etherpop : pop}
# added : dic{shimmer pop : pop}
# missing genre : comic
# added : dic{medieval : rock}
# added : dic{slavic metal : rock}
# added : dic{swedish metal : rock}
# added : dic{canadian metal : rock}
# missing genre : choral
# added : dic{modern classical : orchestral}
# missing genre : string quartet
# missing genre : violin
# added : dic{death core : hip hop}
# added : dic{deep jazz guitar : jazz}
# missing genre : cantautor
# added : dic{rock en espanol : country}
# added : dic{spanish pop : pop}
# added : dic{spanish pop rock : rock}
# added : dic{spanish rock : rock}
# added : dic{italian jazz : jazz}
# added : dic{deep new americana : country}
# added : dic{roots rock : rock}
# added : dic{chamber psych : folk}
# added : dic{northern irish indie : rock}
# added : dic{popgaze : pop}
# missing genre : preverb
# added : dic{pop house : electronic}
# missing genre : choral
# missing genre : harpsichord
# missing genre : broadway
# missing genre : hollywood
# added : dic{show tunes : country}
# added : dic{bow pop : pop}
# missing genre : laboratorio
# missing genre : clarinet
# added : dic{classical flute : orchestral}
# added : dic{deep australian indie : rock}
# missing genre : pixie
# missing genre : pixie
# added : dic{turkish hip hop : hip hop}
# added : dic{indie poptimism : pop}
# added : dic{la indie : rock}
# missing genre : tzadik
# added : dic{classical organ : orchestral}
# added : dic{sleaze rock : rock}
# missing genre : hollywood
# added : dic{norwegian pop : pop}
# added : dic{norwegian rock : rock}
# added : dic{blues-rock : rock}
# missing genre : clarinet
# added : dic{german indie : rock}
# added : dic{indie garage rock : rock}
# missing genre : preverb
# added : dic{alt-indie rock : rock}
# missing genre : preverb
# added : dic{underground pop rap : hip hop}
# added : dic{british alternative rock : rock}
# added : dic{new weird america : folk}
# missing genre : preverb
# missing genre : mashup
# added : dic{canadian indie : rock}
# added : dic{singer-songwriter : folk}
# added : dic{belgian rock : rock}
# added : dic{french indietronica : electronic}
# missing genre : violin
# added : dic{stride : jazz}
# added : dic{deep pop r&b : r&b and soul}
# added : dic{r&b : r&b and soul}
# added : dic{slow game : electronic}
# added : dic{electro jazz : jazz}
# added : dic{acoustic blues : blues}
# added : dic{british invasion : folk}
# added : dic{classic rock : rock}
# added : dic{harmonica blues : blues}
# added : dic{traditional blues : blues}
# added : dic{swedish alternative rock : rock}
# added : dic{swedish hip hop : hip hop}
# added : dic{swedish idol pop : pop}
# added : dic{swedish indie rock : rock}
# added : dic{swedish pop : pop}
# added : dic{swedish reggae : hip hop}
# added : dic{adult standards : pop}
# added : dic{bay area indie : rock}
# added : dic{bass music : avant-garde}
# added : dic{float house : electronic}
# missing genre : fluxwork
# added : dic{intelligent dance music : avant-garde}
# missing genre : mandible
# added : dic{deep opera : hip hop}
# missing genre : talent show
# added : dic{kiwi rock : rock}
# missing genre : preverb
# added : dic{punk : rock}
# added : dic{straight edge : jazz}
# added : dic{christian hardcore : electronic}
# missing genre : beatdown
# added : dic{chaotic hardcore : electronic}
# added : dic{uk post-punk : rock}
# added : dic{new orleans blues : blues}
# added : dic{black thrash : rock}
# added : dic{stoner metal : rock}
# added : dic{psychedelic doom : electronic}
# added : dic{retro metal : rock}
# added : dic{jazz composition : jazz}
# added : dic{italian indie pop : pop}
# added : dic{brazilian composition : latin}
# missing genre : forro
# missing genre : mpb
# added : dic{deep gothic post-punk : rock}
# added : dic{belgian indie : rock}
# missing genre : zeuhl
# missing genre : violin
# added : dic{neo classical metal : rock}
# added : dic{neo-progressive : electronic}
# added : dic{ska : rock}
# added : dic{blues-rock guitar : rock}
# added : dic{chicago soul : r&b and soul}
# added : dic{memphis soul : r&b and soul}
# missing genre : motown
# added : dic{destroy techno : electronic}
# added : dic{vapor house : electronic}
# missing genre : nwobhm
# added : dic{traditional country : country}
# added : dic{cyber metal : rock}
# added : dic{gothic symphonic metal : rock}
# missing genre : lilith
# missing genre : kabarett
# missing genre : liedermacher
# added : dic{dutch rock : rock}
# added : dic{thrash-groove metal : rock}
# missing genre : hauntology
# added : dic{progressive post-hardcore : electronic}
# added : dic{west coast rap : hip hop}
# missing genre : clarinet
# added : dic{black sludge : rock}
# added : dic{drone : rock}
# added : dic{post-doom metal : rock}
# missing genre : concert piano
# missing genre : harpsichord
# missing genre : concert piano
# added : dic{romantic : pop}
# missing genre : violin
# missing genre : choral
# missing genre : harpsichord
# missing genre : modern performance
# missing genre : violin
# added : dic{folk christmas : folk}
# added : dic{indie christmas : rock}
# missing genre : lilith
# added : dic{classic funk rock : rock}
# added : dic{p funk : r&b and soul}
# missing genre : wrestling
# added : dic{funk rock : rock}
# added : dic{industrial : hip hop}
# missing genre : madchester
# added : dic{boston rock : rock}
# missing genre : preverb
# added : dic{pop christmas : pop}
# added : dic{soul christmas : r&b and soul}
# added : dic{irish indie : rock}
# added : dic{australian indie : rock}
# added : dic{baroque ensemble : pop}
# added : dic{albanian pop : pop}
# missing genre : volksmusik
# missing genre : zillertal
# added : dic{gothic americana : country}
# added : dic{disco house : electronic}
# added : dic{math pop : pop}
# missing genre : choral
# missing genre : protopunk
# added : dic{acoustic pop : pop}
# added : dic{deep classical piano : orchestral}
# added : dic{israeli rock : rock}
# added : dic{french indie pop : pop}
# added : dic{native american : folk}
# added : dic{rock steady : rock}
# added : dic{world christmas : rock}
# missing genre : pixie
# added : dic{classical guitar : orchestral}
# added : dic{deep melodic hard rock : rock}
# added : dic{classic norwegian pop : pop}
# added : dic{athens indie : rock}
# added : dic{indie emo : rock}
# added : dic{shiver pop : pop}
# added : dic{vapor soul : r&b and soul}
# missing genre : austindie
# added : dic{indie psych-rock : rock}
# missing genre : fluxwork
# missing genre : mandible
# added : dic{dwn trap : hip hop}
# missing genre : indiecoustica
# added : dic{chinese traditional : pop}
# missing genre : choral
# missing genre : violin
# added : dic{new tribe : rock}
# added : dic{brazilian indie : rock}
# added : dic{rock gaucho : rock}
# missing genre : violin
# missing genre : violin
# added : dic{italian pop rock : rock}
# missing genre : preverb
# missing genre : lilith
# added : dic{chicago indie : rock}
# added : dic{post rock : rock}
# added : dic{slow core : hip hop}
# missing genre : violin
# added : dic{underground rap : hip hop}
# added : dic{jazz orchestra : jazz}
# added : dic{brill building pop : pop}
# added : dic{symphonic rock : rock}
# added : dic{traditional folk : folk}
# missing genre : balkan brass
# added : dic{hard glam : rock}
# added : dic{swedish hard rock : rock}
# missing genre : melancholia
# added : dic{pub rock : rock}
# added : dic{contemporary country : country}
# added : dic{country christmas : country}
# added : dic{country road : easy listening}
# added : dic{finnish jazz : jazz}
# added : dic{swedish jazz : jazz}
# missing genre : electrofox
# missing genre : liedermacher
# added : dic{swiss rock : rock}
# added : dic{indie dream pop : pop}
# added : dic{indie shoegaze : rock}
# added : dic{deep german indie : rock}
# added : dic{brooklyn indie : rock}
# added : dic{ska revival : folk}
# added : dic{gauze pop : pop}
# added : dic{deep disco house : electronic}
# added : dic{deep euro house : electronic}
# added : dic{deep melodic euro house : electronic}
# added : dic{german techno : electronic}
# missing genre : comic
# added : dic{grave wave : electronic}
# missing genre : liedermacher
# missing genre : concert piano
# missing genre : violin
# missing genre : concert piano
# added : dic{deep cello : r&b and soul}
# missing genre : violin
# missing genre : fingerstyle
# added : dic{bass trap : hip hop}
# added : dic{electronic trap : hip hop}
# added : dic{vapor twitch : electronic}
# added : dic{abstract hip hop : hip hop}
# missing genre : preverb
# added : dic{shimmer psych : folk}
# missing genre : preverb
# missing genre : christmas
# added : dic{doo-wop : electronic}
# added : dic{rock-and-roll : rock}
# added : dic{ok indie : rock}
# missing genre : pixie
# added : dic{spanish indie rock : rock}
# missing genre : balkan brass
# missing genre : violin
# added : dic{brutal death metal : rock}
# missing genre : deathgrind
# added : dic{acousmatic : electronic}
# added : dic{musique concrete : electronic}
# added : dic{deep free jazz : jazz}
# missing genre : ebm
# missing genre : ebm
# missing genre : motown
# added : dic{turkish rock : rock}
# added : dic{nu age : pop}
# added : dic{warm drone : rock}
# added : dic{german oi : electronic}
# missing genre : ninja
# added : dic{jam band : jazz}
# missing genre : hauntology
# missing genre : mandible
# missing genre : comic
# added : dic{welsh rock : rock}
# missing genre : volksmusik
# missing genre : volksmusik
# missing genre : preverb
# missing genre : psychill
# missing genre : protopunk
# missing genre : violin
# added : dic{french hip hop : hip hop}
# added : dic{trap francais : hip hop}
# missing genre : francoton
# added : dic{french rock : rock}
# missing genre : francoton
# missing genre : melancholia
# added : dic{deep folk metal : rock}
# added : dic{canadian country : country}
# missing genre : cello
# missing genre : steampunk
# missing genre : orgcore
# missing genre : harpsichord
# added : dic{alternative americana : country}
# added : dic{big band : jazz}
# missing genre : accordion
# missing genre : ninja
# missing genre : bmore
# added : dic{neo-singer-songwriter : folk}
# added : dic{boy band : jazz}
# missing genre : strut
# missing genre : clarinet
# missing genre : violin
# added : dic{bassline : electronic}
# missing genre : azontobeats
# missing genre : francoton
# added : dic{filter house : electronic}
# missing genre : francoton
# added : dic{malagasy folk : folk}
# added : dic{yugoslav rock : rock}
# missing genre : violin
# missing genre : violin
# missing genre : violin
# added : dic{cuban rumba : latin}
# added : dic{latin christmas : latin}
# missing genre : volksmusik
# missing genre : volksmusik
# missing genre : zillertal
# missing genre : volksmusik
# added : dic{mexican indie : rock}
# added : dic{venezuelan rock : rock}
# added : dic{bossa nova jazz : jazz}
# missing genre : klezmer
# added : dic{traditional swing : jazz}
# missing genre : harpsichord
# missing genre : liedermacher
# added : dic{korean pop : pop}
# missing genre : exotica
# missing genre : laboratorio
# added : dic{lounge : easy listening}
# added : dic{surf music : avant-garde}
# missing genre : preverb
# missing genre : madchester
# missing genre : violin
# added : dic{minimal tech house : electronic}
# missing genre : violin
# missing genre : violin
# missing genre : string quartet
# missing genre : quiet storm
# added : dic{progressive electro house : electronic}
# added : dic{lovers rock : rock}
# added : dic{groove room : electronic}
# added : dic{deep funk carioca : latin}
# missing genre : violin
# added : dic{deep latin jazz : jazz}
# missing genre : orgcore
# added : dic{power-pop punk : rock}
# added : dic{vocal house : electronic}
# added : dic{seattle indie : rock}
# missing genre : tzadik
# missing genre : concert piano
# missing genre : violin
# missing genre : concert piano
# missing genre : violin
# missing genre : classify
# missing genre : beatdown
# missing genre : ebm
# added : dic{neo-synthpop : pop}
# added : dic{drone folk : folk}
# missing genre : violin
# missing genre : violin
# missing genre : harpsichord
# missing genre : violin
# missing genre : trova
# missing genre : redneck
# missing genre : ebm
# added : dic{country dawn : country}
# added : dic{country gospel : blues}
# added : dic{modern country rock : rock}
# added : dic{austrian hip hop : hip hop}
# missing genre : violin
# added : dic{south african jazz : jazz}
# added : dic{lift kit : electronic}
# added : dic{deep string quartet : r&b and soul}
# missing genre : string quartet
# missing genre : norteno
# added : dic{turkish classical : orchestral}
# added : dic{turkish folk : folk}
# added : dic{turkish jazz : jazz}
# missing genre : talent show
# missing genre : throat singing
# added : dic{finnish metal : rock}
# missing genre : violin
# added : dic{alternative roots rock : rock}
# added : dic{swedish indie pop : pop}
# missing genre : kabarett
# missing genre : liedermacher
# added : dic{deep danish pop : pop}
# added : dic{deep tropical house : electronic}
# missing genre : francoton
# missing genre : francoton
# missing genre : francoton
# missing genre : francoton
# added : dic{danish pop rock : rock}
# missing genre : melancholia
# added : dic{scottish rock : rock}
# missing genre : choral
# missing genre : violin
# added : dic{portuguese rock : rock}
# missing genre : choral
# missing genre : concert piano
# missing genre : harpsichord
# missing genre : violin
# added : dic{christian christmas : rock}
# added : dic{gospel : blues}
# missing genre : francoton
# missing genre : cello
# missing genre : steampunk
# added : dic{vienna indie : rock}
# missing genre : danspunk
# added : dic{atmospheric post rock : rock}
# added : dic{depressive black metal : rock}
# missing genre : voidgaze
# added : dic{italian metal : rock}
# missing genre : violin
# added : dic{portland indie : rock}
# added : dic{deep german punk : rock}
# missing genre : cello
# missing genre : tzadik
# added : dic{reggae rock : rock}
# missing genre : orgcore
# added : dic{tracestep : electronic}
# missing genre : forro
# missing genre : mpb
# missing genre : velha guarda
# missing genre : soundtrack
# added : dic{antiviral pop : pop}
# missing genre : comic
# missing genre : otacore
# added : dic{vancouver indie : rock}
# added : dic{deep underground hip hop : hip hop}
# missing genre : balkan brass
# added : dic{italian folk : folk}
# added : dic{french folk pop : pop}
# missing genre : violin
# missing genre : violin
# missing genre : violin
# missing genre : choral
# missing genre : harpsichord
# missing genre : violin
# added : dic{british folk : folk}
# added : dic{irish folk : folk}
# missing genre : preverb
# added : dic{danish indie : rock}
# missing genre : preverb
# missing genre : motown
# missing genre : quiet storm
# missing genre : christmas
# missing genre : eurovision
# missing genre : deathgrind
# missing genre : nwothm
# missing genre : gamecore
# missing genre : mpb
# missing genre : yoik
# missing genre : nwobhm
# added : dic{chinese indie rock : rock}
# missing genre : motown
# missing genre : clarinet
# missing genre : voidgaze
# missing genre : sleep
# added : dic{modern southern rock : rock}
# missing genre : quebecois
# added : dic{trash rock : rock}
# missing genre : deathgrind
# added : dic{slam death metal : rock}
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : tzadik
# missing genre : volksmusik
# added : dic{christian alternative rock : rock}
# added : dic{library music : avant-garde}
# added : dic{chaotic black metal : rock}
# missing genre : voidgaze
# added : dic{traditional funk : r&b and soul}
# added : dic{atmospheric post-metal : rock}
# added : dic{substep : electronic}
# missing genre : harpsichord
# missing genre : violin
# missing genre : steampunk
# added : dic{modern free jazz : jazz}
# missing genre : lilith
# missing genre : vocaloid
# missing genre : anime
# added : dic{baroque : pop}
# missing genre : choral
# added : dic{early music : avant-garde}
# missing genre : harpsichord
# added : dic{jazz trio : jazz}
# missing genre : mandible
# missing genre : modern performance
# missing genre : pixie
# missing genre : dreamo
# missing genre : dreamo
# added : dic{deep trap : hip hop}
# added : dic{deep regional mexican : pop}
# missing genre : norteno
# added : dic{latin hip hop : hip hop}
# added : dic{pop reggaeton : latin}
# added : dic{reggaeton flow : latin}
# added : dic{vegas indie : rock}
# missing genre : comic
# missing genre : violin
# added : dic{filthstep : electronic}
# added : dic{zapstep : electronic}
# missing genre : violin
# added : dic{deep southern trap : hip hop}
# missing genre : electrofox
# missing genre : harpsichord
# missing genre : violin
# missing genre : danspunk
# missing genre : volksmusik
# added : dic{channel pop : pop}
# missing genre : madchester
# missing genre : classify
# missing genre : concert piano
# missing genre : balkan brass
# missing genre : liedermacher
# added : dic{classic schlager : pop}
# missing genre : austindie
# missing genre : melancholia
# added : dic{suomi rock : rock}
# missing genre : voidgaze
# missing genre : anthem worship
# added : dic{christian uplift : electronic}
# missing genre : violin
# missing genre : beatdown
# added : dic{sertanejo universitario : country}
# missing genre : liedermacher
# missing genre : francoton
# missing genre : ebm
# missing genre : violin
# missing genre : volksmusik
# missing genre : volksmusik
# missing genre : choral
# missing genre : balkan brass
# missing genre : mpb
# missing genre : karneval
# added : dic{british indie rock : rock}
# added : dic{sheffield indie : rock}
# missing genre : corrosion
# added : dic{danish jazz : jazz}
# added : dic{bulgarian folk : folk}
# added : dic{japanese psychedelic : folk}
# added : dic{kraut rock : rock}
# missing genre : balkan brass
# added : dic{classic garage rock : rock}
# missing genre : classify
# missing genre : otacore
# missing genre : scorecore
# missing genre : abstract
# missing genre : fluxwork
# added : dic{hardcore techno : electronic}
# missing genre : mandible
# missing genre : ninja
# missing genre : pixie
# missing genre : talent show
# added : dic{deep swedish indie pop : pop}
# added : dic{swedish folk pop : pop}
# missing genre : mpb
# added : dic{neo-trad metal : rock}
# missing genre : concert piano
# missing genre : consort
# missing genre : preverb
# added : dic{stomp pop : pop}
# missing genre : ebm
# added : dic{neoclassical : rock}
# missing genre : fingerstyle
# added : dic{minimal melodic techno : electronic}
# missing genre : merseybeat
# missing genre : motown
# missing genre : protopunk
# missing genre : merseybeat
# missing genre : motown
# missing genre : protopunk
# missing genre : motown
# missing genre : quiet storm
# added : dic{contemporary classical : orchestral}
# missing genre : deathgrind
# missing genre : classify
# missing genre : deathgrind
# added : dic{regional mexican pop : pop}
# added : dic{bass trip : electronic}
# missing genre : concert piano
# added : dic{deep taiwanese pop : pop}
# missing genre : harpsichord
# added : dic{deep groove house : electronic}
# missing genre : soundtrack
# added : dic{classic swedish pop : pop}
# missing genre : nwobhm
# added : dic{grim death metal : rock}
# added : dic{deep texas country : country}
# missing genre : redneck
# missing genre : preverb
# missing genre : environmental
# missing genre : commons
# missing genre : riddim
# missing genre : aussietronica
# missing genre : volksmusik
# missing genre : volksmusik
# missing genre : zillertal
# missing genre : nwobhm
# added : dic{brazilian hip hop : hip hop}
# missing genre : laboratorio
# missing genre : clarinet
# added : dic{brass band : jazz}
# added : dic{a cappella : hip hop}
# added : dic{greek indie : rock}
# added : dic{french punk : rock}
# missing genre : francoton
# missing genre : e6fi
# missing genre : christmas
# missing genre : volksmusik
# missing genre : fingerstyle
# missing genre : preverb
# missing genre : beatdown
# added : dic{turbo folk : folk}
# missing genre : tico
# added : dic{deep chiptune : electronic}
# added : dic{alternative r&b : r&b and soul}
# missing genre : violin
# added : dic{croatian pop : pop}
# missing genre : deathgrind
# added : dic{hindustani classical : orchestral}
# added : dic{indian classical : orchestral}
# added : dic{melodic progressive metal : rock}
# missing genre : euroska
# missing genre : volksmusik
# missing genre : talent show
# missing genre : choral
# missing genre : harpsichord
# missing genre : madchester
# added : dic{merengue urbano : latin}
# missing genre : cubaton
# added : dic{classic soundtrack : orchestral}
# added : dic{classic danish pop : pop}
# missing genre : dansktop
# added : dic{deep chill-out : hip hop}
# added : dic{nu-cumbia : latin}
# added : dic{deep dub techno : electronic}
# added : dic{k-hop : hip hop}
# missing genre : fluxwork
# missing genre : mandible
# added : dic{minimal dub : electronic}
# added : dic{garage punk blues : blues}
# missing genre : ebm
# missing genre : ebm
# missing genre : steampunk
# missing genre : balkan brass
# missing genre : fluxwork
# missing genre : orgcore
# added : dic{traditional british folk : folk}
# added : dic{african rock : rock}
# missing genre : preverb
# missing genre : preverb
# missing genre : laboratorio
# missing genre : renaissance
# missing genre : liedermacher
# added : dic{ambient fusion : jazz}
# missing genre : laboratorio
# added : dic{cowboy western : folk}
# added : dic{stomp and flutter : jazz}
# added : dic{indie singer-songwriter : folk}
# missing genre : euroska
# missing genre : violin
# missing genre : anthem worship
# missing genre : harpsichord
# missing genre : preverb
# missing genre : comic
# added : dic{indorock : rock}
# missing genre : quebecois
# missing genre : pixie
# added : dic{progressive trance house : electronic}
# missing genre : blackgaze
# missing genre : voidgaze
# missing genre : protopunk
# missing genre : francoton
# missing genre : fingerstyle
# added : dic{candy pop : pop}
# missing genre : lilith
# missing genre : maghreb
# added : dic{rio de la plata : pop}
# missing genre : dreamo
# missing genre : soundtrack
# missing genre : concert piano
# missing genre : violin
# missing genre : liedermacher
# missing genre : danspunk
# missing genre : liedermacher
# missing genre : strut
# added : dic{classic turkish pop : pop}
# added : dic{turkish alternative : rock}
# missing genre : fluxwork
# missing genre : hauntology
# missing genre : mandible
# missing genre : preverb
# added : dic{uk dub : electronic}
# missing genre : francoton
# added : dic{zouk riddim : latin}
# missing genre : francoton
# added : dic{ye ye : r&b and soul}
# missing genre : orgcore
# added : dic{irish rock : rock}
# missing genre : modern performance
# missing genre : violin
# added : dic{neo-rockabilly : country}
# added : dic{hungarian hip hop : hip hop}
# missing genre : harpsichord
# added : dic{deep minimal techno : electronic}
# added : dic{west coast trap : hip hop}
# missing genre : harpsichord
# added : dic{deep soft rock : rock}
# missing genre : comic
# missing genre : ninja
# added : dic{deep canadian indie : rock}
# missing genre : violin
# missing genre : throat singing
# missing genre : violin
# added : dic{deep pop edm : blues}
# added : dic{canadian hip hop : hip hop}
# missing genre : laboratorio
# added : dic{deep acoustic pop : pop}
# missing genre : christmas
# missing genre : fluxwork
# missing genre : hauntology
# missing genre : mandible
# missing genre : modern performance
# added : dic{indie psych-pop : pop}
# added : dic{noise punk : rock}
# missing genre : melancholia
# added : dic{alternative pop : pop}
# missing genre : gbvfi
# missing genre : lilith
# missing genre : melancholia
# added : dic{piano rock : rock}
# missing genre : fluxwork
# missing genre : mandible
# missing genre : modern performance
# missing genre : concert piano
# missing genre : violin
# missing genre : violin
# missing genre : violin
# missing genre : lilith
# missing genre : corrosion
# missing genre : ebm
# missing genre : dreamo
# added : dic{emo punk : rock}
# missing genre : steampunk
# missing genre : fingerstyle
# added : dic{folklore argentino : folk}
# missing genre : german ccm
# missing genre : christmas
# missing genre : motown
# missing genre : quiet storm
# missing genre : violin
# missing genre : strut
# missing genre : necrogrind
# missing genre : concert piano
# added : dic{g funk : r&b and soul}
# missing genre : pixie
# added : dic{deep pop punk : rock}
# missing genre : talent show
# missing genre : fingerstyle
# added : dic{russian punk : rock}
# missing genre : barbershop
# missing genre : riddim
# missing genre : comic
# added : dic{catstep : electronic}
# added : dic{deep big room : electronic}
# missing genre : riddim
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : fingerstyle
# missing genre : violin
# missing genre : pixie
# missing genre : harpsichord
# missing genre : harpsichord
# missing genre : violin
# missing genre : deathgrind
# missing genre : melancholia
# added : dic{melodic hard rock : rock}
# missing genre : nwobhm
# missing genre : nwothm
# added : dic{dansband : country}
# missing genre : danspunk
# missing genre : ebm
# missing genre : ebm
# missing genre : shanty
# added : dic{latvian pop : pop}
# missing genre : fingerstyle
# missing genre : otacore
# added : dic{thrash core : hip hop}
# missing genre : comic
# added : dic{jig and reel : jazz}
# added : dic{michigan indie : rock}
# missing genre : choral
# missing genre : harpsichord
# missing genre : choral
# missing genre : harpsichord
# missing genre : violin
# missing genre : liedermacher
# added : dic{sunset lounge : easy listening}
# missing genre : zillertal
# missing genre : choral
# missing genre : madchester
# missing genre : lithumania
# added : dic{brutal deathcore : rock}
# added : dic{deep symphonic black metal : rock}
# missing genre : liedermacher
# added : dic{classic italian pop : pop}
# added : dic{italian hip hop : hip hop}
# missing genre : clarinet
# missing genre : tzadik
# missing genre : opm
# added : dic{pinoy alternative : rock}
# missing genre : mandible
# added : dic{funeral doom : electronic}
# missing genre : voidgaze
# missing genre : lilith
# added : dic{funky breaks : electronic}
# missing genre : balkan brass
# added : dic{belly dance : electronic}
# added : dic{rai : jazz}
# missing genre : steelpan
# missing genre : electrofox
# missing genre : comic
# missing genre : pixie
# missing genre : pixie
# added : dic{j-metal : rock}
# added : dic{czech rock : rock}
# missing genre : doujin
# added : dic{j-core : hip hop}
# added : dic{twee pop : pop}
# missing genre : francoton
# missing genre : balkan brass
# added : dic{persian pop : pop}
# missing genre : mpb
# missing genre : choral
# missing genre : electrofox
# missing genre : fluxwork
# missing genre : mandible
# missing genre : melancholia
# added : dic{children's music : avant-garde}
# missing genre : louvor
# missing genre : melancholia
# added : dic{deep jazz fusion : jazz}
# missing genre : relaxative
# missing genre : preverb
# missing genre : violin
# missing genre : healing
# added : dic{new age : pop}
# missing genre : deathgrind
# missing genre : opm
# missing genre : melancholia
# added : dic{deep delta blues : blues}
# missing genre : abstract
# missing genre : preverb
# missing genre : lilith
# missing genre : axe
# missing genre : forro
# missing genre : mpb
# missing genre : axe
# added : dic{balearic : electronic}
# missing genre : motown
# missing genre : quiet storm
# missing genre : motown
# missing genre : quiet storm
# added : dic{neo metal : rock}
# missing genre : ninja
# missing genre : nwobhm
# missing genre : nwothm
# missing genre : liedermacher
# added : dic{electro dub : electronic}
# missing genre : hollywood
# added : dic{argentine rock : rock}
# added : dic{cumbia pop : pop}
# added : dic{cumbia villera : latin}
# missing genre : danspunk
# missing genre : zim
# added : dic{spanish hip hop : hip hop}
# missing genre : lilith
# added : dic{k-indie : rock}
# missing genre : voidgaze
# missing genre : protopunk
# missing genre : balkan brass
# missing genre : mpb
# missing genre : lilith
# missing genre : modern performance
# missing genre : melancholia
# missing genre : carnatic
# missing genre : wrestling
# missing genre : concert piano
# missing genre : violin
# added : dic{psychedelic blues-rock : rock}
# missing genre : mpb
# missing genre : epicore
# missing genre : scorecore
# missing genre : soundtrack
# added : dic{early music ensemble : avant-garde}
# missing genre : renaissance
# missing genre : melancholia
# missing genre : liedermacher
# missing genre : indiecoustica
# missing genre : quebecois
# missing genre : quebecois
# added : dic{albuquerque indie : rock}
# missing genre : cello
# missing genre : violin
# missing genre : preverb
# added : dic{swedish synthpop : pop}
# missing genre : volksmusik
# missing genre : ballroom
# added : dic{new orleans jazz : jazz}
# missing genre : arabesk
# added : dic{deep turkish pop : pop}
# missing genre : deathgrind
# added : dic{dark psytrance : rock}
# added : dic{deep darkpsy : r&b and soul}
# missing genre : balkan brass
# missing genre : balkan brass
# added : dic{uk hip hop : hip hop}
# added : dic{norwegian gospel : blues}
# missing genre : melancholia
# missing genre : beatdown
# missing genre : beatdown
# missing genre : blackgaze
# missing genre : voidgaze
# added : dic{hard alternative : rock}
# added : dic{colombian rock : rock}
# missing genre : violin
# missing genre : idol
# added : dic{swedish punk : rock}
# added : dic{finnish indie : rock}
# missing genre : choral
# missing genre : ccm
# added : dic{christian music : avant-garde}
# missing genre : worship
# missing genre : melancholia
# missing genre : orgcore
# missing genre : anthem worship
# missing genre : mallet
# added : dic{neue deutsche welle : rock}
# added : dic{slovenian rock : rock}
# missing genre : liedermacher
# added : dic{drone psych : folk}
# missing genre : violin
# missing genre : entehno
# added : dic{chilean rock : rock}
# missing genre : quebecois
# missing genre : francoton
# missing genre : steampunk
# missing genre : balkan brass
# added : dic{deep psychobilly : rock}
# missing genre : christmas
# missing genre : preverb
# missing genre : preverb
# missing genre : preverb
# missing genre : lilith
# missing genre : melancholia
# missing genre : violin
# missing genre : ebm
# added : dic{martial industrial : hip hop}
# missing genre : harpsichord
# missing genre : melancholia
# missing genre : boogaloo
# added : dic{salsa international : latin}
# missing genre : soundtrack
# missing genre : quiet storm
# missing genre : deathgrind
# missing genre : preverb
# missing genre : boogaloo
# missing genre : trova
# missing genre : madchester
# missing genre : choral
# missing genre : harpsichord
# missing genre : violin
# missing genre : nwobhm
# missing genre : wrestling
# missing genre : preverb
# added : dic{polish indie : rock}
# added : dic{polish pop : pop}
# missing genre : ebm
# missing genre : kabarett
# missing genre : liedermacher
# added : dic{folkmusik : folk}
# missing genre : modern performance
# missing genre : gbvfi
# added : dic{outsider : electronic}
# missing genre : violin
# missing genre : ebm
# missing genre : pixie
# added : dic{mexican traditional : pop}
# missing genre : voidgaze
# missing genre : voidgaze
# missing genre : deathgrind
# added : dic{deep melodic metalcore : rock}
# added : dic{screamo punk : rock}
# missing genre : liedermacher
# added : dic{vapor pop : pop}
# added : dic{black death : rock}
# missing genre : deathgrind
# added : dic{alternative metalcore : rock}
# missing genre : ninja
# added : dic{retro electro : electronic}
# missing genre : cubaton
# missing genre : cello
# missing genre : madchester
# missing genre : lilith
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : tzadik
# added : dic{deep indie singer-songwriter : folk}
# missing genre : blackgaze
# missing genre : euroska
# added : dic{chip hop : hip hop}
# added : dic{outer hip hop : hip hop}
# missing genre : liedermacher
# missing genre : modern performance
# missing genre : string quartet
# added : dic{brazilian punk : rock}
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : voidgaze
# missing genre : abstractro
# missing genre : fluxwork
# missing genre : hauntology
# missing genre : mandible
# missing genre : choral
# missing genre : german ccm
# missing genre : german ccm
# missing genre : harpsichord
# missing genre : beatdown
# missing genre : christmas
# missing genre : balkan brass
# missing genre : klezmer
# added : dic{romanian pop : pop}
# added : dic{electro latino : latin}
# added : dic{lounge house : electronic}
# added : dic{spanish noise pop : pop}
# missing genre : anthem worship
# added : dic{world worship : rock}
# added : dic{french movie tunes : country}
# added : dic{deep discofox : r&b and soul}
# missing genre : volksmusik
# missing genre : zillertal
# missing genre : madchester
# added : dic{polynesian pop : pop}
# missing genre : euroska
# missing genre : laboratorio
# missing genre : choral
# missing genre : harpsichord
# missing genre : nwobhm
# missing genre : ninja
# missing genre : dreamo
# missing genre : orgcore
# missing genre : orgcore
# missing genre : madchester
# missing genre : preverb
# missing genre : francoton
# added : dic{deep space rock : rock}
# missing genre : preverb
# added : dic{deep cumbia sonidera : latin}
# missing genre : nwobhm
# missing genre : fluxwork
# missing genre : mandible
# added : dic{nz indie : rock}
# missing genre : concert piano
# added : dic{underground power pop : pop}
# added : dic{nu disco : r&b and soul}
# missing genre : electrofox
# added : dic{african percussion : african}
# missing genre : harp
# missing genre : violin
# added : dic{leeds indie : rock}
# missing genre : spoken word
# missing genre : quebecois
# missing genre : harpsichord
# added : dic{military band : jazz}
# added : dic{metal guitar : rock}
# missing genre : tzadik
# missing genre : zolo
# missing genre : pixie
# missing genre : ebm
# missing genre : ebm
# missing genre : merseybeat
# missing genre : motown
# missing genre : protopunk
# missing genre : deathgrind
# missing genre : balkan brass
# missing genre : deathgrind
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : liedermacher
# missing genre : norteno
# missing genre : voidgaze
# missing genre : kompa
# missing genre : beatdown
# missing genre : mandible
# missing genre : mandible
# missing genre : blackgaze
# missing genre : blackgaze
# missing genre : voidgaze
# missing genre : choral
# missing genre : harpsichord
# missing genre : protopunk
# missing genre : indiecoustica
# missing genre : deathgrind
# missing genre : concert piano
# missing genre : violin
# missing genre : preverb
# missing genre : choral
# missing genre : harpsichord
# missing genre : lilith
# added : dic{chanson quebecois : pop}
# missing genre : quebecois
# missing genre : quebecois
# missing genre : brass ensemble
# added : dic{cumbia sonidera : latin}
# added : dic{drumfunk : r&b and soul}
# added : dic{jump up : latin}
# added : dic{deep liquid : electronic}
# added : dic{deep liquid bass : electronic}
# missing genre : choral
# missing genre : clarinet
# missing genre : kabarett
# missing genre : liedermacher
# added : dic{deep comedy : comedy}
# missing genre : preverb
# missing genre : madchester
# missing genre : kabarett
# missing genre : liedermacher
# added : dic{deep italo disco : r&b and soul}
# missing genre : balkan brass
# missing genre : zolo
# added : dic{skinhead oi : electronic}
# missing genre : ballroom
# missing genre : fingerstyle
# missing genre : choral
# added : dic{columbus ohio indie : rock}
# missing genre : pixie
# missing genre : preverb
# missing genre : otacore
# missing genre : gbvfi
# missing genre : preverb
# missing genre : orgcore
# missing genre : modern performance
# missing genre : austindie
# missing genre : quebecois
# missing genre : quebecois
# missing genre : harpsichord
# missing genre : brass ensemble
# missing genre : ballroom
# missing genre : ballroom
# missing genre : cantautor
# added : dic{spanish indie pop : pop}
# missing genre : deathgrind
# missing genre : deathgrind
# added : dic{technical brutal death metal : rock}
# missing genre : mpb
# missing genre : ebm
# missing genre : ninja
# missing genre : quebecois
# missing genre : dreamo
# missing genre : classify
# added : dic{deep norteno : r&b and soul}
# missing genre : violin
# missing genre : liedermacher
# missing genre : deathgrind
# added : dic{movie tunes : country}
# missing genre : soundtrack
# missing genre : coverchill
# missing genre : german ccm
# missing genre : ninja
# missing genre : throat singing
# added : dic{lo star : hip hop}
# missing genre : violin
# missing genre : danspunk
# missing genre : orgcore
# missing genre : liedermacher
# missing genre : riddim
# missing genre : quebecois
# missing genre : violin
# missing genre : otacore
# added : dic{mod revival : folk}
# missing genre : christmas
# missing genre : motown
# missing genre : quiet storm
# missing genre : preverb
# added : dic{electro : electronic}
# missing genre : mandible
# missing genre : preverb
# missing genre : riddim
# missing genre : riddim
# missing genre : comic
# missing genre : pixie
# added : dic{west african jazz : jazz}
# missing genre : klezmer
# added : dic{flick hop : hip hop}
# added : dic{cante flamenco : latin}
# missing genre : ninja
# missing genre : violin
# missing genre : quebecois
# missing genre : hauntology
# missing genre : fake
# missing genre : blackgaze
# missing genre : voidgaze
# added : dic{deep vocal jazz : jazz}
# missing genre : nwobhm
# missing genre : nwobhm
# missing genre : nwothm
# missing genre : fluxwork
# missing genre : mandible
# missing genre : motown
# missing genre : quiet storm
# added : dic{vegan straight edge : jazz}
# added : dic{corsican folk : folk}
# missing genre : polyphony
# missing genre : nwobhm
# missing genre : arabesk
# added : dic{vintage tango : latin}
# missing genre : preverb
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : concert piano
# missing genre : violin
# added : dic{deep latin christian : rock}
# missing genre : choral
# added : dic{japanese jazztronica : jazz}
# added : dic{deep surf music : avant-garde}
# added : dic{classic finnish rock : rock}
# missing genre : abstractro
# missing genre : hauntology
# added : dic{italian progressive rock : rock}
# missing genre : eurovision
# missing genre : throat singing
# missing genre : francoton
# missing genre : pixie
# missing genre : harp
# added : dic{indie rockism : rock}
# missing genre : serialism
# added : dic{bounce : hip hop}
# missing genre : strut
# missing genre : indiecoustica
# missing genre : c86
# missing genre : violin
# missing genre : melancholia
# added : dic{electropowerpop : pop}
# missing genre : pixie
# missing genre : madchester
# missing genre : lilith
# missing genre : austindie
# missing genre : brass ensemble
# added : dic{grisly death metal : rock}
# missing genre : klezmer
# missing genre : riddim
# missing genre : ebm
# missing genre : balkan brass
# added : dic{perth indie : rock}
# added : dic{faroese pop : pop}
# missing genre : corrosion
# added : dic{triangle indie : rock}
# missing genre : classify
# missing genre : wrestling
# added : dic{power violence : rock}
# missing genre : orgcore
# missing genre : christmas
# missing genre : beatdown
# missing genre : duranguense
# missing genre : norteno
# missing genre : ebm
# missing genre : ebm
# missing genre : eurovision
# added : dic{hands up : latin}
# added : dic{swedish eurodance : electronic}
# missing genre : dreamo
# missing genre : violin
# missing genre : pixie
# missing genre : voidgaze
# missing genre : voidgaze
# missing genre : dreamo
# missing genre : nwobhm
# missing genre : preverb
# missing genre : comic
# missing genre : pixie
# missing genre : clarinet
# missing genre : euroska
# missing genre : nwothm
# missing genre : cubaton
# added : dic{memphis hip hop : hip hop}
# added : dic{ambient idm : electronic}
# added : dic{abstract idm : electronic}
# missing genre : fingerstyle
# missing genre : e6fi
# missing genre : gbvfi
# missing genre : tzadik
# added : dic{afrobeats : african}
# missing genre : liedermacher
# missing genre : melancholia
# missing genre : steampunk
# missing genre : ninja
# missing genre : mandible
# missing genre : corrosion
# missing genre : cubaton
# missing genre : pixie
# missing genre : mizrahi
# missing genre : mizrahi
# missing genre : preverb
# missing genre : liedermacher
# missing genre : violin
# missing genre : kabarett
# missing genre : liedermacher
# missing genre : melancholia
# missing genre : liedermacher
# missing genre : cantautor
# missing genre : ebm
# added : dic{nordic folk : folk}
# missing genre : indiecoustica
# added : dic{deep swedish hip hop : hip hop}
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : gbvfi
# added : dic{experimental psych : folk}
# missing genre : epicore
# added : dic{louisville indie : rock}
# missing genre : comic
# missing genre : pixie
# missing genre : concert piano
# missing genre : madchester
# missing genre : comic
# missing genre : laboratorio
# missing genre : soundtrack
# missing genre : madchester
# missing genre : quebecois
# missing genre : punta
# added : dic{argentine reggae : hip hop}
# missing genre : galego
# missing genre : preverb
# missing genre : nwobhm
# missing genre : christmas
# added : dic{ectofolk : folk}
# missing genre : lilith
# missing genre : melancholia
# missing genre : motown
# missing genre : quiet storm
# missing genre : orgcore
# missing genre : duranguense
# missing genre : norteno
# missing genre : nwobhm
# missing genre : nwothm
# missing genre : healing
# missing genre : kirtan
# missing genre : merseybeat
# missing genre : protopunk
# missing genre : lilith
# missing genre : motown
# missing genre : tzadik
# missing genre : pixie
# missing genre : dreamo
# missing genre : eurovision
# missing genre : electrofox
# missing genre : steampunk
# missing genre : orgcore
# missing genre : melancholia
# missing genre : preverb
# missing genre : pixie
# added : dic{german street punk : rock}
# missing genre : melancholia
# missing genre : protopunk
# missing genre : healing
# missing genre : kirtan
# missing genre : meditation
# added : dic{world meditation : rock}
# missing genre : liedermacher
# missing genre : violin
# missing genre : madchester
# added : dic{argentine indie : rock}
# missing genre : preverb
# added : dic{gothic post-punk : rock}
# missing genre : laboratorio
# missing genre : steampunk
# missing genre : laboratorio
# added : dic{vintage french electronic : electronic}
# missing genre : ebm
# added : dic{new age piano : pop}
# missing genre : volksmusik
# added : dic{electro trash : electronic}
# missing genre : austindie
# missing genre : nwobhm
# missing genre : motown
# missing genre : quiet storm
# missing genre : christmas
# missing genre : austindie
# missing genre : deathgrind
# missing genre : voidgaze
# missing genre : voidgaze
# missing genre : renaissance
# missing genre : kindermusik
# missing genre : blackgaze
# missing genre : usbm
# missing genre : voidgaze
# missing genre : choral
# missing genre : preverb
# missing genre : choral
# missing genre : gbvfi
# missing genre : protopunk
# missing genre : zolo
# missing genre : mpb
# missing genre : deathgrind
# missing genre : voidgaze
# missing genre : deathgrind
# missing genre : deathgrind
# missing genre : preverb
# missing genre : indiecoustica
# missing genre : electrofox
# missing genre : choral
# missing genre : consort
# missing genre : harpsichord
# missing genre : euroska
# missing genre : motown
# missing genre : quiet storm
# missing genre : christmas
# missing genre : fluxwork
# missing genre : ninja
# missing genre : ninja
# missing genre : dreamo
# missing genre : tribute
# missing genre : fluxwork
# missing genre : fluxwork
# missing genre : mandible
# missing genre : madchester
# missing genre : beats
# missing genre : modern performance
# added : dic{poetry : folk}
# missing genre : francoton
# added : dic{fast melodic punk : rock}
# missing genre : quebecois
# missing genre : euroska
# missing genre : melancholia
# missing genre : preverb
# missing genre : pixie
# missing genre : fluxwork
# missing genre : pixie
# missing genre : pixie
# missing genre : karneval
# missing genre : melancholia
# missing genre : children's christmas
# missing genre : hollywood
# missing genre : christmas
# missing genre : entehno
# missing genre : nwothm
# missing genre : nwobhm
# missing genre : preverb
# missing genre : hollywood
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : pixie
# missing genre : wrestling
# missing genre : deathgrind
# missing genre : pixie
# missing genre : klezmer
# missing genre : nwobhm
# missing genre : cantautor
# added : dic{rock catala : rock}
# added : dic{spanish folk : folk}
# added : dic{classic polish pop : pop}
# missing genre : bmore
# missing genre : healing
# missing genre : kirtan
# missing genre : meditation
# missing genre : quiet storm
# missing genre : quiet storm
# missing genre : choral
# missing genre : harpsichord
# missing genre : azontobeats
# missing genre : francoton
# added : dic{zouglou : african}
# missing genre : protopunk
# missing genre : abstract
# missing genre : fluxwork
# missing genre : ninja
# missing genre : ninja
# ...
# missing genre : motown
# missing genre : quiet storm
# missing genre : voidgaze
# missing genre : riddim
# added : dic{irish country : country}
# missing genre : melancholia
# added : dic{deep swedish rock : rock}
# missing genre : harp
# missing genre : deathgrind
# missing genre : voidgaze
# missing genre : ebm
# missing genre : quebecois
# missing genre : fluxwork
# missing genre : mandible
# missing genre : string quartet
# missing genre : violin
# added : dic{indian rock : rock}
# added : dic{finnish hardcore : electronic}
# missing genre : quebecois
# missing genre : ebm
# missing genre : steampunk
# missing genre : ebm
# missing genre : comic
# missing genre : orgcore
# missing genre : motown
# missing genre : quiet storm
# missing genre : ebm
# missing genre : motown
# missing genre : quiet storm
# missing genre : liedermacher
# missing genre : francoton
# missing genre : axe
# missing genre : forro
# missing genre : mpb
# missing genre : velha guarda
# missing genre : mpb
# missing genre : quiet storm
# missing genre : modern performance
# missing genre : monastic
# missing genre : modern performance
# missing genre : string quartet
# missing genre : violin
# missing genre : christmas
# missing genre : ninja
# missing genre : madchester
# missing genre : protopunk
# missing genre : zolo
# missing genre : liedermacher
# missing genre : madchester
# missing genre : norteno
# added : dic{tin pan alley : electronic}
# added : dic{ambient dub techno : electronic}
# added : dic{deep deep house : electronic}
# missing genre : choral
# missing genre : harpsichord
# missing genre : fluxwork
# missing genre : footwork
# missing genre : fluxwork
# missing genre : fluxwork
# added : dic{re:techno : electronic}
# missing genre : accordion
# missing genre : austindie
# missing genre : euroska
# added : dic{kc indie : rock}
# missing genre : soundtrack
# added : dic{funky tech house : electronic}
# missing genre : azontobeats
# added : dic{dark minimal techno : electronic}
# missing genre : melancholia
# added : dic{classic colombian pop : pop}
# missing genre : concert piano
# missing genre : christmas
# missing genre : motown
# missing genre : quiet storm
# added : dic{deep sunset lounge : easy listening}
# missing genre : choral
# missing genre : harpsichord
# missing genre : norteno
# missing genre : beats
# missing genre : comic
# missing genre : fluxwork
# added : dic{deep tech house : electronic}
# missing genre : fluxwork
# missing genre : string quartet
# missing genre : soundtrack
# added : dic{sertanejo tradicional : country}
# missing genre : velha guarda
# missing genre : consort
# missing genre : dreamo
# missing genre : violin
# missing genre : anthem worship
# missing genre : motown
# missing genre : quiet storm
# added : dic{dark progressive house : electronic}
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : norteno
# added : dic{freestyle : hip hop}
# missing genre : schranz
# missing genre : fluxwork
# missing genre : mandible
# missing genre : hollywood
# added : dic{greek house : electronic}
# missing genre : melancholia
# missing genre : broadway
# missing genre : hollywood
# missing genre : choral
# missing genre : violin
# missing genre : worship
# missing genre : hollywood
# missing genre : quiet storm
# added : dic{pop flamenco : latin}
# added : dic{hard minimal techno : electronic}
# added : dic{mexican rock-and-roll : rock}
# missing genre : mashup
# missing genre : quiet storm
# missing genre : desi
# missing genre : anthem worship
# missing genre : praise
# missing genre : motown
# missing genre : quiet storm
# missing genre : pixie
# missing genre : worship
# missing genre : worship
# missing genre : hollywood
# missing genre : covertrance
# missing genre : mashup
# missing genre : mashup
# missing genre : praise
# missing genre : comic
# added : dic{geek rock : rock}
# missing genre : zolo
# added : dic{tekno : electronic}
# missing genre : mashup
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : classify
# missing genre : epicore
# missing genre : beatdown
# missing genre : violin
# missing genre : norteno
# added : dic{deep freestyle : hip hop}
# added : dic{italian disco : r&b and soul}
# missing genre : fluxwork
# missing genre : ccm
# missing genre : worship
# missing genre : fluxwork
# missing genre : mandible
# missing genre : fluxwork
# missing genre : mandible
# added : dic{ambient psychill : electronic}
# missing genre : psychill
# missing genre : didgeridoo
# missing genre : psychill
# missing genre : psychill
# missing genre : dreamo
# missing genre : violin
# missing genre : christmas
# missing genre : manele
# missing genre : mandible
# missing genre : fluxwork
# added : dic{classic french pop : pop}
# missing genre : preverb
# added : dic{vietnamese pop : pop}
# missing genre : electrofox
# missing genre : mandible
# missing genre : worship
# missing genre : anime
# missing genre : otacore
# missing genre : norteno
# missing genre : comic
# missing genre : boogaloo
# missing genre : pixie
# missing genre : pixie
# missing genre : pixie
# missing genre : healing
# missing genre : kirtan
# missing genre : meditation
# missing genre : strut
# missing genre : talent show
# missing genre : fluxwork
# missing genre : fluxwork
# missing genre : mandible
# missing genre : hawaiian
# missing genre : worship
# missing genre : fluxwork
# missing genre : hauntology
# missing genre : mandible
# missing genre : fluxwork
# missing genre : ninja
# missing genre : fluxwork
# missing genre : mandible
# missing genre : ninja
# missing genre : merseybeat
# missing genre : protopunk
# missing genre : consort
# missing genre : ninja
# missing genre : preverb
# missing genre : fluxwork
# missing genre : anthem worship
# missing genre : worship
# missing genre : pixie
# missing genre : fluxwork
# missing genre : footwork
# missing genre : mandible
# added : dic{indonesian pop : pop}
# added : dic{nordic house : electronic}
# missing genre : romantico
# added : dic{deep happy hardcore : electronic}
# added : dic{deep christian rock : rock}
# missing genre : schranz
# added : dic{deep neo-synthpop : pop}
# missing genre : comic
# missing genre : schranz
# missing genre : schranz
# missing genre : schranz
# missing genre : broadway
# missing genre : renaissance
# missing genre : choral
# missing genre : string quartet
# missing genre : violin
# missing genre : schranz
# missing genre : fake
# missing genre : fluxwork
# missing genre : mandible
# missing genre : mandible
# missing genre : fluxwork
# missing genre : ninja
# missing genre : ninja
# missing genre : ninja
# missing genre : mashup
# missing genre : scratch
# missing genre : madchester
# missing genre : coverchill
# missing genre : pixie
# added : dic{cinematic dubstep : electronic}
# missing genre : ebm
# added : dic{deep eurodance : electronic}
# missing genre : anthem worship
# missing genre : ccm
# missing genre : worship
# missing genre : comic
# missing genre : zolo
# missing genre : hollywood
# missing genre : e6fi
# missing genre : fluxwork
# missing genre : duranguense
# missing genre : norteno
# missing genre : electrofox
# missing genre : schranz
# missing genre : choral
# missing genre : consort
# missing genre : harpsichord
# missing genre : violin
# missing genre : opm
# missing genre : abstract
# missing genre : abstract
# missing genre : pixie
# missing genre : merseybeat
# missing genre : indiecoustica
# missing genre : pixie
# missing genre : francoton
# added : dic{orquesta tropical : latin}
# added : dic{dominican pop : pop}
# missing genre : ecuadoria
# missing genre : schranz
# missing genre : duranguense
# missing genre : norteno
# missing genre : worship
# missing genre : norteno
# missing genre : kompa
# missing genre : lilith
# missing genre : fluxwork
# added : dic{deep uplifting trance : electronic}
# added : dic{progressive uplifting trance : electronic}
# missing genre : pixie
# missing genre : abstract beats
# missing genre : ambeat
# added : dic{bubble trance : electronic}
# missing genre : abstract
# missing genre : scorecore
# missing genre : barnmusik
# added : dic{neurostep : electronic}
# missing genre : madchester
# added : dic{brazilian gospel : blues}
# missing genre : louvor
# missing genre : melancholia
# missing genre : mandible
# added : dic{j-ambient : electronic}
# missing genre : psychill
# missing genre : opm
# added : dic{electro bailando : asian}
# missing genre : coupe decale
# missing genre : cantautor
# missing genre : trova
# missing genre : norteno
# missing genre : preverb
# missing genre : norteno
# added : dic{deep psytrance : r&b and soul}
# missing genre : strut
# added : dic{ostrock : rock}
# missing genre : redneck
# missing genre : preverb
# added : dic{world chill : electronic}
# added : dic{tone : rock}
# missing genre : duranguense
# missing genre : cubaton
# missing genre : motown
# missing genre : quiet storm
# missing genre : euroska
# missing genre : consort
# added : dic{deep progressive trance : electronic}
# added : dic{deep downtempo fusion : jazz}
# added : dic{charred death : rock}
# missing genre : comic
# missing genre : mandible
# missing genre : mashup
# missing genre : mandible
# added : dic{rock noise : avant-garde}
# missing genre : blackgaze
# missing genre : voidgaze
# missing genre : madchester
# missing genre : protopunk
# missing genre : electrofox
# missing genre : electrofox
# missing genre : anthem worship
# missing genre : dreamo
# added : dic{grunge pop : pop}
# missing genre : cantautor
# missing genre : worship
# missing genre : abstract beats
# missing genre : ninja
# missing genre : schranz
# missing genre : schranz
# missing genre : abstract beats
# missing genre : hollywood
# missing genre : madchester
# missing genre : azontobeats
# missing genre : ninja
# missing genre : scratch
# missing genre : ninja
# missing genre : abstract beats
# missing genre : healing
# missing genre : meditation
# missing genre : anthem worship
# missing genre : redneck
# missing genre : environmental
# missing genre : electrofox
# missing genre : healing
# missing genre : meditation
# missing genre : quiet storm
# missing genre : opm
# missing genre : norteno
# added : dic{dark hardcore : electronic}
# missing genre : pixie
# missing genre : redneck
# missing genre : blackgaze
# missing genre : voidgaze
# missing genre : fluxwork
# missing genre : mandible
# missing genre : halloween
# missing genre : preverb
# missing genre : musica para ninos
# missing genre : fluxwork
# missing genre : mandible
# missing genre : duranguense
# missing genre : norteno
# missing genre : norteno
# missing genre : coverchill
# missing genre : ninja
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : indiecoustica
# missing genre : strut
# missing genre : norteno
# missing genre : fluxwork
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : mashup
# missing genre : madchester
# missing genre : hollywood
# missing genre : anime score
# missing genre : duranguense
# missing genre : norteno
# missing genre : anime
# missing genre : otacore
# missing genre : ninja
# missing genre : fluxwork
# missing genre : fluxwork
# missing genre : romantico
# missing genre : idol
# missing genre : coupe decale
# missing genre : mashup
# missing genre : abstract beats
# missing genre : ninja
# missing genre : modern performance
# added : dic{deep hardcore : electronic}
# added : dic{japanese city pop : pop}
# missing genre : ballroom
# missing genre : christmas
# missing genre : violin
# missing genre : mandible
# missing genre : abstract
# missing genre : fluxwork
# missing genre : mandible
# missing genre : ninja
# missing genre : scratch
# missing genre : c86
# added : dic{slovak hip hop : hip hop}
# missing genre : laboratorio
# missing genre : tzadik
# missing genre : hauntology
# missing genre : otacore
# missing genre : scorecore
# missing genre : hauntology
# missing genre : fluxwork
# missing genre : fluxwork
# missing genre : footwork
# missing genre : mandible
# missing genre : ninja
# missing genre : worship
# missing genre : ninja
# missing genre : ninja
# missing genre : ninja
# missing genre : ninja
# missing genre : schranz
# missing genre : abstract beats
# missing genre : modern performance
# missing genre : comic
# missing genre : zolo
# missing genre : melancholia
# added : dic{oshare kei : rock}
# missing genre : indiecoustica
# added : dic{zouk : latin}
# missing genre : fluxwork
# missing genre : pixie
# missing genre : norteno
# missing genre : christmas
# missing genre : motown
# missing genre : quiet storm
# missing genre : pixie
# missing genre : ebm
# missing genre : manele
# missing genre : axe
# missing genre : fluxwork
# missing genre : ninja
# missing genre : opm
# missing genre : consort
# missing genre : comic
# missing genre : zolo
# missing genre : kompa
# missing genre : pixie
# missing genre : didgeridoo
# missing genre : motown
# missing genre : comic
# missing genre : aussietronica
# missing genre : fingerstyle
# missing genre : doujin
# missing genre : sinhala
# missing genre : indiecoustica
# missing genre : fluxwork
# missing genre : mandible
# added : dic{dark electro-industrial : hip hop}
# missing genre : fluxwork
# missing genre : mandible
# missing genre : otacore
# missing genre : coverchill
# added : dic{breaks : electronic}
# missing genre : ninja
# added : dic{neo-industrial rock : rock}
# added : dic{malaysian pop : pop}
# missing genre : christmas
# missing genre : cantautor
# missing genre : schranz
# missing genre : choral
# missing genre : idol
# missing genre : abstract beats
# missing genre : forro
# missing genre : mpb
# missing genre : velha guarda
# missing genre : modern performance
# missing genre : tzadik
# missing genre : pixie
# missing genre : melancholia
# missing genre : fluxwork
# missing genre : mandible
# missing genre : motown
# missing genre : christmas
# missing genre : nwobhm
# added : dic{swamp pop : pop}
# missing genre : choral
# missing genre : pixie
# missing genre : pixie
# missing genre : mashup
# missing genre : renaissance
# missing genre : exotica
# added : dic{deep funk house : electronic}
# missing genre : ninja
# missing genre : ninja
# missing genre : christmas
# missing genre : motown
# missing genre : choral
# missing genre : harpsichord
# missing genre : abstract beats
# missing genre : kompa
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : fluxwork
# missing genre : fluxwork
# missing genre : footwork
# missing genre : fluxwork
# missing genre : footwork
# missing genre : footwork
# added : dic{thai indie : rock}
# missing genre : dreamo
# missing genre : beatdown
# missing genre : soundtrack
# missing genre : scorecore
# missing genre : soundtrack
# missing genre : pixie
# missing genre : violin
# missing genre : ambeat
# missing genre : fluxwork
# missing genre : gamecore
# missing genre : louvor
# missing genre : schranz
# missing genre : fluxwork
# missing genre : madchester
# missing genre : pixie
# missing genre : aussietronica
# missing genre : norteno
# added : dic{dutch hip hop : hip hop}
# missing genre : boogaloo
# missing genre : ninja
# missing genre : norteno
# missing genre : remix
# missing genre : comic
# missing genre : redneck
# missing genre : deathgrind
# missing genre : comic
# missing genre : didgeridoo
# missing genre : lilith
# missing genre : christmas
# missing genre : broadway
# missing genre : hollywood
# missing genre : fluxwork
# missing genre : ebm
# missing genre : preverb
# missing genre : christmas
# missing genre : electrofox
# missing genre : indiecoustica
# missing genre : fluxwork
# missing genre : hauntology
# missing genre : mandible
# missing genre : epicore
# missing genre : strut
# missing genre : cantautor
# missing genre : consort
# missing genre : harpsichord
# missing genre : scorecore
# missing genre : christmas
# missing genre : anthem worship
# missing genre : worship
# missing genre : soundtrack
# missing genre : footwork
# missing genre : fluxwork
# missing genre : mandible
# missing genre : ninja
# missing genre : ebm
# missing genre : violin
# missing genre : ninja
# missing genre : beatdown
# missing genre : laboratorio
# missing genre : ninja
# missing genre : norteno
# missing genre : zeuhl
# missing genre : opm
# missing genre : manele
# added : dic{nu electro : electronic}
# missing genre : vocaloid
# added : dic{deep rai : jazz}
# missing genre : abstract
# missing genre : broadway
# missing genre : hollywood
# missing genre : ninja
# missing genre : healing
# missing genre : kirtan
# missing genre : meditation
# missing genre : mandible
# missing genre : fluxwork
# missing genre : mandible
# missing genre : fluxwork
# missing genre : mandible
# missing genre : mandible
# missing genre : mandible
# missing genre : mandible
# missing genre : mandible
# missing genre : mandible
# missing genre : hauntology
# added : dic{deep hardcore punk : rock}
# missing genre : fluxwork
# missing genre : mandible
# added : dic{indie emo rock : rock}
# Dictionnary of genre saved.

# %%
dictionnaryOfGenres = LU.loadDictionary("FullData/AllGenresDic",enc="utf-8")
dictionnaryOfGenres

print
# Out:
# {'contemporary classical': 'orchestral',
#  'power violence': 'rock',
#  'brass band': 'jazz',
#  'post-grunge': 'rock',
#  'electro latino': 'latin',
#  'skweee': 'electronic',
#  'indie poptimism': 'pop',
#  'folk pop': 'pop',
#  'deep new wave': 'electronic',
#  'noise rock': 'rock',
#  'operatic pop': 'pop',
#  'glam metal': 'rock',
#  'nu-funk': 'electronic',
#  'latin alternative': 'latin',
#  'genge': 'african',
#  'anthem emo': 'rock',
#  'native american': 'folk',
#  'deep classical piano': 'orchestral',
#  'deep latin hip hop': 'hip hop',
#  'canterbury scene': 'rock',
#  'p-funk': 'r&b and soul',
#  'swedish punk': 'rock',
#  'worldbeat': 'rock',
#  'nu-disco': 'electronic',
#  'isicathamiya': 'african',
#  'vapor house': 'electronic',
#  'hungarian pop': 'pop',
#  'st. louis blues': 'blues',
#  'jazz-funk': 'jazz',
#  'modern southern rock': 'rock',
#  'brazilian': 'latin',
#  'electro music': 'hip hop',
#  'progressive folk': 'folk',
#  'stoner rock': 'rock',
#  'kwela': 'african',
#  'k-hop': 'hip hop',
#  'deep funk carioca': 'latin',
#  'brutal death metal': 'rock',
#  'dream pop': 'rock',
#  'australian pop': 'pop',
#  'deep uplifting trance': 'electronic',
#  'screamo punk': 'rock',
#  "jerkin'": 'hip hop',
#  'outsider house': 'electronic',
#  'punk': 'rock',
#  'electro trash': 'electronic',
#  'conscious hip hop': 'hip hop',
#  'stoner metal': 'rock',
#  'neue deutsche harte': 'rock',
#  'j-punk': 'rock',
#  'traditional swing': 'jazz',
#  'desert rock': 'rock',
#  'drumfunk': 'r&b and soul',
#  'african': 'african',
#  'stomp and whittle': 'jazz',
#  'cha cha cha': 'caribbean and caribbean-influenced',
#  'underground power pop': 'pop',
#  'trip hop (or bristol sound)': 'hip hop',
#  'african rock': 'rock',
#  'musique concrete': 'electronic',
#  'mexican rock-and-roll': 'rock',
#  'folk metal': 'rock',
#  'etherpop': 'pop',
#  'early music': 'avant-garde',
#  'polish pop': 'pop',
#  'instrumental hip hop': 'hip hop',
#  'mbaqanga': 'african',
#  'deep darkpsy': 'r&b and soul',
#  'deep ccm': 'r&b and soul',
#  'depressive black metal': 'rock',
#  'dutch pop': 'pop',
#  'swedish eurodance': 'electronic',
#  'classical period': 'orchestral',
#  'psychedelic rock': 'rock',
#  'makossa': 'african',
#  'electronic rock': 'rock',
#  'nerdcore': 'hip hop',
#  'deep swedish hip hop': 'hip hop',
#  'blue-eyed soul': 'r&b and soul',
#  'italian pop': 'pop',
#  'technical brutal death metal': 'rock',
#  'swedish hard rock': 'rock',
#  'deep turkish pop': 'pop',
#  'british blues': 'blues',
#  'neue deutsche härte': 'rock',
#  'samba': 'latin',
#  'j-reggae': 'hip hop',
#  'swedish indie rock': 'rock',
#  'chip hop': 'hip hop',
#  'neo classical metal': 'rock',
#  'icelandic pop': 'pop',
#  'psychobilly/punkabilly': 'country',
#  'deep orchestral': 'orchestral',
#  'stomp and holler': 'jazz',
#  'freakbeat': 'rock',
#  'sertanejo': 'country',
#  'nz indie': 'rock',
#  'deep underground hip hop': 'hip hop',
#  'nu-nrg': 'electronic',
#  'twee pop': 'pop',
#  'czech folk': 'folk',
#  'austrian hip hop': 'hip hop',
#  'free jazz': 'jazz',
#  'acid house': 'electronic',
#  'finnish metal': 'rock',
#  'hard glam': 'rock',
#  'deep latin christian': 'rock',
#  'deep jazz fusion': 'jazz',
#  'smooth jazz': 'jazz',
#  'psychedelic pop': 'pop',
#  'jersey club': 'electronic',
#  'brazilian rock': 'latin',
#  'apala': 'african',
#  'chilean rock': 'rock',
#  'balearic beat': 'electronic',
#  'deep liquid': 'electronic',
#  'breakbeat hardcore': 'electronic',
#  'german oi': 'electronic',
#  'australian dance': 'electronic',
#  'french movie tunes': 'country',
#  'jazz brass': 'jazz',
#  'persian pop': 'pop',
#  'ambient psychill': 'electronic',
#  'puerto rican rock': 'rock',
#  'powerviolence': 'rock',
#  'viking metal': 'rock',
#  'zydeco': 'country',
#  'coupé-décalé': 'african',
#  'highlife': 'african',
#  'brick city club': 'hip hop',
#  'cumbia rap': 'hip hop',
#  'neo-trad metal': 'rock',
#  'acousmatic': 'electronic',
#  'tekno': 'electronic',
#  'folk punk': 'rock',
#  'anarcho-punk': 'rock',
#  'hardcore': 'electronic',
#  'dansband music': 'country',
#  'dubsteppe': 'electronic',
#  'truck-driving country': 'country',
#  'khaliji': 'asian',
#  'classical performance': 'orchestral',
#  'nitzhonot': 'electronic',
#  'celtic': 'folk',
#  'roots rock': 'rock',
#  'swedish jazz': 'jazz',
#  'americana': 'country',
#  'indie dream pop': 'pop',
#  "children's music": 'avant-garde',
#  'hungarian hip hop': 'hip hop',
#  'ska revival': 'folk',
#  'electro bailando': 'asian',
#  'classic funk rock': 'rock',
#  'argentine reggae': 'hip hop',
#  '2-step garage': 'electronic',
#  'country blues': 'blues',
#  'folk rock': 'rock',
#  'movie tunes': 'country',
#  'electro jazz': 'jazz',
#  'deep neo-synthpop': 'pop',
#  'jangle pop': 'pop',
#  'sleaze rock': 'rock',
#  'cuban rumba': 'latin',
#  'brazilian hip hop': 'hip hop',
#  'ambient dub techno': 'electronic',
#  'deep thrash metal': 'rock',
#  'pinoy pop': 'asian',
#  'bhangra': 'asian',
#  'country pop': 'pop',
#  'turkish rock': 'rock',
#  'dark progressive house': 'electronic',
#  'alt-indie rock': 'rock',
#  "death 'n' roll": 'rock',
#  'crunk': 'hip hop',
#  'punk christmas': 'rock',
#  'comedy': 'comedy',
#  'lyrical hip hop': 'hip hop',
#  'big beat': 'electronic',
#  'bounce': 'hip hop',
#  'neo soul': 'r&b and soul',
#  'christian christmas': 'rock',
#  'australian alternative rock': 'rock',
#  'indie rockism': 'rock',
#  'popgaze': 'pop',
#  'west coast hip hop': 'hip hop',
#  'chanson': 'pop',
#  'indie r&b': 'r&b and soul',
#  'horror punk': 'rock',
#  'dunedin sound': 'rock',
#  'indie anthem-folk': 'folk',
#  'traditional:': 'latin',
#  'kuduro': 'african',
#  'free funk': 'jazz',
#  'alternative emo': 'rock',
#  'freestyle rap': 'hip hop',
#  'igbo highlife': 'african',
#  'pub rock': 'rock',
#  'happy hardcore': 'electronic',
#  'minimal dub': 'electronic',
#  'chicha': 'latin',
#  'chaotic hardcore': 'electronic',
#  'dance-punk': 'electronic',
#  'mathcore': 'rock',
#  'vaporwave': 'electronic',
#  'country': 'country',
#  'deep indie r&b': 'r&b and soul',
#  'swedish folk pop': 'pop',
#  'memphis blues': 'blues',
#  'alternative country': 'country',
#  'traditional country music': 'country',
#  'salsa romántica': 'latin',
#  'welsh rock': 'rock',
#  'acid rock': 'rock',
#  'martial industrial': 'hip hop',
#  'deep symphonic black metal': 'rock',
#  'drone': 'rock',
#  'kraut rock': 'rock',
#  'música criolla': 'latin',
#  'afro-cuban jazz': 'latin',
#  'spanish folk': 'folk',
#  'kapuka aka boomba': 'african',
#  'chamber choir': 'jazz',
#  'ethereal wave': 'electronic',
#  'no wave': 'rock',
#  'zouk-lambada': 'latin',
#  'post-disco': 'r&b and soul',
#  'tropical house': 'electronic',
#  'morlam': 'asian',
#  'classic country': 'country',
#  'folklore argentino': 'folk',
#  'dance pop': 'pop',
#  'future garage': 'electronic',
#  'speedcore': 'electronic',
#  'piano blues': 'blues',
#  'dutch house': 'electronic',
#  'turntablism': 'hip hop',
#  'melodic power metal': 'rock',
#  'spanish noise pop': 'pop',
#  'italian metal': 'rock',
#  'portuguese rock': 'rock',
#  'thrash-groove metal': 'rock',
#  'deep progressive trance': 'electronic',
#  'polish hip hop': 'hip hop',
#  'alternative metal': 'rock',
#  'cryptic black metal': 'rock',
#  'neo-industrial rock': 'rock',
#  'punk ska': 'rock',
#  'deep canadian indie': 'rock',
#  'german pop': 'pop',
#  'zouglou': 'african',
#  'belgian rock': 'rock',
#  'deep new americana': 'country',
#  'deep latin jazz': 'jazz',
#  'sung poetry': 'folk',
#  'swedish reggae': 'hip hop',
#  'deep christian rock': 'rock',
#  'columbus ohio indie': 'rock',
#  'irish folk': 'folk',
#  'athens indie': 'rock',
#  'rara tech': 'electronic',
#  'r&b': 'r&b and soul',
#  'flamenco': 'latin',
#  'uk funky': 'electronic',
#  'post-doom metal': 'rock',
#  'bulgarian folk': 'folk',
#  'japanese psychedelic': 'folk',
#  'jump up': 'latin',
#  'power metal': 'rock',
#  'dubtronica': 'electronic',
#  'string band': 'jazz',
#  'houston hip hop': 'hip hop',
#  'grave wave': 'electronic',
#  'neotraditional country': 'country',
#  'soul jazz': 'jazz',
#  'dancehall music': 'caribbean and caribbean-influenced',
#  'punk blues': 'blues',
#  'rap opera': 'hip hop',
#  'chamber jazz': 'jazz',
#  'spanish pop': 'pop',
#  'finnish jazz': 'jazz',
#  'outsider': 'electronic',
#  'indian rock': 'rock',
#  'boogie-woogie': 'jazz',
#  'compas': 'caribbean and caribbean-influenced',
#  'corsican folk': 'folk',
#  'classical flute': 'orchestral',
#  'indie punk': 'rock',
#  'german pop rock': 'rock',
#  'pagode': 'latin',
#  'latin metal': 'rock',
#  'korean pop': 'pop',
#  'industrial music': 'electronic',
#  'soca': 'caribbean and caribbean-influenced',
#  'stride jazz': 'jazz',
#  'raga rock': 'rock',
#  'neofolk': 'folk',
#  'downtempo fusion': 'jazz',
#  'chicano rap': 'hip hop',
#  'pinoy alternative': 'rock',
#  'deep minimal techno': 'electronic',
#  'flick hop': 'hip hop',
#  'country gospel': 'blues',
#  'teen pop': 'pop',
#  'hip house': 'hip hop',
#  'trapstep': 'electronic',
#  'screamo': 'rock',
#  'eurodance': 'electronic',
#  'soft rock': 'rock',
#  'luk krung': 'asian',
#  'mexican indie': 'rock',
#  'hip hop': 'hip hop',
#  'orquesta tropical': 'latin',
#  'country christmas': 'country',
#  'breakstep': 'electronic',
#  'lambada': 'latin',
#  'punk rock': 'rock',
#  'electronicore': 'rock',
#  'deep string quartet': 'r&b and soul',
#  'finnish pop': 'pop',
#  'classic afrobeat': 'african',
#  'breton folk': 'folk',
#  'soul': 'r&b and soul',
#  'jùjú': 'african',
#  'greek house': 'electronic',
#  'sufi rock': 'rock',
#  'm-base': 'jazz',
#  'northern soul': 'r&b and soul',
#  'country dawn': 'country',
#  'avant-garde jazz': 'jazz',
#  'slovak pop': 'pop',
#  'folk christmas': 'folk',
#  'bouyon': 'caribbean and caribbean-influenced',
#  'dangdut': 'asian',
#  'persian traditional': 'pop',
#  'math rock': 'rock',
#  'rock': 'rock',
#  'comedy rock': 'comedy',
#  'deep opera': 'hip hop',
#  'enka': 'asian',
#  'visual kei': 'rock',
#  'acoustic pop': 'pop',
#  'anison': 'asian',
#  'lounge music': 'easy listening',
#  'funkstep': 'electronic',
#  'new orleans blues': 'blues',
#  'deep german hip hop': 'hip hop',
#  'mbalax': 'african',
#  'edm': 'blues',
#  'spanish indie pop': 'pop',
#  'balearic trance': 'electronic',
#  'electro-industrial': 'electronic',
#  'a cappella': 'hip hop',
#  'swedish hip hop': 'hip hop',
#  'underground pop rap': 'hip hop',
#  'baroque': 'pop',
#  'new wave': 'rock',
#  'country rock': 'country',
#  'show tunes': 'country',
#  'antiviral pop': 'pop',
#  'europop': 'pop',
#  'modern classical': 'orchestral',
#  'timba': 'latin',
#  'atmospheric post rock': 'rock',
#  'nu skool breaks': 'electronic',
#  'kwaito house': 'electronic',
#  'french folk pop': 'pop',
#  'laptronica': 'electronic',
#  'new beat': 'electronic',
#  'manila sound': 'asian',
#  'classical guitar': 'orchestral',
#  'british dance band': 'jazz',
#  'microhouse/minimal house': 'electronic',
#  'west coast jazz': 'jazz',
#  'surf music': 'avant-garde',
#  'west coast rap': 'hip hop',
#  'rock en español': 'latin',
#  'classic swedish pop': 'pop',
#  'celtic punk': 'rock',
#  'ska jazz': 'jazz',
#  'boston rock': 'rock',
#  'marrabenta': 'african',
#  'deep indian pop': 'pop',
#  'crust punk': 'rock',
#  'chicago soul': 'r&b and soul',
#  'groove room': 'electronic',
#  'bongo flava': 'hip hop',
#  'southern rock': 'rock',
#  'australian hip hop': 'hip hop',
#  'acid jazz': 'jazz',
#  'compositional ambient': 'electronic',
#  'fast melodic punk': 'rock',
#  'song poem': 'hip hop',
#  'synthwave': 'electronic',
#  'spanish rock': 'rock',
#  'vispop': 'pop',
#  'congolese rumba': 'african',
#  'bay area indie': 'rock',
#  'death core': 'hip hop',
#  'tecno brega': 'electronic',
#  'g-funk': 'hip hop',
#  'experimental psych': 'folk',
#  'urban contemporary': 'pop',
#  'caribbean and caribbean-influenced': 'caribbean and caribbean-influenced',
#  'western swing': 'country',
#  'nortec': 'electronic',
#  'lovers rock': 'rock',
#  'deep pop punk': 'rock',
#  'hyphy': 'hip hop',
#  'turkish hip hop': 'hip hop',
#  'c-pop': 'pop',
#  'industrial': 'hip hop',
#  'euro disco': 'electronic',
#  'reggaeton flow': 'latin',
#  'deep melodic hard rock': 'rock',
#  'step': 'electronic',
#  'avant-garde': 'avant-garde',
#  'thrash core': 'hip hop',
#  'ragtime': 'jazz',
#  'neoclassical': 'rock',
#  'italian disco': 'r&b and soul',
#  'diva house/handbag house': 'electronic',
#  'deep melodic euro house': 'electronic',
#  'classic eurovision': 'orchestral',
#  'moombahton': 'electronic',
#  'crunkcore': 'hip hop',
#  'filk music': 'folk',
#  'hardbag': 'electronic',
#  'rock noise': 'avant-garde',
#  'spanish new wave': 'electronic',
#  'experimental dubstep': 'electronic',
#  'rock gaucho': 'rock',
#  'canzone': 'pop',
#  'world meditation': 'rock',
#  'latin pop': 'pop',
#  'gothic symphonic metal': 'rock',
#  'blues-rock guitar': 'rock',
#  'ghettotech': 'hip hop',
#  'raggacore': 'electronic',
#  'library music': 'avant-garde',
#  'nordic folk': 'folk',
#  'chiptune': 'electronic',
#  'progressive pop': 'pop',
#  'baroque ensemble': 'pop',
#  'uk post-punk': 'rock',
#  'digital hardcore': 'rock',
#  'grim death metal': 'rock',
#  'melodic hardcore': 'electronic',
#  'italian indie pop': 'pop',
#  'german punk': 'rock',
#  'classical': 'orchestral',
#  'folkmusik': 'folk',
#  'electropop': 'pop',
#  'djent': 'rock',
#  'hands up': 'latin',
#  'hokum': 'country',
#  'indie jazz': 'jazz',
#  'electronic trap': 'hip hop',
#  'kiwi rock': 'rock',
#  'german metal': 'rock',
#  'drill': 'hip hop',
#  'tejano': 'latin',
#  'illbient': 'electronic',
#  'pop rap': 'pop',
#  'art punk': 'rock',
#  'game boy music': 'electronic',
#  'romantic': 'pop',
#  'vapor pop': 'pop',
#  'electronic body music': 'electronic',
#  'melodic metalcore': 'rock',
#  'african heavy metal': 'african',
#  'fijiri': 'asian',
#  'pop soul': 'pop',
#  'early music ensemble': 'avant-garde',
#  'classical christmas': 'orchestral',
#  'brega': 'latin',
#  'danish pop': 'pop',
#  'french reggae': 'hip hop',
#  'seggae': 'african',
#  'wonky': 'electronic',
#  'dance-pop': 'pop',
#  'greek indie': 'rock',
#  'classic colombian pop': 'pop',
#  'tech house': 'electronic',
#  'rock-and-roll': 'rock',
#  'black death': 'rock',
#  'deep house': 'electronic',
#  'reggae fusion': 'jazz',
#  'power noise': 'electronic',
#  'nashville sound': 'country',
#  'rock en espanol': 'country',
#  'indian classical': 'orchestral',
#  'samba-enredo': 'latin',
#  'aggrotech': 'electronic',
#  'cajun': 'country',
#  'go-go': 'r&b and soul',
#  'moombahcore': 'electronic',
#  'post rock': 'rock',
#  'vocal house': 'electronic',
#  'vocal jazz': 'jazz',
#  'j-core': 'hip hop',
#  'canción': 'pop',
#  'continental jazz': 'jazz',
#  'swamp blues': 'blues',
#  'mambo': 'latin',
#  'electro dub': 'electronic',
#  'japanese jazztronica': 'jazz',
#  'deep contemporary country': 'country',
#  'pop punk': 'rock',
#  'abstract hip hop': 'hip hop',
#  'kc indie': 'rock',
#  'opera': 'hip hop',
#  'dub techno': 'electronic',
#  'psychedelic trance': 'electronic',
#  'venezuelan rock': 'rock',
#  'black sludge': 'rock',
#  'tracestep': 'electronic',
#  'turkish jazz': 'jazz',
#  'progressive rock': 'rock',
#  'kwaito': 'hip hop',
#  'channel pop': 'pop',
#  'bassline': 'electronic',
#  'metal': 'rock',
#  'danish jazz': 'jazz',
#  'zapstep': 'electronic',
#  'latin house': 'electronic',
#  'deep chill': 'electronic',
#  'neo honky tonk': 'country',
#  'emo punk': 'rock',
#  'musique concrète': 'electronic',
#  'doomcore': 'electronic',
#  'medieval rock': 'rock',
#  'liquid funk': 'electronic',
#  'funky breaks': 'electronic',
#  'palm-wine': 'african',
#  'world chill': 'electronic',
#  'bossa nova': 'latin',
#  'tropicalia': 'latin',
#  'basque rock': 'rock',
#  'medieval metal': 'rock',
#  'math pop': 'pop',
#  'bass music': 'avant-garde',
#  'screamocore': 'rock',
#  'power-pop punk': 'rock',
#  'portland indie': 'rock',
#  'album rock': 'rock',
#  'jumpstyle': 'electronic',
#  'funk metal': 'rock',
#  'polynesian pop': 'pop',
#  'soukous': 'african',
#  'jazz rap': 'jazz',
#  'maracatu': 'latin',
#  'electric blues': 'blues',
#  'retro electro': 'electronic',
#  'italian arena pop': 'pop',
#  'deep euro house': 'electronic',
#  'bitpop': 'electronic',
#  'classic garage rock': 'rock',
#  'brazilian composition': 'latin',
#  'hip hop soul': 'r&b and soul',
#  'ragini': 'asian',
#  'candy pop': 'pop',
#  'bolero': 'latin',
#  'deep psychobilly': 'rock',
#  'rock catala': 'rock',
#  'deep hardcore': 'electronic',
#  'anti-folk': 'folk',
#  'latin rock': 'latin',
#  'trap francais': 'hip hop',
#  'suomi rock': 'rock',
#  'contemporary folk': 'folk',
#  'old school hip hop': 'hip hop',
#  'nordic house': 'electronic',
#  'progressive uplifting trance': 'electronic',
#  'urban pasifika': 'hip hop',
#  'post-post-hardcore': 'electronic',
#  'riot grrrl': 'rock',
#  'cowboy/western music': 'folk',
#  'argentine rock': 'rock',
#  'traditional british folk': 'folk',
#  'dancehall': 'caribbean and caribbean-influenced',
#  'trance': 'electronic',
#  'deep delta blues': 'blues',
#  'deep deep house': 'electronic',
#  'gothic rock': 'rock',
#  'canadian indie': 'rock',
#  'catstep': 'electronic',
#  'industrial folk': 'folk',
#  'tin pan alley': 'electronic',
#  'cumbia': 'latin',
#  'adult contemporary': 'pop',
#  'latin jazz': 'latin',
#  're:techno': 'electronic',
#  'christian uplift': 'electronic',
#  'house music': 'electronic',
#  'classic danish pop': 'pop',
#  'indie fuzzpop': 'pop',
#  'deep tech house': 'electronic',
#  'technical death metal': 'rock',
#  'symphonic metal': 'rock',
#  'christian relaxative': 'rock',
#  'classic russian rock': 'rock',
#  'dark jazz': 'jazz',
#  'neo-rockabilly': 'country',
#  'abstract idm': 'electronic',
#  'thai pop': 'asian',
#  'slavic metal': 'rock',
#  'german show tunes': 'country',
#  'drone folk': 'folk',
#  'deep hardcore punk': 'rock',
#  'power electronics': 'electronic',
#  'escape room': 'electronic',
#  'indonesian pop': 'pop',
#  'yugoslav rock': 'rock',
#  'british alternative rock': 'rock',
#  'bachata': 'latin',
#  'norwegian indie': 'rock',
#  'post-teen pop': 'pop',
#  'orchestral jazz': 'jazz',
#  'merengue': 'latin',
#  'greek hip hop': 'hip hop',
#  'guajira': 'latin',
#  'albanian pop': 'pop',
#  'k-pop': 'pop',
#  'soul christmas': 'r&b and soul',
#  'trap music': 'avant-garde',
#  'pipe band': 'jazz',
#  'neo-bop jazz': 'jazz',
#  'sertanejo tradicional': 'country',
#  'irish indie': 'rock',
#  'funktronica': 'electronic',
#  'louisiana blues': 'blues',
#  'ska punk': 'rock',
#  'michigan indie': 'rock',
#  'original pilipino music': 'asian',
#  'deep eurodance': 'electronic',
#  'gothic post-punk': 'rock',
#  'rapcore': 'rock',
#  'jig and reel': 'jazz',
#  'asian american jazz': 'jazz',
#  'zouk riddim': 'latin',
#  'protest song': 'folk',
#  'sambass': 'electronic',
#  'ethno jazz': 'jazz',
#  'chamber psych': 'folk',
#  'jazz orchestra': 'jazz',
#  'tone': 'rock',
#  'space disco': 'electronic',
#  'mafioso rap': 'hip hop',
#  'post-rock': 'rock',
#  'singer-songwriter': 'folk',
#  'british hip hop': 'hip hop',
#  'complextro': 'electronic',
#  'estonian pop': 'pop',
#  'tropipop': 'latin',
#  'delta blues': 'blues',
#  'deathrock': 'rock',
#  'street punk': 'rock',
#  'black metal': 'rock',
#  'traditional ska': 'rock',
#  'noise pop': 'pop',
#  'electro swing': 'electronic',
#  'deep comedy': 'comedy',
#  'indie garage rock': 'rock',
#  'florida breaks': 'electronic',
#  'jazz fusion': 'jazz',
#  'psych gaze': 'rock',
#  'gothic americana': 'country',
#  'alternative roots rock': 'rock',
#  'indietronica': 'electronic',
#  'poetry': 'folk',
#  'dark electro-industrial': 'hip hop',
#  'metal guitar': 'rock',
#  'minimal melodic techno': 'electronic',
#  'beat music': 'rock',
#  'atlanta hip hop': 'hip hop',
#  'west coast trap': 'hip hop',
#  "traditional rock 'n roll": 'rock',
#  'industrial rock': 'rock',
#  'paisley underground': 'rock',
#  'reggaeton': 'latin',
#  'ragga jungle': 'electronic',
#  'glitch beats': 'electronic',
#  'christian rock': 'rock',
#  'progressive trance': 'electronic',
#  'war metal': 'rock',
#  'traditional funk': 'r&b and soul',
#  'iranian pop': 'pop',
#  'snap music': 'hip hop',
#  'thai indie': 'rock',
#  'liwa': 'asian',
#  'arab folk': 'folk',
#  'coldwave': 'electronic',
#  'new school hip hop': 'hip hop',
#  'gypsy punk': 'rock',
#  'gauze pop': 'pop',
#  'latin swing': 'latin',
#  'full on': 'electronic',
#  'alternative hardcore': 'electronic',
#  'canadian blues': 'blues',
#  'minimal dubstep': 'electronic',
#  'spanish punk': 'rock',
#  'jazz trio': 'jazz',
#  'sheffield indie': 'rock',
#  'funk carioca': 'latin',
#  'malagasy folk': 'folk',
#  'crustgrind': 'rock',
#  'sludge metal': 'rock',
#  'shimmer psych': 'folk',
#  'vegan straight edge': 'jazz',
#  'pop rock': 'rock',
#  'underground rap': 'hip hop',
#  'blues rock': 'blues',
#  'gypsy jazz': 'jazz',
#  'industrial metal': 'rock',
#  'raï': 'african',
#  'deep downtempo fusion': 'jazz',
#  'chicago indie': 'rock',
#  'j-pop': 'pop',
#  'slow core': 'hip hop',
#  'latin electronica': 'electronic',
#  'franco-country': 'country',
#  'armenian folk': 'folk',
#  'celtic christmas': 'folk',
#  'glitch hop': 'electronic',
#  'japanoise': 'electronic',
#  'new prog': 'rock',
#  'furniture music': 'easy listening',
#  'british folk revival': 'folk',
#  'instrumental country': 'country',
#  'roots reggae': 'hip hop',
#  'drone psych': 'folk',
#  'nu electro': 'electronic',
#  'slam death metal': 'rock',
#  'irish rock': 'rock',
#  'industrial hip hop': 'hip hop',
#  'asian underground': 'electronic',
#  'deep indie singer-songwriter': 'folk',
#  'deep trap': 'hip hop',
#  'swedish pop': 'pop',
#  'deep psytrance': 'r&b and soul',
#  'finnish indie': 'rock',
#  'folk': 'folk',
#  'forró': 'latin',
#  'deep power-pop punk': 'rock',
#  'hard alternative': 'rock',
#  'acoustic blues': 'blues',
#  'rock steady': 'rock',
#  'unblack metal': 'rock',
#  'neo-progressive': 'electronic',
#  'hard minimal techno': 'electronic',
#  'semba': 'african',
#  'norwegian rock': 'rock',
#  'cajun fiddle tunes': 'country',
#  'swiss rock': 'rock',
#  'swedish pop punk': 'rock',
#  'electro house': 'electronic',
#  'electronica': 'electronic',
#  'glitch': 'electronic',
#  'turkish pop': 'pop',
#  'cadence-lypso': 'caribbean and caribbean-influenced',
#  'deep southern trap': 'hip hop',
#  'christian country music': 'country',
#  'darkstep': 'electronic',
#  'hokum blues': 'blues',
#  'ranchera': 'latin',
#  'deep pop edm': 'blues',
#  'african percussion': 'african',
#  'alternative hip hop': 'hip hop',
#  'bebop': 'jazz',
#  'nu gaze': 'rock',
#  'funk rock': 'rock',
#  'bikutsi': 'african',
#  'acousmatic music': 'electronic',
#  'german street punk': 'rock',
#  'old-time': 'jazz',
#  'atmospheric black metal': 'rock',
#  'chicago house': 'electronic',
#  'electro': 'electronic',
#  'kizomba': 'african',
#  'samba rock': 'latin',
#  'lounge': 'easy listening',
#  'swedish alternative rock': 'rock',
#  'indie pop': 'pop',
#  'house': 'electronic',
#  'gangster rap': 'hip hop',
#  'chinese traditional': 'pop',
#  'freak folk': 'folk',
#  'nl folk': 'folk',
#  'deep folk metal': 'rock',
#  'outlaw country': 'country',
#  'minimal tech house': 'electronic',
#  'east coast hip hop': 'hip hop',
#  'j-ambient': 'electronic',
#  'funky tech house': 'electronic',
#  'ghetto house': 'hip hop',
#  'doo-wop': 'electronic',
#  'minimal': 'electronic',
#  'world worship': 'rock',
#  'british brass band': 'jazz',
#  'indie emo rock': 'rock',
#  'rockabilly': 'country',
#  'classic': 'orchestral',
#  'livetronica': 'jazz',
#  'hindustani classical': 'orchestral',
#  'progressive country': 'country',
#  'vegas indie': 'rock',
#  'new-age music': 'electronic',
#  'finnish hardcore': 'electronic',
#  'hard rock': 'rock',
#  'canzone napoletana': 'pop',
#  'garage pop': 'pop',
#  'j-rock': 'asian',
#  'vapor soul': 'r&b and soul',
#  'chap hop': 'hip hop',
#  'isolationism': 'electronic',
#  'classical organ': 'orchestral',
#  'romanian pop': 'pop',
#  'close harmony': 'country',
#  'gangsta rap': 'hip hop',
#  'hi-nrg': 'electronic',
#  'latin': 'latin',
#  'doom metal': 'rock',
#  'shangaan electro': 'african',
#  'hardcore techno': 'electronic',
#  'hip pop': 'hip hop',
#  'danish indie': 'rock',
#  'underground hip hop': 'hip hop',
#  'trap': 'hip hop',
#  'college a cappella': 'hip hop',
#  'jam band': 'jazz',
#  'beautiful music': 'easy listening',
#  'deep melodic death metal': 'rock',
#  'mbube': 'african',
#  'trad jazz': 'jazz',
#  'punk jazz': 'jazz',
#  'spanish pop rock': 'rock',
#  'chopped and screwed': 'hip hop',
#  'deep danish pop': 'pop',
#  'shibuya-kei': 'jazz',
#  'cowpunk': 'rock',
#  'new romantic': 'pop',
#  'northern irish indie': 'rock',
#  'deep space rock': 'rock',
#  'louisiana swamp pop': 'pop',
#  'brazilian punk': 'rock',
#  'vocal trance': 'electronic',
#  'italian punk': 'rock',
#  'norteño': 'latin',
#  'swedish metal': 'rock',
#  'garage punk blues': 'blues',
#  'hard house': 'electronic',
#  'noise punk': 'rock',
#  'bass trip': 'electronic',
#  'rhythm and blues': 'r&b and soul',
#  'deathcore': 'rock',
#  'new jack swing': 'r&b and soul',
#  'onkyokei': 'asian',
#  'christian music': 'avant-garde',
#  'indonesian indie': 'rock',
#  'modern country rock': 'rock',
#  'schlager': 'pop',
#  'video game music': 'electronic',
#  'trival': 'electronic',
#  'gothic metal': 'rock',
#  'fourth world': 'rock',
#  'merenrap': 'hip hop',
#  'novelty music': 'comedy',
#  'melbourne bounce': 'electronic',
#  'japanese city pop': 'pop',
#  'freestyle music': 'r&b and soul',
#  'glam rock': 'rock',
#  'detroit hip hop': 'hip hop',
#  'mákina': 'electronic',
#  'turkish classical': 'orchestral',
#  'dubstyle': 'electronic',
#  'grunge pop': 'pop',
#  'speed metal': 'rock',
#  'italian folk': 'folk',
#  'sunset lounge': 'easy listening',
#  'hardcore breaks': 'electronic',
#  'hill country blues': 'blues',
#  'trance music': 'electronic',
#  'bullerengue': 'latin',
#  'dirty texas rap': 'hip hop',
#  'surf pop': 'pop',
#  'comedy music': 'comedy',
#  'thrash metal': 'rock',
#  'tropical': 'latin',
#  'igbo rap': 'hip hop',
#  'dansband': 'country',
#  'rap metalcore': 'rock',
#  'argentine indie': 'rock',
#  'cool jazz': 'jazz',
#  'deep surf music': 'avant-garde',
#  'christian hip hop': 'hip hop',
#  'rap': 'hip hop',
#  'medieval': 'rock',
#  'j-metal': 'rock',
#  'krautrock': 'rock',
#  'new rave': 'electronic',
#  'jump blues': 'blues',
#  'dark black metal': 'rock',
#  'slow game': 'electronic',
#  'slowcore': 'rock',
#  'third stream': 'jazz',
#  'surf rock': 'rock',
#  'experimental hip hop': 'hip hop',
#  'new tribe': 'rock',
#  'italo disco': 'pop',
#  'post-metal': 'rock',
#  'sophisti-pop': 'pop',
#  'alternative pop': 'pop',
#  'goregrind': 'rock',
#  'contemporary post-bop': 'jazz',
#  'motswako': 'hip hop',
#  'discofox': 'r&b and soul',
#  'space rock': 'rock',
#  'neue deutsche welle': 'rock',
#  'downtempo': 'electronic',
#  'soul blues': 'blues',
#  'broken beat': 'electronic',
#  'cumbia pop': 'pop',
#  'avant-garde metal': 'rock',
#  'classic icelandic pop': 'pop',
#  'neurostep': 'electronic',
#  'electroacoustic improvisation': 'jazz',
#  'son': 'latin',
#  'kadongo kamu': 'african',
#  'west coast blues': 'blues',
#  'grindie': 'electronic',
#  'novelty ragtime': 'jazz',
#  'brill building pop': 'pop',
#  'garage house': 'electronic',
#  'suomisaundi': 'electronic',
#  'dark wave': 'electronic',
#  'blues': 'blues',
#  'brazilian indie': 'rock',
#  'mexican son': 'latin',
#  'cinematic dubstep': 'electronic',
#  'float house': 'electronic',
#  'axé': 'latin',
#  'canadian metal': 'rock',
#  'canadian pop': 'pop',
#  'classic female blues': 'blues',
#  'french hip hop': 'hip hop',
#  'ethiopian pop': 'pop',
#  'deep smooth jazz': 'jazz',
#  'deep swedish indie pop': 'pop',
#  'jungle': 'electronic',
#  'vienna indie': 'rock',
#  'big room': 'electronic',
#  'outer hip hop': 'hip hop',
#  'deep discofox': 'r&b and soul',
#  'nu jazz': 'jazz',
#  'nu-cumbia': 'latin',
#  'deep rai': 'jazz',
#  'european free jazz': 'jazz',
#  'malaysian pop': 'pop',
#  'deep tropical house': 'electronic',
#  'zouk': 'latin',
#  'easy listening': 'easy listening',
#  'stomp and flutter': 'jazz',
#  'mexican traditional': 'pop',
#  'bassline/4x4 garage': 'electronic',
#  'turkish folk': 'folk',
#  'ska': 'rock',
#  'banda': 'latin',
#  'ambient': 'electronic',
#  'russian rock': 'rock',
#  'new jersey hip hop': 'hip hop',
#  'experimental': 'avant-garde',
#  'swedish prog': 'rock',
#  'deep brazilian pop': 'pop',
#  'deep german punk': 'rock',
#  'deep cumbia sonidera': 'latin',
#  'pop reggaeton': 'latin',
#  'lento violento': 'electronic',
#  'scottish rock': 'rock',
#  'deep cello': 'r&b and soul',
#  'frevo': 'latin',
#  'detroit blues': 'blues',
#  'vapor twitch': 'electronic',
#  'progressive bluegrass': 'country',
#  'dwn trap': 'hip hop',
#  'australian indie': 'rock',
#  'christian alternative rock': 'rock',
#  'oi': 'electronic',
#  'deep australian indie': 'rock',
#  'slc indie': 'rock',
#  'italo dance': 'pop',
#  'idm': 'electronic',
#  'country road': 'easy listening',
#  'elevator music': 'easy listening',
#  'neo-singer-songwriter': 'folk',
#  'melodic hard rock': 'rock',
#  'skinhead oi': 'electronic',
#  'russian hip hop': 'hip hop',
#  'art rock': 'rock',
#  'crossover jazz': 'jazz',
#  'ambient idm': 'electronic',
#  ...}

# %%
def downloadGenresWikipedia(str_file,dictionnary,begin=0,end=100000):

    Artists = pd.read_csv(str_file,index_col=0)
    
    if(end>Artists.shape[0]):
        end = Artists.shape[0]
    
    path = "FullData/ArtistDataframe_"+str(begin)+"_"+str(end)+".csv"
    print("Downloading genres of "+str(end-begin)+" artist...")
    last_read = 0
    for i in range(begin,end):
        S = Artists[Artists.index==i]
        artist = S["artist"].values[0]
        genres_ra = AE.getGenresFromWikipedia(artist,dictionnary)
        if(len(genres_ra)<1):
            genres_ra = None
        Artists.loc[Artists.index==i,"genres_ra"] = str(genres_ra)

        if(i%300==0):
            Artists.to_csv(path,encoding="utf-8")
            print(str(i)+": Saved under "+path)
    
    Artists.to_csv(path,encoding="utf-8")
    
    print(str(i)+": Saved under "+path)
    last_read = i

    print("Last read = "+str(last_read))
    return Artists

# %%
import requests
import bs4

Artist = "Noisia"

def getGenresFromWikipedia(Artist,dic=None):
    #print("Extract from RA")
    artist = Artist.replace(" ","_")
    URL = "https://fr.wikipedia.org/wiki/"+artist
    print(URL)
    content = requests.get(URL).text
    
    soup = bs4.BeautifulSoup(content, "html5lib")   
    #print(content)
    listGenre = []
    for art in soup.findAll("a"):
        text = art.text
        if(dic==None):
            dic=createDictionnary()
            
        for genre in dic:
            if(genre in text):
                listGenre.append(genre)
    return set(listGenre)

# %%
getGenresFromWikipedia("Tiesto",dictionnaryOfGenres)
# Out:
# https://fr.wikipedia.org/wiki/Tiesto
# {'acid house',
#  'disco',
#  'electro',
#  'emo',
#  'future house',
#  'hardcore',
#  'house',
#  'latin',
#  'new beat',
#  'oi',
#  'rai',
#  'rap',
#  'ska',
#  'son',
#  'tone',
#  'trance'}

# %%
a = downloadGenresRA("FullData/ArtistDataframe.csv",dictionnaryOfGenres,0,30)
a
# Out:
# Downloading genres of 30 artist...
# 0: Saved under FullData/ArtistDataframe_0_30.csv
# 29: Saved under FullData/ArtistDataframe_0_30.csv
# Last read = 29
#                          artist  \
# 0              Andy Gruber Band
# 1                    DJ Raykard
# 2                 Martin Sander
# 3               Bernhard Hörler
# 4                         Oomph
# 5                    Plusmacher
# 6         Konstantin Scherbakov
# 7                  The Bosshoss
# 8              The Sore Loosers
# 9                  Viper Sniper
# 10            T. S. Monk Sextet
# 11            Markus Brönnimann
# 12             Barbara Tillmann
# 13                Ulrike Jacoby
# 14             Muriel Schweizer
# 15                  Anita Jehli
# 16            Jaël Bertschinger
# 17             Esther Fritzsche
# 18                    Borknagar
# 19                      Kampfar
# 20                   Diabolical
# 21                   Lia Andres
# 22               Debora Büttner
# 23                 Raphael Höhn
# 24                 Tobias Wicky
# 25              Maki Wiederkehr
# 26                Elina Kaykova
# 27              Veronika Eberle
# 28                Kenny Garrett
# 29                Vernell Brown
# ...                         ...
# 45348                    Vessel
# 45349                      Kahn
# 45350                      Neek
# 45351    El Kid and Ishan Sound
# 45352                   incite/
# 45353                   Actress
# 45354                   + more.
# 45355                  DJ Hachi
# 45356           Garçon & Morard
# 45357                  Sexbeach
# 45358        Homopatik - Japan)
# 45359               Shingo Suwa
# 45360                Akirahawks
# 45361           Merkur - Japan)
# 45362            SENSE - Basel)
# 45363                   P.A.S.K
# 45364                     Salar
# 45365                Christo...
# 45366        Scrap & Jimi Jules
# 45367  Stereo Riders & DJ Big B
# 45368    DJ Tonic & DJ Tremendo
# 45369                    Daitan
# 45370                   Dottore
# 45371                     Goyav
# 45372                       WÆV
# 45373              PleasureLab)
# 45374             CMYKollektiv)
# 45375                   Stavros
# 45376                 Carlos Jr
# 45377            Apples & Pears
#
#                                           genres_spotify genres_ra  \
# 0                                                   None      None
# 1                                                   None      None
# 2                                                   None      None
# 3                                                   None      None
# 4      ['german metal', 'industrial metal', 'industri...      None
# 5              ['deep german hip hop', 'german hip hop']      None
# 6                   ['classical piano', 'concert piano']      None
# 7             ['comic', 'german pop', 'german pop rock']      None
# 8                                                   None      None
# 9                                                   None      None
# 10                                                  None      None
# 11                                                  None      None
# 12                                                  None      None
# 13                                                  None      None
# 14                                                  None      None
# 15                                                  None      None
# 16                                                  None      None
# 17                                                  None      None
# 18     ['atmospheric black metal', 'avantgarde metal'...      None
# 19     ['atmospheric black metal', 'avantgarde metal'...      None
# 20                                                  None      None
# 21                                                  None      None
# 22                                                  None      None
# 23                                                  None      None
# 24                                                  None      None
# 25                                                  None      None
# 26                                                  None      None
# 27                                                  None      None
# 28     ['bebop', 'contemporary jazz', 'contemporary p...      None
# 29                                                  None      None
# ...                                                  ...       ...
# 45348   ['deep indie r&b', 'vapor soul', 'vapor twitch']       NaN
# 45349                                               None       NaN
# 45350                                               None       NaN
# 45351                                               None       NaN
# 45352            ['groove metal', 'thrash-groove metal']       NaN
# 45353  ['alternative dance', 'brooklyn indie', 'chill...       NaN
# 45354  ['alternative metal', 'nu metal', 'post-grunge...       NaN
# 45355                                               None       NaN
# 45356                                               None       NaN
# 45357                                               None       NaN
# 45358                                               None       NaN
# 45359                                               None       NaN
# 45360                                               None       NaN
# 45361                                               None       NaN
# 45362                                               None       NaN
# 45363                                               None       NaN
# 45364             ['persian pop', 'persian traditional']       NaN
# 45365                                               None       NaN
# 45366                                               None       NaN
# 45367                                               None       NaN
# 45368                                               None       NaN
# 45369                                               None       NaN
# 45370                                               None       NaN
# 45371                                               None       NaN
# 45372                                               None       NaN
# 45373                                               None       NaN
# 45374                                               None       NaN
# 45375                                 ['indie emo rock']       NaN
# 45376                                   ['samba-enredo']       NaN
# 45377                                               None       NaN
#
#        main_genres  top3_genres  genre
# 0              NaN          NaN    NaN
# 1              NaN          NaN    NaN
# 2              NaN          NaN    NaN
# 3              NaN          NaN    NaN
# 4              NaN          NaN    NaN
# 5              NaN          NaN    NaN
# 6              NaN          NaN    NaN
# 7              NaN          NaN    NaN
# 8              NaN          NaN    NaN
# 9              NaN          NaN    NaN
# 10             NaN          NaN    NaN
# 11             NaN          NaN    NaN
# 12             NaN          NaN    NaN
# 13             NaN          NaN    NaN
# 14             NaN          NaN    NaN
# 15             NaN          NaN    NaN
# 16             NaN          NaN    NaN
# 17             NaN          NaN    NaN
# 18             NaN          NaN    NaN
# 19             NaN          NaN    NaN
# 20             NaN          NaN    NaN
# 21             NaN          NaN    NaN
# 22             NaN          NaN    NaN
# 23             NaN          NaN    NaN
# 24             NaN          NaN    NaN
# 25             NaN          NaN    NaN
# 26             NaN          NaN    NaN
# 27             NaN          NaN    NaN
# 28             NaN          NaN    NaN
# 29             NaN          NaN    NaN
# ...            ...          ...    ...
# 45348          NaN          NaN    NaN
# 45349          NaN          NaN    NaN
# 45350          NaN          NaN    NaN
# 45351          NaN          NaN    NaN
# 45352          NaN          NaN    NaN
# 45353          NaN          NaN    NaN
# 45354          NaN          NaN    NaN
# 45355          NaN          NaN    NaN
# 45356          NaN          NaN    NaN
# 45357          NaN          NaN    NaN
# 45358          NaN          NaN    NaN
# 45359          NaN          NaN    NaN
# 45360          NaN          NaN    NaN
# 45361          NaN          NaN    NaN
# 45362          NaN          NaN    NaN
# 45363          NaN          NaN    NaN
# 45364          NaN          NaN    NaN
# 45365          NaN          NaN    NaN
# 45366          NaN          NaN    NaN
# 45367          NaN          NaN    NaN
# 45368          NaN          NaN    NaN
# 45369          NaN          NaN    NaN
# 45370          NaN          NaN    NaN
# 45371          NaN          NaN    NaN
# 45372          NaN          NaN    NaN
# 45373          NaN          NaN    NaN
# 45374          NaN          NaN    NaN
# 45375          NaN          NaN    NaN
# 45376          NaN          NaN    NaN
# 45377          NaN          NaN    NaN
#
# [45378 rows x 6 columns]

# %% [raw]
# files = []
# files = glob.glob("ClubData/ClubData0/*.csv")+glob.glob("ClubData/ClubData1/*.csv")+glob.glob("ClubData/ClubData2/*.csv")+glob.glob("ClubData/ClubData3/*.csv")
# print(len(files))
# ClubDataFrame = pd.read_csv(files[0],sep="\t")
#
# for file in files:
#     df= pd.read_csv(file,sep ="\t")
#     ClubDataFrame = ClubDataFrame.append(df,ignore_index = True)
#
# #Drop Useless columns
# ClubDataFrame = ClubDataFrame.drop('Unnamed: 0', 1)
# ClubDataFrame.reset_index()
# print(ClubDataFrame.shape)

# %%
file = "ClubData/ClubDataGeo/ClubDataFrame.csv"
ClubDataFrame = pd.read_csv(file,sep=",")
ClubDataFrame["Genre"] = None
ClubDataFrame["location"] = None
ClubDataFrame["club"] = 1
ClubDataFrame = ClubDataFrame[["ClubName","club","Address","location","EventName","Date","LineUp","Genre","Location"]]
ClubDataFrame.columns = ["place","club","address","location","event","date","artists","genre","coordinates"]
ClubDataFrame

# %%
file = "EventsChData/completeWithCoordinates.csv"
EventsDataFrame = pd.read_csv(file)
EventsDataFrame["address"] = None
EventsDataFrame["place"] = None
EventsDataFrame["club"] = 0
EventsDataFrame = EventsDataFrame[["place","club","address","location","event","date","artists","genre","coordinates"]]
EventsDataFrame

# %%
Dataframe = pd.DataFrame()
Dataframe = Dataframe.append(EventsDataFrame)
Dataframe = Dataframe.append(ClubDataFrame)
Dataframe.to_csv("FullData/EventsAndClubs.csv")

# %% [markdown]
# # Getting all artists

# %%
ArtistsDataFrame = pd.DataFrame()
i=0
print(Dataframe.shape)
for index,row in Dataframe.iterrows():
    lineup = row[6] #get line-up
    artists = literal_eval(lineup)
    for a in artists:
        a = a.split("(")[0]#Remove parenthesis at end of artist (record label, live act..)
        a = pd.Series(a.strip())
        ArtistsDataFrame = ArtistsDataFrame.append(a,ignore_index=True)
    i+=1
    if(i%5000==0):
        print(i)
        
ArtistsDataFrame.columns=["artist"]
ArtistsDataFrame.to_csv("FullData/ArtistsList.csv")
ArtistsDataFrame.head(10)

# %%
ArtistsDataFrame.to_csv("FullData/ArtistsList.csv",encoding="utf-8")

# %%
def downloadGenres(str_file,begin=0,end=100000):

    Artists = pd.read_csv(str_file,index_col=0)
    Artists = Artists.drop_duplicates().reset_index()[["artist"]]
    Artists.columns=["artist"]
    Artists["genres_spotify"]=None
    Artists["genres_ra"]=None
    Artists["main_genres"]=None
    Artists["top3_genres"]=None
    Artists["genre"]=None    
    
    if(end>Artists.shape[0]):
        end = Artists.shape[0]
    
    path = "FullData/ArtistDataframe_"+str(begin)+"_"+str(end)+".csv"
    print("Downloading genres of "+str(end-begin)+" artist...")
    last_read = 0
    for i in range(begin,end):
        S = Artists[Artists.index==i]
        artist = S["artist"].values[0]
        genres_spotify = AE.getGenresFromSpotify(artist)
        if(len(genres_spotify)<1):
            genres_spotify = None
        Artists.loc[Artists.index==i,"genres_spotify"] = str(genres_spotify)

        if(i%300==0):
            Artists.to_csv(path,encoding="utf-8")
            print(str(i)+": Saved under "+path)
    
    Artists.to_csv(path,encoding="utf-8")
    
    print(str(i)+": Saved under "+path)
    last_read = i

    print("Last read = "+str(last_read))
    return Artists

# %%
A = downloadGenres("FullData/ArtistsList.csv",0)
A.head(10)

# %%
begin = 0
end = 45378

df = pd.read_csv("FullData/ArtistDataframe.csv")
df

# %%
import ArtistExtractor as AE

begin = 0
end = 45378

df = pd.read_csv("FullData/ArtistDataframe.csv")
df

i=0
AllGenresDownloaded = []
for id,row in df.iterrows():
    listGenres = literal_eval(row[2])
    print(listGenres)
    if(listGenres!=None):
        AllGenresDownloaded+=listGenres
    i+=1
    if(i>10):
        break
print(AllGenresDownloaded)

dic = AE.createDictionnary()
AE.updateDictionnary(AllGenresDownloaded,dic,debug=True)

# %% [markdown]
# # Construct full artist dictionnary

# %%
files = []
files = glob.glob("Artists/*.txt")
print("Nb files : "+str(len(files)))
ArtistsMainDic = dict()
ArtistsAllDic = dict()

for file in files :
    filename = file.replace(".txt","")
    dictTemp = LU.loadDictionary(filename,path="")
    
    if("All" in file):
        ArtistsAllDic = {**ArtistsAllDic,**dictTemp}
        
    if("Main" in file):
        ArtistsMainDic = {**ArtistsMainDic,**dictTemp}
        
print("Artist dictionaries loaded. Merging...",end="")
LU.saveDictionary(ArtistsAllDic,"ArtistsAllGenres","Artists/",enc="UTF-8")
LU.saveDictionary(ArtistsMainDic,"ArtistsMainGenre","Artists/",enc="UTF-8")
print("done.")
print("Deleting temp files...")
for file in files :
    if("-" in file and "temp" in file):
        print("Deleting temp file "+file)
        os.remove(file)
print("DONE.")

# %% [markdown]
# ## Creating dataframe of artists

# %%
ArtistDicoMain = LU.loadDictionary("ArtistsMainGenreOld","Artists/",enc="UTF-8")
ArtistDicoAll =  LU.loadDictionary("ArtistsAllGenresOld","Artists/",enc="UTF-8")
ArtistsSet = set(a.encode("UTF-8") for a in ArtistDicoMain.keys())

ArtistsSet.update(ArtistDicoAll.keys())

DictionnaryGenre = LU.loadDictionary("MusicGenres","Artists/",enc="UTF-8")

ClubDataFrame["Genre"] = None
ClubDataFrame["All Genres"] = None
print("Retrieving genre over " +str(ClubDataFrame.shape)+" events:")

MissingGenres = set()

i=0
for id,row in ClubDataFrame.iterrows():
    genres = []
    lineup = row["LineUp"]
    artists = SplitLineup(lineup)
    
    for artist in artists:
        mainGenre = None
        allGenres = None
        
        if(artist in ArtistsSet):
            mainGenre = ArtistDicoMain.get(artist)
            if(mainGenre!="None" and mainGenre!=None):
                if(mainGenre not in DictionnaryGenre):
                    MissingGenres.add(mainGenre)
                else:
                    translatedGenre = DictionnaryGenre[mainGenre]
                if(translatedGenre!=None):
                    mainGenre = translatedGenre
                allGenres = ArtistDicoAll.get(artist)
        else:
            print("Not found in dictionnary :"+str(artist),end = "")
            #Updating dictionnaries
            ArtistsSet.add(artist)
            allGenres = AE.getGenre(artist,dictionnary=DictionnaryGenre,ReturnAllGenres=True)
            mainGenre = AE.getMaxGenre(allGenres,)
            print(", MainGenre is : "+str(mainGenre))
            ArtistDicoMain.update({artist : mainGenre})
            ArtistDicoAll.update({artist : allGenres})
        
        #Adding to LineUp genres
        genres.append(mainGenre) 
        
            
    if(len(genres)==0):
        print(artists)
    else:
        maxGenre =AE.getMaxGenre(genres)
        #updating dataframe
        ClubDataFrame = ClubDataFrame.set_value(id,"Genre",maxGenre)
        ClubDataFrame = ClubDataFrame.set_value(id,"All Genres",str(genres))
        ClubDataFrame = ClubDataFrame.set_value(id,"LineUp",str(artists))
    
    i+=1
    if(i%200==0):
        print(str(i))
    if(i%200==0):
        LU.saveDictionary(ArtistDicoMain,"ArtistDicoMain",path = "Artists/",enc="UTF-8")
        LU.saveDictionary(ArtistDicoAll,"ArtistDicoAll",path = "Artists/",enc="UTF-8")
        
print("FINISHED")
LU.saveDictionary(ArtistDicoMain,"ArtistDicoMain",path = "Artists/",enc="UTF-8")
LU.saveDictionary(ArtistDicoAll,"ArtistDicoAll",path = "Artists/",enc="UTF-8")

print("\n\n These genres were not found in dictionary : ")
print(MissingGenres)

# %%
AE.createDictionnary()
ClubDataFrame[0:50]

# %%
ClubDataFrame.to_csv("ClubData/EventsWithGenre.csv",encoding="UTF-8")
