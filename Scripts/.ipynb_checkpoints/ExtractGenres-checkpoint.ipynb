# %%
import numpy as np
import ArtistExtractor as AE
import pandas as pd
import glob
import os
import LocationUtils as LU
from ExtractGenreClubs import SplitLineup
from ast import literal_eval

# %%
import ArtistExtractor as AE
def generateDictionnary(str_dataframe):
    begin = 0
    end = 45378
    path = str_dataframe
    path = "FullData/ArtistDataframe.csv"
    df = pd.read_csv(path)
    df

    i=0
    AllGenresDownloaded = []
    print("Populating dictionnary with other genres:")
    print("Reading all genres from dataframe : "+path)
    for id,row in df.iterrows():
        listGenres = literal_eval(row[2])
        if(listGenres!=None):
            AllGenresDownloaded+=listGenres
    print("All genre extracted from dataframe. Updating dictionnary..")
    dic = AE.createDictionnary()
    dic = AE.updateDictionnary(AllGenresDownloaded,dic,debug=True)
    LU.saveDictionary(dic,"FullData/AllGenresDic",enc="utf-8")
    print("Dictionnary of genre saved.")

# %%
dictionnaryOfGenres = LU.loadDictionary("FullData/AllGenresDic",enc="utf-8")

# %%
a = "Hello"
AE.getMaxGenre(a,2)
# Out:
# ['l', 'o']

# %%
begin = 0
end = 45378

df = pd.read_csv("FullData/ArtistDataframe_21000_45378.csv")
df2 = pd.read_csv("FullData/ArtistDataframe_0_21000.csv")
df3 = df.copy()
df3["all_genres"] = None
i=0
dictionnaryOfGenres = LU.loadDictionary("FullData/AllGenresDic",enc="utf-8")

for id,row in df3.iterrows():
    i+=1
    #if(i>20):
     #   break
    if(i%1000==0):
        print(i)
        
    artist = row["artist"]
    corresponding_df2=df2[df2.artist==row["artist"]]["genres_ra"]           
     
    str_df2 = str(None)
    if(len(corresponding_df2.values)>0):
        str_df2 = str(corresponding_df2.values[0])
    str_df2.replace("{","[").replace("}","]")
    
    gs = df3[df3.artist == artist]["genres_spotify"]    
    genres_s =str(None)
    if(len(gs)>0):
        genres_s = df3[df3.artist == artist]["genres_spotify"].values[0]#,df3.genres_spotify]
        
    genres_a = str_df2.replace("{","[").replace("}","]")
    
    if(genres_s!="None"):
        genres_s = literal_eval(genres_s)
    else:
        genres_s = []
        
    if(genres_a!="None" and str(genres_a)!="nan"):
        try:
            genres_a = literal_eval(genres_a)
        except:
            print(genres_a)
    else:
        genres_a = []
    
    genres = genres_s+genres_a
    
    main_genres = AE.mainGenres(genres,dictionnaryOfGenres)
    top3 = AE.getMaxGenre(main_genres,3)
    main_genre = None
    
    if(top3!=None and len(top3)>1):
        main_genre = top3[0]
        
        
    if(len(genres)==0):
        genres = None
    if(len(genres_a)==0):
        genres_a = None
    if(len(main_genres)==0):
        main_genres = None
        
    df3.loc[id,"genres_ra"] = str(genres_a)
    df3.loc[id,"main_genres"] = str(main_genres)
    df3.loc[id,"top3_genres"] = str(top3)
    df3.loc[id,"all_genres"] = str(genres)
    df3.loc[id,"genre"] = main_genre
    
        
df3.to_csv("FullData/ArtistDF_withGenres.csv",encoding="utf-8")
df3
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
#        Unnamed: 0                    artist  \
# 0               0          Andy Gruber Band
# 1               1                DJ Raykard
# 2               2             Martin Sander
# 3               3           Bernhard Hörler
# 4               4                     Oomph
# 5               5                Plusmacher
# 6               6     Konstantin Scherbakov
# 7               7              The Bosshoss
# 8               8          The Sore Loosers
# 9               9              Viper Sniper
# 10             10         T. S. Monk Sextet
# 11             11         Markus Brönnimann
# 12             12          Barbara Tillmann
# 13             13             Ulrike Jacoby
# 14             14          Muriel Schweizer
# 15             15               Anita Jehli
# 16             16         Jaël Bertschinger
# 17             17          Esther Fritzsche
# 18             18                 Borknagar
# 19             19                   Kampfar
# 20             20                Diabolical
# 21             21                Lia Andres
# 22             22            Debora Büttner
# 23             23              Raphael Höhn
# 24             24              Tobias Wicky
# 25             25           Maki Wiederkehr
# 26             26             Elina Kaykova
# 27             27           Veronika Eberle
# 28             28             Kenny Garrett
# 29             29             Vernell Brown
# ...           ...                       ...
# 45348       45348                    Vessel
# 45349       45349                      Kahn
# 45350       45350                      Neek
# 45351       45351    El Kid and Ishan Sound
# 45352       45352                   incite/
# 45353       45353                   Actress
# 45354       45354                   + more.
# 45355       45355                  DJ Hachi
# 45356       45356           Garçon & Morard
# 45357       45357                  Sexbeach
# 45358       45358        Homopatik - Japan)
# 45359       45359               Shingo Suwa
# 45360       45360                Akirahawks
# 45361       45361           Merkur - Japan)
# 45362       45362            SENSE - Basel)
# 45363       45363                   P.A.S.K
# 45364       45364                     Salar
# 45365       45365                Christo...
# 45366       45366        Scrap & Jimi Jules
# 45367       45367  Stereo Riders & DJ Big B
# 45368       45368    DJ Tonic & DJ Tremendo
# 45369       45369                    Daitan
# 45370       45370                   Dottore
# 45371       45371                     Goyav
# 45372       45372                       WÆV
# 45373       45373              PleasureLab)
# 45374       45374             CMYKollektiv)
# 45375       45375                   Stavros
# 45376       45376                 Carlos Jr
# 45377       45377            Apples & Pears
#
#                                           genres_spotify  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      ['german metal', 'industrial metal', 'industri...
# 5              ['deep german hip hop', 'german hip hop']
# 6                   ['classical piano', 'concert piano']
# 7             ['comic', 'german pop', 'german pop rock']
# 8                                                   None
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                                  None
# 13                                                  None
# 14                                                  None
# 15                                                  None
# 16                                                  None
# 17                                                  None
# 18     ['atmospheric black metal', 'avantgarde metal'...
# 19     ['atmospheric black metal', 'avantgarde metal'...
# 20                                                  None
# 21                                                  None
# 22                                                  None
# 23                                                  None
# 24                                                  None
# 25                                                  None
# 26                                                  None
# 27                                                  None
# 28     ['bebop', 'contemporary jazz', 'contemporary p...
# 29                                                  None
# ...                                                  ...
# 45348   ['deep indie r&b', 'vapor soul', 'vapor twitch']
# 45349                                               None
# 45350                                               None
# 45351                                               None
# 45352            ['groove metal', 'thrash-groove metal']
# 45353  ['alternative dance', 'brooklyn indie', 'chill...
# 45354  ['alternative metal', 'nu metal', 'post-grunge...
# 45355                                               None
# 45356                                               None
# 45357                                               None
# 45358                                               None
# 45359                                               None
# 45360                                               None
# 45361                                               None
# 45362                                               None
# 45363                                               None
# 45364             ['persian pop', 'persian traditional']
# 45365                                               None
# 45366                                               None
# 45367                                               None
# 45368                                               None
# 45369                                               None
# 45370                                               None
# 45371                                               None
# 45372                                               None
# 45373                                               None
# 45374                                               None
# 45375                                 ['indie emo rock']
# 45376                                   ['samba-enredo']
# 45377                                               None
#
#                                                genres_ra  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      ['electro', 'rai', 'son', 'heavy metal', 'meta...
# 5                                                   None
# 6                                       ['rap', 'disco']
# 7                                                   None
# 8                                                   None
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                        ['emo', 'rap']
# 13                                                  None
# 14                                                  None
# 15                                                  None
# 16                                                  None
# 17                                                  None
# 18     ['black metal', 'metal', 'folk', 'rap', 'ska',...
# 19     ['black metal', 'metal', 'folk', 'viking metal...
# 20                                                  None
# 21                                                  None
# 22                                                  None
# 23                                                  None
# 24                                                  None
# 25                                                  None
# 26                                                  None
# 27                                                  None
# 28                                ['rap', 'jazz', 'son']
# 29                                                  None
# ...                                                  ...
# 45348                                               None
# 45349                                               None
# 45350                                               None
# 45351                                               None
# 45352                                               None
# 45353                                               None
# 45354                                               None
# 45355                                               None
# 45356                                               None
# 45357                                               None
# 45358                                               None
# 45359                                               None
# 45360                                               None
# 45361                                               None
# 45362                                               None
# 45363                                               None
# 45364                                               None
# 45365                                               None
# 45366                                               None
# 45367                                               None
# 45368                                               None
# 45369                                               None
# 45370                                               None
# 45371                                               None
# 45372                                               None
# 45373                                               None
# 45374                                               None
# 45375                                               None
# 45376                                               None
# 45377                                               None
#
#                                              main_genres  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      ['rock', 'rock', 'rock', 'rock', 'electronic',...
# 5                                 ['hip hop', 'hip hop']
# 6              ['orchestral', 'hip hop', 'r&b and soul']
# 7                                        ['pop', 'rock']
# 8                                                   None
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                   ['rock', 'hip hop']
# 13                                                  None
# 14                                                  None
# 15                                                  None
# 16                                                  None
# 17                                                  None
# 18     ['rock', 'rock', 'rock', 'rock', 'rock', 'rock...
# 19     ['rock', 'rock', 'rock', 'rock', 'rock', 'rock...
# 20                                                  None
# 21                                                  None
# 22                                                  None
# 23                                                  None
# 24                                                  None
# 25                                                  None
# 26                                                  None
# 27                                                  None
# 28     ['jazz', 'jazz', 'jazz', 'jazz', 'jazz', 'jazz...
# 29                                                  None
# ...                                                  ...
# 45348     ['r&b and soul', 'r&b and soul', 'electronic']
# 45349                                               None
# 45350                                               None
# 45351                                               None
# 45352                                   ['rock', 'rock']
# 45353  ['electronic', 'rock', 'electronic', 'electron...
# 45354                   ['rock', 'rock', 'rock', 'rock']
# 45355                                               None
# 45356                                               None
# 45357                                               None
# 45358                                               None
# 45359                                               None
# 45360                                               None
# 45361                                               None
# 45362                                               None
# 45363                                               None
# 45364                                     ['pop', 'pop']
# 45365                                               None
# 45366                                               None
# 45367                                               None
# 45368                                               None
# 45369                                               None
# 45370                                               None
# 45371                                               None
# 45372                                               None
# 45373                                               None
# 45374                                               None
# 45375                                           ['rock']
# 45376                                          ['latin']
# 45377                                               None
#
#                                      top3_genres         genre  \
# 0                                           None           NaN
# 1                                           None           NaN
# 2                                           None           NaN
# 3                                           None           NaN
# 4                ['rock', 'electronic', 'latin']          rock
# 5                                    ['hip hop']          None
# 6      ['hip hop', 'r&b and soul', 'orchestral']       hip hop
# 7                                ['pop', 'rock']           pop
# 8                                           None          None
# 9                                           None          None
# 10                                          None          None
# 11                                          None          None
# 12                           ['rock', 'hip hop']          rock
# 13                                          None          None
# 14                                          None          None
# 15                                          None          None
# 16                                          None          None
# 17                                          None          None
# 18                   ['rock', 'folk', 'hip hop']          rock
# 19                   ['rock', 'folk', 'hip hop']          rock
# 20                                          None          None
# 21                                          None          None
# 22                                          None          None
# 23                                          None          None
# 24                                          None          None
# 25                                          None          None
# 26                                          None          None
# 27                                          None          None
# 28                  ['jazz', 'latin', 'hip hop']          jazz
# 29                                          None          None
# ...                                          ...           ...
# 45348             ['r&b and soul', 'electronic']  r&b and soul
# 45349                                       None          None
# 45350                                       None          None
# 45351                                       None          None
# 45352                                   ['rock']          None
# 45353              ['electronic', 'pop', 'rock']    electronic
# 45354                                   ['rock']          None
# 45355                                       None          None
# 45356                                       None          None
# 45357                                       None          None
# 45358                                       None          None
# 45359                                       None          None
# 45360                                       None          None
# 45361                                       None          None
# 45362                                       None          None
# 45363                                       None          None
# 45364                                    ['pop']          None
# 45365                                       None          None
# 45366                                       None          None
# 45367                                       None          None
# 45368                                       None          None
# 45369                                       None          None
# 45370                                       None          None
# 45371                                       None          None
# 45372                                       None          None
# 45373                                       None          None
# 45374                                       None          None
# 45375                                   ['rock']          None
# 45376                                  ['latin']          None
# 45377                                       None          None
#
#                                               all_genres
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      ['german metal', 'industrial metal', 'industri...
# 5              ['deep german hip hop', 'german hip hop']
# 6      ['classical piano', 'concert piano', 'rap', 'd...
# 7             ['comic', 'german pop', 'german pop rock']
# 8                                                   None
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                        ['emo', 'rap']
# 13                                                  None
# 14                                                  None
# 15                                                  None
# 16                                                  None
# 17                                                  None
# 18     ['atmospheric black metal', 'avantgarde metal'...
# 19     ['atmospheric black metal', 'avantgarde metal'...
# 20                                                  None
# 21                                                  None
# 22                                                  None
# 23                                                  None
# 24                                                  None
# 25                                                  None
# 26                                                  None
# 27                                                  None
# 28     ['bebop', 'contemporary jazz', 'contemporary p...
# 29                                                  None
# ...                                                  ...
# 45348   ['deep indie r&b', 'vapor soul', 'vapor twitch']
# 45349                                               None
# 45350                                               None
# 45351                                               None
# 45352            ['groove metal', 'thrash-groove metal']
# 45353  ['alternative dance', 'brooklyn indie', 'chill...
# 45354  ['alternative metal', 'nu metal', 'post-grunge...
# 45355                                               None
# 45356                                               None
# 45357                                               None
# 45358                                               None
# 45359                                               None
# 45360                                               None
# 45361                                               None
# 45362                                               None
# 45363                                               None
# 45364             ['persian pop', 'persian traditional']
# 45365                                               None
# 45366                                               None
# 45367                                               None
# 45368                                               None
# 45369                                               None
# 45370                                               None
# 45371                                               None
# 45372                                               None
# 45373                                               None
# 45374                                               None
# 45375                                 ['indie emo rock']
# 45376                                   ['samba-enredo']
# 45377                                               None
#
# [45378 rows x 8 columns]

# %%
def downloadGenresWikipedia(str_file,dictionnary,begin=0,end=100000):

    Artists = pd.read_csv(str_file,index_col=0)
    
    if(end>Artists.shape[0]):
        end = Artists.shape[0]
    
    path = "FullData/ArtistDataframe_"+str(begin)+"_"+str(end)+".csv"
    print("Downloading genres of "+str(end-begin)+" artist...")
    last_read = 0
    for i in range(begin,end):
        S = Artists[Artists.index==i]
        artist = S["artist"].values[0]
        genres_ra = AE.getGenresFromWikipedia(artist,dictionnary)
        if(len(genres_ra)<1):
            genres_ra = None
        Artists.loc[Artists.index==i,"genres_ra"] = str(genres_ra)

        if(i%300==0):
            Artists.to_csv(path,encoding="utf-8")
            print(str(i)+": Saved under "+path)
    
    Artists.to_csv(path,encoding="utf-8")
    
    print(str(i)+": Saved under "+path)
    last_read = i

    print("Last read = "+str(last_read))
    return Artists

# %%
a = downloadGenresWikipedia("FullData/ArtistDataframe.csv",dictionnaryOfGenres,9,18)
a

# %% [raw]
# files = []
# files = glob.glob("ClubData/ClubData0/*.csv")+glob.glob("ClubData/ClubData1/*.csv")+glob.glob("ClubData/ClubData2/*.csv")+glob.glob("ClubData/ClubData3/*.csv")
# print(len(files))
# ClubDataFrame = pd.read_csv(files[0],sep="\t")
#
# for file in files:
#     df= pd.read_csv(file,sep ="\t")
#     ClubDataFrame = ClubDataFrame.append(df,ignore_index = True)
#
# #Drop Useless columns
# ClubDataFrame = ClubDataFrame.drop('Unnamed: 0', 1)
# ClubDataFrame.reset_index()
# print(ClubDataFrame.shape)

# %%
file = "ClubData/ClubDataGeo/ClubDataFrame.csv"
ClubDataFrame = pd.read_csv(file,sep=",")
ClubDataFrame["Genre"] = None
ClubDataFrame["location"] = None
ClubDataFrame["club"] = 1
ClubDataFrame = ClubDataFrame[["ClubName","club","Address","location","EventName","Date","LineUp","Genre","Location"]]
ClubDataFrame.columns = ["place","club","address","location","event","date","artists","genre","coordinates"]
ClubDataFrame

# %%
file = "EventsChData/completeWithCoordinates.csv"
EventsDataFrame = pd.read_csv(file)
EventsDataFrame["address"] = None
EventsDataFrame["place"] = None
EventsDataFrame["club"] = 0
EventsDataFrame = EventsDataFrame[["place","club","address","location","event","date","artists","genre","coordinates"]]
EventsDataFrame

# %%
Dataframe = pd.DataFrame()
Dataframe = Dataframe.append(EventsDataFrame)
Dataframe = Dataframe.append(ClubDataFrame)
Dataframe.to_csv("FullData/EventsAndClubs.csv", encoding="utf-8")

# %% [markdown]
# # Getting all artists

# %%
ArtistsDataFrame = pd.DataFrame()
i=0
print(Dataframe.shape)
for index,row in Dataframe.iterrows():
    lineup = row[6] #get line-up
    artists = literal_eval(lineup)
    for a in artists:
        a = a.split("(")[0]#Remove parenthesis at end of artist (record label, live act..)
        a = pd.Series(a.strip())
        ArtistsDataFrame = ArtistsDataFrame.append(a,ignore_index=True)
    i+=1
    if(i%5000==0):
        print(i)
        
ArtistsDataFrame.columns=["artist"]
ArtistsDataFrame.to_csv("FullData/ArtistsList.csv")
ArtistsDataFrame.head(10)

# %%
ArtistsDataFrame.to_csv("FullData/ArtistsList.csv",encoding="utf-8")

# %%
def downloadGenres(str_file,begin=0,end=100000):

    Artists = pd.read_csv(str_file,index_col=0)
    Artists = Artists.drop_duplicates().reset_index()[["artist"]]
    Artists.columns=["artist"]
    Artists["genres_spotify"]=None
    Artists["genres_ra"]=None
    Artists["main_genres"]=None
    Artists["top3_genres"]=None
    Artists["genre"]=None    
    
    if(end>Artists.shape[0]):
        end = Artists.shape[0]
    
    path = "FullData/ArtistDataframe_"+str(begin)+"_"+str(end)+".csv"
    print("Downloading genres of "+str(end-begin)+" artist...")
    last_read = 0
    for i in range(begin,end):
        S = Artists[Artists.index==i]
        artist = S["artist"].values[0]
        genres_spotify = AE.getGenresFromSpotify(artist)
        if(len(genres_spotify)<1):
            genres_spotify = None
        Artists.loc[Artists.index==i,"genres_spotify"] = str(genres_spotify)

        if(i%300==0):
            Artists.to_csv(path,encoding="utf-8")
            print(str(i)+": Saved under "+path)
    
    Artists.to_csv(path,encoding="utf-8")
    
    print(str(i)+": Saved under "+path)
    last_read = i

    print("Last read = "+str(last_read))
    return Artists

# %%
A = downloadGenres("FullData/ArtistsList.csv",0)
A.head(10)

# %%
dictionnaryOfGenres = LU.loadDictionary("FullData/AllGenresDic",enc="utf-8")
for a in dictionnaryOfGenres:
    if(a=="rap"):
        print(a)

# %%
import ArtistExtractor as AE

begin = 0
end = 45378

df = pd.read_csv("FullData/ArtistDataframe.csv")
df

i=0
AllGenresDownloaded = []
for id,row in df.iterrows():
    listGenres = literal_eval(row[2])
    print(listGenres)
    if(listGenres!=None):
        AllGenresDownloaded+=listGenres
    i+=1
    if(i>10):
        break
print(AllGenresDownloaded)

dic = AE.createDictionnary()
AE.updateDictionnary(AllGenresDownloaded,dic,debug=True)

# %% [markdown]
# # Construct full artist dictionnary

# %%
files = []
files = glob.glob("Artists/*.txt")
print("Nb files : "+str(len(files)))
ArtistsMainDic = dict()
ArtistsAllDic = dict()

for file in files :
    filename = file.replace(".txt","")
    dictTemp = LU.loadDictionary(filename,path="")
    
    if("All" in file):
        ArtistsAllDic = {**ArtistsAllDic,**dictTemp}
        
    if("Main" in file):
        ArtistsMainDic = {**ArtistsMainDic,**dictTemp}
        
print("Artist dictionaries loaded. Merging...",end="")
LU.saveDictionary(ArtistsAllDic,"ArtistsAllGenres","Artists/",enc="UTF-8")
LU.saveDictionary(ArtistsMainDic,"ArtistsMainGenre","Artists/",enc="UTF-8")
print("done.")
print("Deleting temp files...")
for file in files :
    if("-" in file and "temp" in file):
        print("Deleting temp file "+file)
        os.remove(file)
print("DONE.")

# %% [markdown]
# ## Creating dataframe of artists

# %%
ArtistDicoMain = LU.loadDictionary("ArtistsMainGenreOld","Artists/",enc="UTF-8")
ArtistDicoAll =  LU.loadDictionary("ArtistsAllGenresOld","Artists/",enc="UTF-8")
ArtistsSet = set(a.encode("UTF-8") for a in ArtistDicoMain.keys())

ArtistsSet.update(ArtistDicoAll.keys())

DictionnaryGenre = LU.loadDictionary("MusicGenres","Artists/",enc="UTF-8")

ClubDataFrame["Genre"] = None
ClubDataFrame["All Genres"] = None
print("Retrieving genre over " +str(ClubDataFrame.shape)+" events:")

MissingGenres = set()

i=0
for id,row in ClubDataFrame.iterrows():
    genres = []
    lineup = row["LineUp"]
    artists = SplitLineup(lineup)
    
    for artist in artists:
        mainGenre = None
        allGenres = None
        
        if(artist in ArtistsSet):
            mainGenre = ArtistDicoMain.get(artist)
            if(mainGenre!="None" and mainGenre!=None):
                if(mainGenre not in DictionnaryGenre):
                    MissingGenres.add(mainGenre)
                else:
                    translatedGenre = DictionnaryGenre[mainGenre]
                if(translatedGenre!=None):
                    mainGenre = translatedGenre
                allGenres = ArtistDicoAll.get(artist)
        else:
            print("Not found in dictionnary :"+str(artist),end = "")
            #Updating dictionnaries
            ArtistsSet.add(artist)
            allGenres = AE.getGenre(artist,dictionnary=DictionnaryGenre,ReturnAllGenres=True)
            mainGenre = AE.getMaxGenre(allGenres,)
            print(", MainGenre is : "+str(mainGenre))
            ArtistDicoMain.update({artist : mainGenre})
            ArtistDicoAll.update({artist : allGenres})
        
        #Adding to LineUp genres
        genres.append(mainGenre) 
        
            
    if(len(genres)==0):
        print(artists)
    else:
        maxGenre =AE.getMaxGenre(genres)
        #updating dataframe
        ClubDataFrame = ClubDataFrame.set_value(id,"Genre",maxGenre)
        ClubDataFrame = ClubDataFrame.set_value(id,"All Genres",str(genres))
        ClubDataFrame = ClubDataFrame.set_value(id,"LineUp",str(artists))
    
    i+=1
    if(i%200==0):
        print(str(i))
    if(i%200==0):
        LU.saveDictionary(ArtistDicoMain,"ArtistDicoMain",path = "Artists/",enc="UTF-8")
        LU.saveDictionary(ArtistDicoAll,"ArtistDicoAll",path = "Artists/",enc="UTF-8")
        
print("FINISHED")
LU.saveDictionary(ArtistDicoMain,"ArtistDicoMain",path = "Artists/",enc="UTF-8")
LU.saveDictionary(ArtistDicoAll,"ArtistDicoAll",path = "Artists/",enc="UTF-8")

print("\n\n These genres were not found in dictionary : ")
print(MissingGenres)

# %%
AE.createDictionnary()
ClubDataFrame[0:50]

# %%
ClubDataFrame.to_csv("ClubData/EventsWithGenre.csv",encoding="UTF-8")
