# %%
import pandas as pd
import numpy as np
import json
import bs4
import requests

# %%
df = pd.read_csv("ClubDataTest/test.csv")
df
# Out:
#     Unnamed: 0                     place                              address  \
# 0            0   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 1            1   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 2            2   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 3            3   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 4            4   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 5            5   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 6            6   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 7            7   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 8            8   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 9            9   2. Akt Restaurant & Bar                      Selnaustrasse 2
# 10          10   2. Akt Restaurant & Bar                      Selnaustrasse 2
# ...

# %%
dictionnary_regions = {}
GOOGLE_API_KEY = "AIzaSyBHFQP-QhcaV7CG7o7-FLacHtlE0YI_E1E"
dataframe = pd.read_csv("FullData/EventsAndClubs_merged.csv")
dataframe.head(10)
# Out:
#    Unnamed: 0 place  club address    location  \
# 0           0   NaN     0     NaN      Zürich
# 1           1   NaN     0     NaN       Basel
# 2           2   NaN     0     NaN       Basel
# 3           3   NaN     0     NaN    Dietikon
# 4           4   NaN     0     NaN      Zürich
# 5           5   NaN     0     NaN      Zürich
# 6           6   NaN     0     NaN      Zürich
# 7           7   NaN     0     NaN  Winterthur
# 8           8   NaN     0     NaN        Bern
# 9           9   NaN     0     NaN  Glattbrugg
#
#                                event        date  \
# 0                   Andy-Gruber-Band  2016-04-22
# 1               Lilian's-White-Party  2016-04-22
# 2          Orgelspiel-zum-Feierabend  2016-04-22
# 3                    Feierabendmusik  2016-04-22
# 4                              Oomph  2016-04-22
# 5                         Plusmacher  2016-04-22
# 6                       Klavierabend  2016-04-22
# 7                       The-Bosshoss  2016-04-22
# ...

# %%
#Adding location of the "club"
def getCanton(clubName,dictionnaryLocality=None,dictionnaryRegion=None,SwissSafety=True):
    '''Returns the location of the club with a tuple (lat,lng)'''
    
    clubName = clubName.replace(";",",")
    region=None
    locality = None
    lat = None
    lng = None
    
    if(dictionnaryRegion != None and (clubName in dictionnaryRegion)):
        region = dictionnaryRegion[clubName]
    
    if(dictionnaryLocality != None and (clubName in dictionnaryLocality)):
        locality = dictionnaryLocality[clubName]
    
    
    if(locality !=None and region!=None):
        return region,locality
    else:
        if(locality==None): #Try with geoCodeAPI
            baseURL1 = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
            try:
                region,locality = getFromAPI(clubName,baseURL1)
            except:
                region,locality  = None,None
            
        if(locality==None): #Try with textSearchAPI
            baseURL2 = 'https://maps.googleapis.com/maps/api/geocode/json'
            try:
                region,locality  = getFromAPI(clubName,baseURL2)
            except:
                region,locality  = None,None
                
        #If nothing found     
        if(region==None and locality==None):
            address_comp = list(clubName.split(","))[::-1]
            
            #timeout
            timeout = 5
            i = 0
            if(len(address_comp)>1):
                for ac in address_comp:
                    i+=1
                    region,locality = getCanton(ac,None,None)
                    if(region!=None):
                        break
                    if(i>timeout):
                        break
                
                
        if(dictionnaryRegion!=None):
            dictionnaryRegion.update({clubName : region})
        if(dictionnaryLocality!=None):
            dictionnaryLocality.update({clubName : locality})
            
    return region, locality

# %%
def getFromAPI(clubName,baseURL):
    param={}
   
    if("geocode" in baseURL):
        param = {'address': str(clubName),
             'region':'ch',
             'key': GOOGLE_API_KEY
                }
    else:
        param = {'query': str(clubName),
                 #'keyword':'Switzerland',
                 'key': GOOGLE_API_KEY
                }
    
    #baseURL = 'https://maps.googleapis.com/maps/api/geocode/json' #Get JSON for Geocode
    content = json.loads(requests.get(baseURL, params = param).text)
    if('error_message' in content):
        raise Exception()
    location = None
    if(len(content['results'])>0):
        location = content['results'][0]['geometry']['location']
        addr_comp = content['results'][0]['address_components']
        region = None
        locality = None
        
        for r in addr_comp:
            if("administrative_area_level_1" in str(r)):
                region = r['short_name']
            if("locality" in str(r)):
                locality = r['short_name'] 
    
    return region,locality

# %%
def completeRegionAndLocality(dataframe):
    dataframe['region'] = None
    dataframe = dataframe[["place" ,"club" ,"address","location","region","event" ,
                           "date","artists","genre","coordinates"]]
    
    AddressDic = {}
    LocalityDic = {}
    
    i = 0
    print(dataframe.shape)
    
    for id,row in dataframe.iterrows():
        
        i+=1
        if(i%200==0):
            print(i)
        
        place = row.place
        address = row.address
        location = row.location
       
        region = None
        locality = None
        #Replace invalid location
        if(":" in str(location) or "{" in str(location) or "nan" in str(location).lower()):
            location = None
            
        noneLocation = (location == None or str(location)=="nan")    
            
        if(noneLocation and address!=None):
            region,locality = getCanton(address,AddressDic,LocalityDic)
            
        elif(noneLocation == None and place!=None):
            region,locality = getCanton(place,AddressDic,LocalityDic)
            
        elif(location != None):
            region,locality = getCanton(location,AddressDic,LocalityDic)
            
        dataframe.loc[id,"location"] = locality
        dataframe.loc[id,"region"] = region
        
    return dataframe

# %%
getCanton("Globull")
# Out:
# ('FR', 'Bulle')

# %%
dataframe = completeRegionAndLocality(dataframe)
dataframe.to_csv("FullData/EventsAndClubs_regions.csv",encoding="utf-8")
# Out:
# (38846, 10)
# C:\Users\Simon\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# 11800
# 12000
# 12200
# 12400
# 12600
# 12800
# 13000
# 13200
# 13400
# 13600
# 13800
# 14000
# 14200
# 14400
# 14600
# 14800
# 15000
# 15200
# 15400
# 15600
# 15800
# 16000
# 16200
# 16400
# 16600
# ...

# %%
dataframe
# Out:
#                            place  club  \
# 0                            NaN     0
# 1                            NaN     0
# 2                            NaN     0
# 3                            NaN     0
# 4                            NaN     0
# 5                            NaN     0
# 6                            NaN     0
# 7                            NaN     0
# 8                            NaN     0
# 9                            NaN     0
# 10                           NaN     0
# 11                           NaN     0
# 12                           NaN     0
# 13                           NaN     0
# 14                           NaN     0
# 15                           NaN     0
# 16                           NaN     0
# 17                           NaN     0
# 18                           NaN     0
# 19                           NaN     0
# 20                           NaN     0
# 21                           NaN     0
# 22                           NaN     0
# ...
