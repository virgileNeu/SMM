# %% [markdown]
# # Resident Advisor Extractor

# %% [markdown]
# This class aim to extract the dataframe of all events in Resident Advisor and create DataFrame such as : Club Location, Event Per Clubs, Club Attendance...

# %% [markdown]
# ## Retrieving the data

# %%
import numpy as np
import pandas as pd
import requests
import bs4

# %%
baseURL = "https://www.residentadvisor.net/"
clubListURL = "https://www.residentadvisor.net/clubs.aspx"
content = requests.get(clubListURL).text

soup = bs4.BeautifulSoup(content, "html5lib")

clubDF = pd.DataFrame(columns = ["ClubID","Name","Address"])

for tdTag in soup.findAll('li'):
    for clubs in tdTag.findAll('li'):
        if('class' in clubs.attrs and len(clubs)==2):
            #Parsing infos
            clubID = "null"
            address = "null"
            name = "null"
            for line in clubs:
                if(line.a == None):
                    address = line.text
                else:
                    name = line.text
                    clubID = line.a['href'].split("=")[1]
            #print(str(clubID)+",,"+str(adress)+",,"+str(name))
            df = pd.Series([clubID,name,address],['ClubID','Name','Address'])
            clubDF = clubDF.append(df, ignore_index=True)
            #print(df) 
clubDF.head(250)
# Out:
#      ClubID                          Name  \
# 0     55816       2. Akt Restaurant & Bar
# 1     84182         25 Hours Hotel Zürich
# 2     24800                     2B Lounge
# 3     85693                      3monkeys
# 4     82433                        4. Akt
# 5     34422                    5ème Etage
# 6     31409                       Abraxas
# 7     39607                        Acanto
# 8    102059                  Acapella Bar
# 9     18481          Acqua Lounge Basilea
# 10     9913                        Adagio
# 11    74860                           Akt
# 12    25492             Albani Music Club
# 13    24542                      Alhambar
# 14   102769                    Alice Choo
# 15   114959                  Alpina Hütte
# 16    42545         Alte Cigarettenfabrik
# 17    52726                  Alte Kaserne
# 18    46827                  Amboss Rampe
# 19    64224          Ampere Club / Lounge
# 20   103024            Ancienne Gare Café
# 21   125254             Anciens Abattoirs
# 22    25068          Annex & Kuppel Basel
# 23   110233             Apawi Pure Lounge
# 24   117620                 AQUARIUM Café
# 25    90475             Arche Brockenhaus
# 26    79367                        Archiv
# 27    57328               Arena Mendrisio
# 28    88527                   Athome Club
# 29    19703                 Atlantis Club
# ..      ...                           ...
# 220   17056                Gaskessel Bern
# 221   15523                       Gaswerk
# 222   52515                       Gate 14
# 223   84483                  Geneva Arena
# 224   25921                  Gewerbehalle
# 225   55929                  Glacier 3000
# 226    8907                       Globull
# 227   39053               Gold & Platinum
# 228   63337                     Gold Club
# 229   54894                         Gonzo
# 230   67697                   Grabenhalle
# 231   43535                     Graffitti
# 232   99373                    Grand Cafe
# 233  112458                 Grand Central
# 234   81000   Grand Hotel Suisse Majestic
# 235  108390                     Grenzwert
# 236   80386                   Grey Lounge
# 237   97541   Gris Alliance des Crèateurs
# 238  108677              Grubenstrasse 15
# 239   99990                  Gunbalow Bar
# 240  111623                     Gutenberg
# 241    9451                GZ Wollishofen
# 242   26491                      Hacienda
# 243   70227                   Hafenkneipe
# 244   26893                Halle De L'Ile
# 245  113421                       Halle22
# 246   17266                 Hallenstadion
# 247  115694          Hang Out & Hang Over
# 248   95975                Hangar 11 Club
# 249  113933                      Hangar 9
#
#                                                Address
# 0                                      Selnaustrasse 2
# 1                  Pfingstweidstrasse 102, 8005 Zürich
# 2                     Nüschelerstrasse 31, 8001 Zürich
# 3        Alexander-Schönistrasse 17, 2502, Biel/Bienne
# 4                     Heinrichstrasse 262, 8005 Zürich
# 5                                 Mühlenplatz 11, Bern
# 6                       Chemin du Stand 5; Pully, 1009
# 7                    Pfingstweidstrasse 6, 8005 Zürich
# 8         Place de la Gare, 1957 Ardon, Valais, Suisse
# 9                     Binningerstrasse 14; 4051, Basel
# 10                    Seidenhofstrasse 5; 6002, Luzern
# 11                   Niederdorfstrasse 64, 8001 Zürich
# 12                                   Steinberggasse 16
# 13               Rue de la Rôtisserie 10; 1204, Genève
# 14                      Limmatstrasse 275, 8005 Zürich
# 15              Bergstation Corviglia, 7500 St. Moritz
# 16                          Sihlquai 268; 8005, Zürich
# 17                       Kanonengasse 16; 8004, Zürich
# 18                         Zollstrasse 80, 8005 Zürich
# 19    Alte Obfelderstrasse 68, 8910 Affoltern am Albis
# 20         Esplanade de l'ancienne gare, 1700 Fribourg
# 21   Rue du Commerce 122, 2300 La Chaux-de-Fonds, S...
# 22                                 Binningerstrasse 14
# 23                            Rheingasse 8, 4058 Basel
# 24                Avenue de la Jonction 5, 1205 Genève
# 25                        Hohlstrasse 489, 8048 Zürich
# 26                    Lehenmattstrasse 353, 4052 Basel
# 27            Via Angelo Maspoli, 24 CH-6850 Mendrisio
# 28                Rue Henry-Grandjean 1, 2400 Le Locle
# 29                         Klosterberg 13; 4051, Basel
# ..                                                 ...
# 220                     Sandrainstrasse 25; 3007, Bern
# 221        Untere Schöntalstrasse 19; 2023, Winterthur
# 222                   Weststrasse 14; 8570, Weinfelden
# 223     Route des Batailleux 3, 1218 Le Grand-Saconnex
# 224                       Baselstrasse 46, 6003 Luzern
# 225                 Col du Pillon, Route du Pillon 253
# 226                     Rue de l’Etang 21; 1630, Bulle
# 227                     Quai du Seujet 20, 1201 Genève
# 228                 Rue des Terreaux 7, 2000 Neuchâtel
# 229                       Langstrasse 135, 8004 Zürich
# 230             Unterer Graben 17, 9000 St. Gallen, CH
# 231                      Scheibenstrasse 64, 3014 Bern
# 232                        Bahnhofstrasse 22, 6300 Zug
# 233  Châtelaine, Chemin de l'Etang 55, 1219 Châtelaine
# 234                 Avenue des Alpes 45, 1820 Montreux
# 235                          Rheingasse 17, 4058 Basel
# 236                 Avenue de Frontenex 3, 1207 Genève
# 237                        Europaallee 33, 8004 Zürich
# 238                           Grubenstrasse 15, Zürich
# 239     11 Rue de la Coulouvrenière, 1st floor, Geneva
# 240                    Gutenbergstrasse 1, 8002 Zürich
# 241                        Bachstrasse 7; 8038, Zürich
# 242               Route de la Monderèche; 3960, Sierre
# 243                     Militärstrasse 12, 8004 Zürich
# 244                     Place de l'Ile 1; 1200, Genève
# 245              Chemin des Batailles 22, 1214 Vernier
# 246                Wallisellenstrasse 45; 8050, Zürich
# 247                       Rue de Berne 47, 1201 Genève
# 248                    Werkstrasse 16, 8400 Winterthur
# 249                      9 Rue du Tunnel, Geneva, 1227
#
# [250 rows x 3 columns]

# %% [markdown]
# Once we have the list of clubs, we need to get all the events for each club. For this, we create a parser that take the ClubID as argument and retrieve all events dates and line-up.

# %%
def getEventsFrom(clubIndex):
    '''Gets dataframe of events for a club'''
    ClubURL = "https://www.residentadvisor.net/club.aspx?id="+str(clubIndex)+""
    content = ""
    DFEvents = pd.DataFrame(columns = ['ClubID','EventID','EventName','Date','LineUp'])
    
    try:
        content = requests.get(ClubURL).text
    except:
        print("Error getting : "+ClubURL)
        return DFEvents
        
    soup = bs4.BeautifulSoup(content, "html5lib")
    
    eventIDList = list() #List of eventsID to be analysed
    
    #Parsing page to get eventIDs
    for sections in soup.findAll('section'):
        for links in sections.findAll('a'):
            if(len(links.attrs)==2 and 'itemprop' in links.attrs):
                link = links['href']
                eventID = link.split('?')[1]
                eventIDList.append(eventID) #Add eventID to list
    
    
    for eid in eventIDList:
        series = getSerieFromEvent(clubIndex,eid)
        DFEvents = DFEvents.append(series,ignore_index=True)
    
    DFEvents.ClubID = DFEvents.ClubID.astype(int)
    return DFEvents

# %%
def getSerieFromEvent(clubInd,eventID):
    '''Returns a Serie [EventID,EventName,Date,LineUp] for the eventID passed as argument'''
    EventURL = 'https://www.residentadvisor.net/event.aspx?'+str(eventID)
    content = ""
    
    try:
        content = requests.get(EventURL).text
    except:
        print("Error getting : "+EventURL)
        return None
    
    soup = bs4.BeautifulSoup(content, "html5lib")
    
    day = ''
    date = ''
    lineup = set()
    title = ''
    
    #Get LineUp
    for ul in soup.findAll('ul'):
        for div in ul.findAll('div'):
            if('Line' in div.text):
                for p in div.findAll('p'):
                    if('class' in p.attrs and p['class']!=None):
                        artists = p.text.split(',')
                        for a in artists:
                            splitted = a.split("\n")
                            for arts in splitted:
                                lineup.add(arts)
            
            #Deprecated#
            '''#Get Event date
            if('class' in div.attrs and div['class']!= ['clearfix'] and len(div.findAll('li'))>0):
                    for line in div.findAll('li'):
                        if('Date' in line.text):
                            for a in line:
                                if('-' in a): #Get time
                                     hr = a
                                if('y' in a): #Get weekday
                                    day = a
                                if(len(a)==1 and " /" not in a.text): #Get Date
                                    date = a
            '''
    
    #Get title and Date of the event
    for meta in soup.findAll('meta'):
        if('property' in meta.attrs ):
            if(meta['property']=='og:title'):
                title = meta['content']
            if(meta['property']=='og:description'):
                datestr = meta['content']
                val = datestr.split(",")
                date = val[1].split("-")[0]
                day = val[0]
    
    lineup = list(lineup)
    data =[int(clubInd), eventID, title,date,lineup]
    S = pd.Series(data,['ClubID','EventID','EventName','Date','LineUp'])

    return S

# %%
ClubID = int(8907)
eventID = 292693
getEventsFrom(ClubID)
# Out:
#     ClubID EventID                                          EventName  \
# 0     8907  876775                  Carre Blanc x Adana Twins (Friso)
# 1     8907  800014                    Mininova with Marc Houle *Live*
# 2     8907  749638                                  Fritz Kalkbrenner
# 3     8907  754179                          Mininova with Andrea Roma
# 4     8907  757817                               Die Brücke & Friends
# 5     8907  691669  Mininova with Matador for Play with Me Tour an...
# 6     8907  698294                              Mininova with Traumer
# 7     8907  691664                Mininova with Avrosse B2B Louie Cut
# 8     8907  681167                      Mininova with Patrik Soderbom
# 9     8907  647003  La Résidance with DJ W!ld: When You Feel Me Re...
# 10    8907  625360                                              Meggy
# 11    8907  570527  La Résidance #10 with Zombie Disco Squad & Kar...
# 12    8907  570528  La Résidance #10 with Zombie Disco Squad & Kar...
# 13    8907  556261  La Résidance #9 with Claptone, Round Table Kni...
# 14    8907  548073               La Résidance #8 with Joris Delacroix
# 15    8907  547570                     Petit Palace with Jonas Mantey
# 16    8907  528078  La Résidance #7 with Adam Port, Horasse & Kart...
# 17    8907  532231  Globull Goes Deep with Viken Arman (Live) & Mi...
# 18    8907  509004                        La Résidance #6 with Mecury
# 19    8907  466798                                 The Cruzaders Club
# 20    8907  478089               Kartel Klub Birthday Party with Hnqo
# 21    8907  473052       Petit Palace w/ Bakermat, Jokari & Deepwhite
# 22    8907  462806                   Swiss Star Games 2013 - Le Chill
# 23    8907  462801         La Résidance - Kartell, Denz & Kartel Klub
# 24    8907  445822            La Résidance - Doctor Dru & Kartel Klub
# 25    8907  435739                   La Résidance - Kartel Klub Night
# 26    8907  415229                                     The Cruzaders
# 27    8907  335686                                      The Cruzaders
# 28    8907  325212                                      The Cruzaders
# 29    8907  284203                             Bimbo T-Shirt Birthday
# 30    8907  284200                                       Cheese Party
# 31    8907  271001                                      Atomic Groove
# 32    8907  223248                                      The Cruzaders
# 33    8907  754632                                        Leprivilege
# 34    8907  233229                                    Jeremy De Koste
# 35    8907  191430                           The Cruzaders (Fribourg)
# 36    8907  186475                                      The Cruzaders
# 37    8907  832324                                      Atomic Groove
# 38    8907  133075                           The Cruzaders At Globull
# 39    8907   41198                         Atomic Groove:gold Edition
#
#                    Date                                             LineUp
# 0    10 September 2016      [Deep White, Adana Twins (Friso x Exploited) ]
# 1     27 February 2016             [Marc Houle, M-United, Sebastian Bosco]
# 2     07 November 2015                                 [Fritz Kalkbrenner]
# 3    26 September 2015          [Andrea Roma ,  David Kiesel,  Never Die ]
# 4    24 September 2015   [, [LINE UP], JR – (Le Jour Me Nuit /CH), Dris...
# 5          13 May 2015   [Dj Never Die (CH), Matador (IE), Sebastian Bo...
# 6        18 April 2015   [Sebastian Bosco, Several Definitions (Knee De...
# 7        28 March 2015   [Dj Never Die, Avrosse B2B Louie Cut, Sebastia...
# 8     07 February 2015   [David Kiesel, Patrik Soderbom (SWE), Sebastia...
# 9      18 October 2014   [ Jokari (Kartel Klub - CH), DJ W!ld (Circoloc...
# 10   13 September 2014                                             [Meggy]
# 11    20 February 2014   [ Jokari,  Chapkmace, Zombie Disco Squad,  Her...
# 12    20 February 2014   [ Jokari,  Chapkmace, Zombie Disco Squad,  Her...
# 13     18 January 2014   [ Cirkus,  Round Table Knights, Claptone,  Lem...
# 14    23 December 2013   [Joris Delacroix,  Krizzli,  Loïc Sottas,  La ...
# 15    20 December 2013   [Jonas Mantey,  Lucas Monème,  Max (Caprice Fe...
# 16     26 October 2013     [Adam Port,  Horasse,  Chapkmace,  Bitsculpter]
# 17     25 October 2013   [Mismatch, Viken Arman, Underclownd (Cookss B2...
# 18      24 August 2013                [Mercury,  Cirkus,  Jokari,  Herkul]
# 19        01 June 2013                                     [The Cruzaders]
# 20         18 May 2013                [ Krizzli,  Jokari, HNQO,  Lemonick]
# 21       27 April 2013                     [Bakermat,  Jokari,  Deepwhite]
# 22       31 March 2013   [ Deepwhite,  Jokari,  Lucas Monème,  Herkul, ...
# 23       23 March 2013                  [ Denz,  Cirkus, Kartell,  Herkul]
# 24    23 February 2013         [Doctor Dru,  Jokari,  Chapkmace,  Krizzli]
# 25    23 December 2012                   [Lemonick,  Jokari,  Bitsculpter]
# 26    17 November 2012                                     [The Cruzaders]
# 27        02 June 2012                                     [The Cruzaders]
# 28       08 April 2012                                     [The Cruzaders]
# 29   29 September 2011                            [- Chapkmace, - Riotboy]
# 30   02 September 2011   [- Cirkus, - Chapkmace, - Congorock, - Round T...
# 31        25 June 2011                        [DJ Gemini, Kooz, D'Jamency]
# 32       23 April 2011                                     [The Cruzaders]
# 33       16 April 2011                                        [Gaty Lopez]
# 34    19 February 2011                                   [Jeremy De Koste]
# 35    13 November 2010                                     [The Cruzaders]
# 36   17 September 2010                                     [The Cruzaders]
# 37      28 August 2010      [- Meda (Neverending), - Djamency, - Mekanics]
# 38       24 April 2010                                     [The Cruzaders]
# 39     26 January 2008   [- Kate Wax (Mental Groove – Output) °Live, - ...

# %% [markdown]
# ## Creating CSV files for all dataframes of clubs

# %%
start = 0
total = len(clubDF.values)-start
i = 0

for d in clubDF.values[start:]:
    #Get Event Dataframe for this index
    index = d[0]
    df = getEventsFrom(index)
    #Add Columns Name and Adress
    df['ClubName'] = d[1]
    df['Address'] = d[2]
    #Reformat Dataframe
    df = df[['clubID','place','address','eventID','event','date','artists']]
    file_name = d[1]
    file_name = file_name.replace(u"/"," ").replace(u"*"," ")
    file_name = d[0]+"-"+file_name
    
    #Save as CSV
    try:
        df.to_csv('ClubData'+str(i%4)+'/'+file_name+".csv",sep ='\t', encoding='utf-8')
    except:
        print("ERROR AT INDEX"+str(i)+", index "+str(intdex)+", file_name = "+str(file_name))
    #console output
    i = i+1
    print(str(i)+"/"+str(total))
# Out:
# 1/1314
# 2/1314
# 3/1314
# 4/1314
# 5/1314
# 6/1314
# 7/1314
# 8/1314
# 9/1314
# 10/1314
# 11/1314
# 12/1314
# 13/1314
# 14/1314
# 15/1314
# 16/1314

# %%
#Testing load
lo = pd.read_csv('ClubData/'+file_name+".csv", sep='\t', index_col=0)
lo['Address']

# %%
print(clubDF.values[430])
