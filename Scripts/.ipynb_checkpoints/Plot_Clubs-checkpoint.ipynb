# %% [markdown]
# # Plotting on the Map

# %% [markdown]
# 1. Create Dataframe of the clubs

# %%
GOOGLE_API_KEY = "AIzaSyBHFQP-QhcaV7CG7o7-FLacHtlE0YI_E1E"

# %%
import glob
import numpy as np
import pandas as pd
import json
import requests

files = []
files = glob.glob("ClubData0/*.csv")+glob.glob("ClubData1/*.csv")+glob.glob("ClubData2/*.csv")+glob.glob("ClubData3/*.csv")
print(len(files))
ClubDataFrame = pd.read_csv(files[0],sep="\t")

for file in files:
    df= pd.read_csv(file,sep ="\t")
    ClubDataFrame = ClubDataFrame.append(df,ignore_index = True)
    
print(ClubDataFrame.shape)
ClubDataFrame.head(10)
# Out:
# 1312
# (10069, 8)
#    Unnamed: 0    ClubID        ClubName  \
# 0         0.0  100121.0      Cyclo Café
# 1         1.0  100121.0      Cyclo Café
# 2         2.0  100121.0      Cyclo Café
# 3         0.0  100121.0      Cyclo Café
# 4         1.0  100121.0      Cyclo Café
# 5         2.0  100121.0      Cyclo Café
# 6         0.0   10186.0   Rocking Chair
# 7         1.0   10186.0   Rocking Chair
# 8         2.0   10186.0   Rocking Chair
# 9         0.0  102059.0    Acapella Bar
#
#                                         Address   EventID  \
# 0            Boulevard de Pérolles 91, Fribourg  707619.0
# 1            Boulevard de Pérolles 91, Fribourg  673119.0
# 2            Boulevard de Pérolles 91, Fribourg  672938.0
# 3            Boulevard de Pérolles 91, Fribourg  707619.0
# 4            Boulevard de Pérolles 91, Fribourg  673119.0
# 5            Boulevard de Pérolles 91, Fribourg  672938.0
# 6            Avenue de Gilamont 60; 1800, Vevey  365245.0
# 7            Avenue de Gilamont 60; 1800, Vevey  284885.0
# 8            Avenue de Gilamont 60; 1800, Vevey   49151.0
# 9  Place de la Gare, 1957 Ardon, Valais, Suisse  693409.0
#
#                                            EventName                Date  \
# 0  Light My Fridays: with Ariane Effect, DJ H-ERA...      10 April 2015
# 1                    Chris Ahn's 4AM Mixtape - Ep. 4   14 November 2014
# 2                Chris Ahn's 4AM Mixtape - Episode 1        16 May 2014
# 3  Light My Fridays: with Ariane Effect, DJ H-ERA...      10 April 2015
# 4                    Chris Ahn's 4AM Mixtape - Ep. 4   14 November 2014
# 5                Chris Ahn's 4AM Mixtape - Episode 1        16 May 2014
# 6                        Hacienda 30th Birthday Tour        05 May 2012
# 7                                Black & White Party       30 June 2010
# 8                                       Jamie Lidell      23 April 2008
# 9                          The Future Color Of Sound      17 April 2015
#
#                                               LineUp
# 0         ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 1                                      ['Chris Ahn']
# 2                                      ['Chris Ahn']
# 3         ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 4                                      ['Chris Ahn']
# 5                                      ['Chris Ahn']
# 6  ['', ' New Order) >>>Andrew Weatherall (Two Lo...
# 7                                       ['Lemonick']
# 8                                   ['Jamie Lidell']
# 9        ['Dj Never Die', 'Jack Demon', 'Vitronic ']

# %%
ClubDataFrame[ClubDataFrame.Address.isnull()]
# Out:
#        Unnamed: 0   ClubID            ClubName Address   EventID  \
# 1111          0.0  41096.0     Uber Naturapura     NaN  334841.0
# 1112          1.0  41096.0     Uber Naturapura     NaN  310686.0
# 1113          2.0  41096.0     Uber Naturapura     NaN  270162.0
# 1114          3.0  41096.0     Uber Naturapura     NaN  247665.0
# 1115          4.0  41096.0     Uber Naturapura     NaN  225559.0
# 1116          5.0  41096.0     Uber Naturapura     NaN   70634.0
# 1662          0.0   6613.0   Streets of Zurich     NaN  866903.0
# 1663          1.0   6613.0   Streets of Zurich     NaN  860048.0
# 1664          2.0   6613.0   Streets of Zurich     NaN  727062.0
# 1665          3.0   6613.0   Streets of Zurich     NaN  749500.0
# 1666          4.0   6613.0   Streets of Zurich     NaN  619561.0
# 1667          5.0   6613.0   Streets of Zurich     NaN  389979.0
# 1668          6.0   6613.0   Streets of Zurich     NaN  112168.0
# 1669          7.0   6613.0   Streets of Zurich     NaN   99417.0
# 1670          8.0   6613.0   Streets of Zurich     NaN   61790.0
# 1671          9.0   6613.0   Streets of Zurich     NaN   32350.0
# 1672         10.0   6613.0   Streets of Zurich     NaN   27129.0
# 3781          0.0  41096.0     Uber Naturapura     NaN  334841.0
# 3782          1.0  41096.0     Uber Naturapura     NaN  310686.0
# 3783          2.0  41096.0     Uber Naturapura     NaN  270162.0
# 3784          3.0  41096.0     Uber Naturapura     NaN  247665.0
# 3785          4.0  41096.0     Uber Naturapura     NaN  225559.0
# 3786          5.0  41096.0     Uber Naturapura     NaN   70634.0
# 4353          0.0   6613.0   Streets of Zurich     NaN  866903.0
# 4354          1.0   6613.0   Streets of Zurich     NaN  860048.0
# 4355          2.0   6613.0   Streets of Zurich     NaN  727062.0
# 4356          3.0   6613.0   Streets of Zurich     NaN  749500.0
# 4357          4.0   6613.0   Streets of Zurich     NaN  619561.0
# 4358          5.0   6613.0   Streets of Zurich     NaN  389979.0
# 4359          6.0   6613.0   Streets of Zurich     NaN  112168.0
# 4360          7.0   6613.0   Streets of Zurich     NaN   99417.0
# 4361          8.0   6613.0   Streets of Zurich     NaN   61790.0
# 4362          9.0   6613.0   Streets of Zurich     NaN   32350.0
# 4363         10.0   6613.0   Streets of Zurich     NaN   27129.0
# 7468          0.0   9864.0               Shark     NaN   46928.0
# 10049         0.0   9864.0               Shark     NaN   46928.0
#
#                                                EventName                 Date  \
# 1111                                                 K36       24 March 2012
# 1112                         Bizeligeburitanzen Mit Hugo    19 November 2011
# 1113                          Bizeliafter Ar Natura Pura      21 August 2011
# 1114                                         Dolce, Sisi       09 April 2011
# 1115                Bizeligeburi vor Natura Pura Zum 5te    12 February 2011
# 1116                       Naturapura - Bern / Gäbelbach    02 November 2008
# 1662                           Hvitling at Street Parade      13 August 2016
# 1663                        Street Parade Zürich - Olymp      13 August 2016
# 1664             Mimmo and Friends - Streetparade Zurich   29 September 2015
# 1665                            Sonidy on The Lovemobile      27 August 2015
# 1666                     Love Mobile Vo Züri, Für Züri 2      02 August 2014
# 1667                    Street Parade 2012 - Kongreshaus      11 August 2012
# 1668               Street Parade 2009 - Official Line Up      08 August 2009
# 1669        Streetparade 2009 Boyz Don't Cry Love Mobile      08 August 2009
# 1670                                Zurich Street Parade      09 August 2008
# 1671                                           Flugstund     28 October 2007
# 1672                                Zürich Street Parade      11 August 2007
# 3781                                                 K36       24 March 2012
# 3782                         Bizeligeburitanzen Mit Hugo    19 November 2011
# 3783                          Bizeliafter Ar Natura Pura      21 August 2011
# 3784                                         Dolce, Sisi       09 April 2011
# 3785                Bizeligeburi vor Natura Pura Zum 5te    12 February 2011
# 3786                       Naturapura - Bern / Gäbelbach    02 November 2008
# 4353                           Hvitling at Street Parade      13 August 2016
# 4354                        Street Parade Zürich - Olymp      13 August 2016
# 4355             Mimmo and Friends - Streetparade Zurich   29 September 2015
# 4356                            Sonidy on The Lovemobile      27 August 2015
# 4357                     Love Mobile Vo Züri, Für Züri 2      02 August 2014
# 4358                    Street Parade 2012 - Kongreshaus      11 August 2012
# 4359               Street Parade 2009 - Official Line Up      08 August 2009
# 4360        Streetparade 2009 Boyz Don't Cry Love Mobile      08 August 2009
# 4361                                Zurich Street Parade      09 August 2008
# 4362                                           Flugstund     28 October 2007
# 4363                                Zürich Street Parade      11 August 2007
# 7468   No Ny A One Night Show By Art Group Klat with ...       13 March 2008
# 10049  No Ny A One Night Show By Art Group Klat with ...       13 March 2008
#
#                                                   LineUp
# 1111                                         ['Paul Eg']
# 1112   [' Mastra .................', ' Bang Goes', 'R...
# 1113   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 1114      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 1115   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 1116   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 1662                                        ['Hvitling']
# 1663   [' MYKE', ' DANI FABREGA', ' DEYAN', ' INTRESS...
# 1664   ['Mirco Esposito', 'George Lamell', 'Steven St...
# 1665   ['Steven Davis', 'MAXXDRUMS', 'Tito Torres', '...
# 1666   [' Danny Coleman', ' Alex Austin', ' Coast', '...
# 1667   ['21.30 Sir Collin', '13.00 Dj Phala', '22.45 ...
# 1668   ['', '14:30 – 16:00 Stimming', '14:00 – 15:30 ...
# 1669   [" Maho & Jackin (Boyz Don't Cry)", " Tonic & ...
# 1670   ['', 'Playlove/81 (D/CH)', 'One:Shot:Ochestra ...
# 1671   [' Chris de Rebel', 'Gleichschritt', ' Tomy Gi...
# 1672   ['', '14.00-15.00 Sander van Doorn (NL)', 'Lim...
# 3781                                         ['Paul Eg']
# 3782   [' Mastra .................', ' Bang Goes', 'R...
# 3783   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 3784      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 3785   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 3786   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 4353                                        ['Hvitling']
# 4354   [' MYKE', ' DANI FABREGA', ' DEYAN', ' INTRESS...
# 4355   ['Mirco Esposito', 'George Lamell', 'Steven St...
# 4356   ['Steven Davis', 'MAXXDRUMS', 'Tito Torres', '...
# 4357   [' Danny Coleman', ' Alex Austin', ' Coast', '...
# 4358   ['21.30 Sir Collin', '13.00 Dj Phala', '22.45 ...
# 4359   ['', '14:30 – 16:00 Stimming', '14:00 – 15:30 ...
# 4360   [" Maho & Jackin (Boyz Don't Cry)", " Tonic & ...
# 4361   ['', 'Playlove/81 (D/CH)', 'One:Shot:Ochestra ...
# 4362   [' Chris de Rebel', 'Gleichschritt', ' Tomy Gi...
# 4363   ['', '14.00-15.00 Sander van Doorn (NL)', 'Lim...
# 7468   ['', 'Peter Stoffel & Cobeia > Electronic boog...
# 10049  ['', 'Peter Stoffel & Cobeia > Electronic boog...

# %% [markdown]
# ### Adding informations

# %% [markdown]
# We need to add some informations, such as the location of the club, and parsing the date.

# %%
#Adding location of the "club"
def getLocation(clubName,dictionnary =None,SwissSafety=True):
    '''Returns the location of the club with a tuple (lat,lng)'''
    
    location = None
    lat = None
    lng = None
    
    if(dictionnary != None and (clubName in dictionnary)):
        return dictionnary[clubName],dictionnary
    else:
        if(location==None): #Try with geoCodeAPI
            baseURL1 = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
            try:
                location = getFromAPI(clubName,baseURL1)
            except:
                location = None
            
        if(location==None): #Try with textSearchAPI
            baseURL2 = 'https://maps.googleapis.com/maps/api/geocode/json'
            try:
                location = getFromAPI(clubName,baseURL2)
            except:
                location = None
            
        if(location == None): #Try usingAddressAPI
            #Try with address 
            address = getAddress(clubName)
            if(address!=None):
                (lat,lng) = getLocation(address)
            
        else:
            #print("location is "+str(location))
            if(location!="ERROR"):
                lat = location['lat']
                lng = location['lng']
            else:
                lat = "ERROR"
                lng = "ERROR"
        
        #Checks if the club is in Switzerland
        if(SwissSafety and lat!=None and lng!=None):
            if(lng<5.7 or lng>10.73 or lat<45.6 or lat>47.9):
                #Out of Switzerland
                print("out of bounds")
                (lat,lng) = getLocation(clubName+", Switzerland")
            
        if(dictionnary!=None):
            dictionnary.update({clubName : (lat,lng)})
            return (lat,lng),dictionnary

    return (lat,lng)

# %%
def getFromAPI(clubName,baseURL):
    param={}
    if("geocode" in baseURL):
        param = {'address': str(clubName),
             'region':'ch',
             'key': GOOGLE_API_KEY}
    else:
        param = {'query': str(clubName),
                 #'keyword':'Switzerland',
                 'key': GOOGLE_API_KEY}
    
    #baseURL = 'https://maps.googleapis.com/maps/api/geocode/json' #Get JSON for Geocode
    content = json.loads(requests.get(baseURL, params = param).text)
    
    if('error_message' in content):
        raise Exception()
    
    location = None
    if(len(content['results'])>0):
        location = content['results'][0]['geometry']['location']
        #print("ContentFound:"+str(location))
    
    return location

# %%
def getAddress(address,count=1):
    count = count-1
    #print(address)
    '''Returns the address of the club with a tuple'''
    param = {'address': str(address),
             'region':'ch',
             'key': GOOGLE_API_KEY}
    
    baseURL = 'https://maps.googleapis.com/maps/api/geocode/json' #Get JSON for Geocode
    content = json.loads(requests.get(baseURL, params = param).text)
    addressRes = None
    
    if(len(content['results'])>0):
        addressRes = content['results'][0]['formatted_address']
        print("result using geocode")
    else:
        #print("No result using geocode")
    #If no results, try another API to find the postal code and retry.
        param2 = {'query': str(address),
                 'key': GOOGLE_API_KEY}    

        baseURL2 = 'https://maps.googleapis.com/maps/api/place/textsearch/json'

        content2 = json.loads(requests.get(baseURL2, params = param2).text)
        if(len(content2['results'])>0):
            addressRes = content2['results'][0]['formatted_address']
            print("result using textsearch")
        #else:
            #print("No result using TextSearch and GeoCode")

    #if(addressRes!=None and "Switzerland" not in addressRes[1:]):
        if(addressRes==None and count>=0):
            addressRes = getAddress(str(address)+", Switzerland",count)
        else:
            #print("No results but : "+str(addressRes))
            return addressRes
    
    return addressRes

# %%
indices = list(ClubDataFrame[ClubDataFrame.Address.isnull()].index)
dicname = {}

for indice in indices:
    name = ClubDataFrame[ClubDataFrame.index == indice]["ClubName"]
    if(name.values[0] not in dicname):
        dicname.update({name.values[0]:getAddress(name)})
    address = dicname[name.values[0]]
    ClubDataFrame.loc[ClubDataFrame.index == indice,"Address"] = address
    
ClubDataFrame[ClubDataFrame.Address.isnull()]
# Out:
# result using geocode
#        Unnamed: 0   ClubID          ClubName Address   EventID  \
# 1111          0.0  41096.0   Uber Naturapura    None  334841.0
# 1112          1.0  41096.0   Uber Naturapura    None  310686.0
# 1113          2.0  41096.0   Uber Naturapura    None  270162.0
# 1114          3.0  41096.0   Uber Naturapura    None  247665.0
# 1115          4.0  41096.0   Uber Naturapura    None  225559.0
# 1116          5.0  41096.0   Uber Naturapura    None   70634.0
# 3781          0.0  41096.0   Uber Naturapura    None  334841.0
# 3782          1.0  41096.0   Uber Naturapura    None  310686.0
# 3783          2.0  41096.0   Uber Naturapura    None  270162.0
# 3784          3.0  41096.0   Uber Naturapura    None  247665.0
# 3785          4.0  41096.0   Uber Naturapura    None  225559.0
# 3786          5.0  41096.0   Uber Naturapura    None   70634.0
# 7468          0.0   9864.0             Shark    None   46928.0
# 10049         0.0   9864.0             Shark    None   46928.0
#
#                                                EventName                Date  \
# 1111                                                 K36      24 March 2012
# 1112                         Bizeligeburitanzen Mit Hugo   19 November 2011
# 1113                          Bizeliafter Ar Natura Pura     21 August 2011
# 1114                                         Dolce, Sisi      09 April 2011
# 1115                Bizeligeburi vor Natura Pura Zum 5te   12 February 2011
# 1116                       Naturapura - Bern / Gäbelbach   02 November 2008
# 3781                                                 K36      24 March 2012
# 3782                         Bizeligeburitanzen Mit Hugo   19 November 2011
# 3783                          Bizeliafter Ar Natura Pura     21 August 2011
# 3784                                         Dolce, Sisi      09 April 2011
# 3785                Bizeligeburi vor Natura Pura Zum 5te   12 February 2011
# 3786                       Naturapura - Bern / Gäbelbach   02 November 2008
# 7468   No Ny A One Night Show By Art Group Klat with ...      13 March 2008
# 10049  No Ny A One Night Show By Art Group Klat with ...      13 March 2008
#
#                                                   LineUp
# 1111                                         ['Paul Eg']
# 1112   [' Mastra .................', ' Bang Goes', 'R...
# 1113   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 1114      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 1115   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 1116   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 3781                                         ['Paul Eg']
# 3782   [' Mastra .................', ' Bang Goes', 'R...
# 3783   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 3784      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 3785   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 3786   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 7468   ['', 'Peter Stoffel & Cobeia > Electronic boog...
# 10049  ['', 'Peter Stoffel & Cobeia > Electronic boog...

# %% [markdown]
# There is still some clubs without an address. We can drop them.

# %%
ClubDataFrame = ClubDataFrame[~ClubDataFrame.Address.isnull()]

# %%
dic={}
print(getLocation("Zone Industrielle du Verdel, Route de l'Étang 21, 1630 Bulle, Switzerland"))
# Out:
# (46.6263926, 7.066865399999999)

# %%
a = getAddress("Globull")
print(a)
# Out:
# result using textsearch
# Zone Industrielle du Verdel, Route de l'Étang 21, 1630 Bulle, Switzerland

# %% [markdown]
# ### Adding the location

# %%
import datetime
def computeDictionaryOfLocations(df,debug=False):
    '''Map each club to a location'''
    dictionary = {}
    allClubs = set(df["Address"])
    nbClubs = len(allClubs)
    i = 0
    
    
    #Computing dictionnary
    if(debug):
        print("NbClubs : "+str(nbClubs))
        print("Begin mapping...")
    bTime = datetime.datetime.now()
    estimate = 123456
    
    for c in allClubs:
        locC = getLocation(c,dictionary)
        if(locC!=None):
            dictionary.update({c : locC[0]})
        else:
            dictionary.update({c : locC})
            
        if(debug and i%30==1):
            delta = datetime.datetime.now()-bTime
            estimate = (nbClubs-i)*delta/30
            timeLeft = bTime+estimate-datetime.datetime.now()
            print("{nb}/{to}, time left = {t}".format(nb = i, to = nbClubs, t=timeLeft))
            bTime = datetime.datetime.now()
        i = i+1

        
    if(debug):
        print("Computation finished!")
    return dictionary

# %%
#dic = computeDictionaryOfLocations(ClubDataFrame,debug=True)

# %%
def saveDictionary(dic, filename):
    outfile = open('ClubDataGeo/'+filename+'.txt', 'w' )
    for key, value in sorted( dic.items() ):
        outfile.write( str(key) + '\t' + str(value) + '\n' )

# %%
def loadDictionary(filename):
    inp = open('ClubDataGeo/'+filename+'.txt', 'r' )
    dic = {}
    for l in inp:
        line = inp.readline()
        s = line.split("\t")
        if(len(s)>1):
            s[1] = s[1].replace("\n","")
            dic.update({s[0]:s[1]})
        else:
            print(s)
    return dic

# %%
dic = loadDictionary("ClubsGeo")
a = dic.get("Lagerplatz 18; 8400, Winterthur")
print(a)
# Out:
# (47.49477690000001, 8.717943900000002)

# %% [raw]
# def locate(s,dictionary):
#     try:
#         if(dictionary == None):
#             print("NONE ")
#         (lat,lng) = dictionary.get(str(s["Address"]))
#         return (lat,lng)
#     except Exception as e:
#         print(e)
#         print("except : "+str(s["Address"]))
#         (lat,lng) = getLocation(s["Address"])
#
#     return (lat,lng)
#
# ClubDataFrame["Location"] = ClubDataFrame.apply(locate,args=(dic,),axis=1)
# ClubDataFrame

# %%
a = dic.get("Cyclo Café")
print(a)
# Out:
# None

# %%
ClubDataFrame.head()
# Out:
#    Unnamed: 0    ClubID     ClubName                             Address  \
# 0         0.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 1         1.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 2         2.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 3         0.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 4         1.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
#
#     EventID                                          EventName  \
# 0  707619.0  Light My Fridays: with Ariane Effect, DJ H-ERA...
# 1  673119.0                    Chris Ahn's 4AM Mixtape - Ep. 4
# 2  672938.0                Chris Ahn's 4AM Mixtape - Episode 1
# 3  707619.0  Light My Fridays: with Ariane Effect, DJ H-ERA...
# 4  673119.0                    Chris Ahn's 4AM Mixtape - Ep. 4
#
#                  Date                                      LineUp
# 0      10 April 2015   ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 1   14 November 2014                                ['Chris Ahn']
# 2        16 May 2014                                ['Chris Ahn']
# 3      10 April 2015   ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 4   14 November 2014                                ['Chris Ahn']

# %% [raw]
# saveDictionary(dic,"ClubsGeoU")
# dic = loadDictionary("ClubsGeo")
#
# for i in ClubDataFrame.index:
#     addr = (ClubDataFrame[ClubDataFrame.index==i]["Address"]).values[0]
#     location = dic.get(addr)
#     if(location == None):
#         location = getLocation(addr)
#         dic.update({addr : location})
#         saveDictionary(dic,"ClubsGeoU")
#
#     #print(str(i)+";"+str(location))
#     ClubDataFrame.loc[ClubDataFrame.index==i,'Location'] = str(location)
#     #dic.get(ClubDataFrame[ClubDataFrame.index==i]["Address"])
#
# ClubDataFrame

# %% [markdown]
# ### Adding main genre for each event

# %%
ClubDataFrame = pd.read_csv("ClubDataGeo/ClubDataFrame.csv", encoding='utf-8')
ClubDataFrame = ClubDataFrame.drop_duplicates()

#Drop Useless columns
ClubDataFrame = ClubDataFrame.drop('Unnamed: 0', 1)
ClubDataFrame = ClubDataFrame.drop('Unnamed: 0.1', 1)
ClubDataFrame = ClubDataFrame.drop_duplicates()
ClubDataFrame.head(5)
# Out:
#      ClubID        ClubName                             Address   EventID  \
# 0  100121.0      Cyclo Café  Boulevard de Pérolles 91, Fribourg  707619.0
# 1  100121.0      Cyclo Café  Boulevard de Pérolles 91, Fribourg  673119.0
# 2  100121.0      Cyclo Café  Boulevard de Pérolles 91, Fribourg  672938.0
# 6   10186.0   Rocking Chair  Avenue de Gilamont 60; 1800, Vevey  365245.0
# 7   10186.0   Rocking Chair  Avenue de Gilamont 60; 1800, Vevey  284885.0
#
#                                            EventName                Date  \
# 0  Light My Fridays: with Ariane Effect, DJ H-ERA...      10 April 2015
# 1                    Chris Ahn's 4AM Mixtape - Ep. 4   14 November 2014
# 2                Chris Ahn's 4AM Mixtape - Episode 1        16 May 2014
# 6                        Hacienda 30th Birthday Tour        05 May 2012
# 7                                Black & White Party       30 June 2010
#
#                                               LineUp  \
# 0         ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 1                                      ['Chris Ahn']
# 2                                      ['Chris Ahn']
# 6  ['', ' New Order) >>>Andrew Weatherall (Two Lo...
# 7                                       ['Lemonick']
#
#                           Location
# 0          (46.7947773, 7.1568081)
# 1          (46.7947773, 7.1568081)
# 2          (46.7947773, 7.1568081)
# 6  (46.4720036, 6.852230199999998)
# 7  (46.4720036, 6.852230199999998)

# %%
import ArtistExtractor as AE

def getGenreByLineUp(s):
    LineUp = s['LineUp']
    listGenres = []
    for artist in LineUp:
        print(artist)
        genre = AE.getGenre(artist)
        if(a!=None):
            listGenres.append(genre)
        print(listGenres)
    
    return AE.getMaxGenre(listGenres)
        

def extractGenreFromLineUps(df):
    indices = df.index
    for i in indices:
        genre = getGenreByLineUp(df[df.index==i])
        #print(str(df[df.index==i])+" - "+ str(genre))
        #print(str(i)+";"+str(location))
        #ClubDataFrame.loc[ClubDataFrame.index==i,'Location'] = str(location)
    
extractGenreFromLineUps(ClubDataFrame)
# Out:
# ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# []
# ['Chris Ahn']
# []
# ['Chris Ahn']
# []
# ['', ' New Order) >>>Andrew Weatherall (Two Lone Swordsmen) >>>Darren Emerson (Detone', ' Underworld)<<<<<<<', '>>>>Peter Hook (Joy Division']
# []
# ['Lemonick']
# []
# ['Jamie Lidell']
# []
# ['Dj Never Die', 'Jack Demon', 'Vitronic ']
# []
# [' Christian Elefante', ' Emre', ' Valentin', ' Guel', 'Serafin']
# []
# [' Beppe Loda (Invisible City Editions)', ' Offen Music)', 'Vladimir Ivkovic (Salon Des Amateurs']
# []
# ['Lexx (ESP Institute', ' Permanent Vacation', ' Kejeblos (Phantom Island)', ' DFA)']
# []
# ['Jan Schulte', ' El Tigre Sound (zweikommasieben)', ' Wolf Müller', ' Bufiman']
# []
# ['Khidja']
# []
# ["Marc D'Arrigo", 'Herman', 'Daniele Cosmo']
# []
# ['Kaan Düzarat (FOC Edits/Istanbul)', ' Mehmet Aslan (Huntleys & Palmers/Berlin)', ' Moscoman (Correspondant/Tel Aviv)']
# []
# ['Dave Eleanor', 'Lord Kesseli & The Drums']
# []
# [' DJ Aunt One & Napoleton (Talen/Laserwolf)', ' Faber (Lux Rec)', 'Timothy J. Fairplay (Emotional Response)']
# []
# ['Alma Negra (Sofrito', ' Basic Fingers', ' Highlife)']
# []
# ['Lexx (Permanent Vacation)', ' Kejeblos (Phantom Island)']
# []
# [' Cosmo & Faber', 'Cold Colors (F)']
# []
# [' Tako & Jamie Tiller (Redlight Records', ' Lausanne)', ' Kejeblos (Phantom Islands)', ' Music From Memory / Amsterdam)', 'Larytta (Creaked Records', ' J. Sayne (Hum Records).']
# []
# ['DJ P-Tess', ' Faust (Bass Vandalizm).']
# []
# [' Daniele Cosmo', ' Fabio Riccio', 'Aurora Halal (Lovers Rock/Mutual Dreaming)']
# []
# [' Raban', ' Oscar Schubaq', " T'N'T", ' LichtDEFEKTE von Van Nutt.', 'Eli Verveine']
# []
# ['Twoets', 'LIVE: Alessandro Parisi (I)', 'D Cosmo']
# []
# ['James Pants (Stones Throw/USA)', 'J. Sayne (Hum-Records)', 'Kejeblos (Drumpoet)']
# []
# [' Malik', 'MTDF', ' Das Pferd  (live)']
# []
# ['', 'CCO', 'Echo 106', 'D Cosmo & Faber']
# []
# [' Das HOUSE)', 'TAF (Art Of Dark', 'Berber & Pasta (Lost Promises', 'Hermansson & Martinez (Schwerelos)', ' Baile Musik - DE)']
# []
# [' Beda', 'Manuell', ' Raban', ' P.Bell']
# []
# ['', ' Akt )', 'Christian Schiemann ( Sasso', "MALEKO'S BEUTEL & AMARU (Das House)"]
# []
# ['DJs: Nik!', ' P-Tess']
# []
# [' Playlove', ' Beda', 'hypnorex (Sportbridgade Sparwasser)', ' Wandler']
# []
# ['P.Bell', ' Beda', ' Idealist  (live)', ' Wicked Wilma']
# []
# [' Beda', 'Styro 2000', ' Goldoni']
# []
# [' Beda (DekaDance Zürich)', ' Marc Fuhrmann (Panthera Zürich)', 'Playlove (Engelreich München)', ' Mastra (Modularclub Bern)']
# []
# [' Beda', ' Rino', 'Live: Pitsch & Magnano', ' Fehlfunktion']
# []
# [' Beda (P45)', 'DJs Eli Verveine (scandal!)', ' Goldoni (Bitboutique)', ' Pochatz (Goldstaub)']
# []
# ['Caslau / Luke Haslau', 'Ikosa', 'Mafou', 'Mukuna', 'Clearvision', 'Ben Kaczor', 'Hund Koecket', 'Kombé']
# []
# ['Garçon', 'Cepheì', 'Hfs Dub', 'Trauminic']
# []
# ['', 'Gabriel Pellicano aka DJ Pellicano', 'Kaschemme Basel', 'DJ STEEL', ' Mark Lamski', 'DJ:', 'Edward Classen aka EDI "LE CHEF"', 'Drinks & Food:', 'Michel Mathis aka DJ Pun', 'Iyad El Qirinawi aka EL Q', 'Live:', 'BLACK TIGER Basel City (Official)', ' DJ Tray', ' Marc Hype ', ' DJ Moishe', 'Venti (Official)']
# []
# ['', 'Radio Ghost Town // Basel (CH)', 'Timnah Sommerfeldt', 'Benjah', 'TMSV', 'Dubhead // Istein (GER)', 'Subotagerecords / Density Radio X // Basel (CH)', 'Zecher', 'Artikal / Black Box // NL']
# []
# [' Krizzli', 'Kairo Is Koming']
# []
# ['Mala // Digital Mystikz (DMZ ) /// UK', 'Cutkachi // re:st // dubtopia /// Bern', 'Dj Montes // Goldfinger Brothers /// Basel', 'Zecher // Subotage Records // RadioX /// Basel']
# []
# [' Scott Kemp', ' Philippe', " Deep 'n Dub", 'Vinyl Speed Adjust']
# []
# ['RP Boo']
# []
# [' Aust', 'Chaos In The CBD', ' Aware']
# []
# ['Enzo Siragusa / Randall M / Chad Andrew / Hash Hendrex / Ferro / Kamran Sadeghi (live) ']
# []
# ['The Name Game', 'DJ Fett Burger', 'elias3O8']
# []
# ['Danny Faber', 'Elrino', 'Ayhasca Ernesto']
# []
# [' B.O.M.', ' Larry King', ' Prop&Lean', ' Getting Any?', 'Teki Latex', ' Ostbahnhof']
# []
# ['Bunte Bummler', ' Truce (aka Tolga Top & Max Albàn) ']
# []
# [' Zora Jones', 'Sinjin Hawke']
# []
# ['Roon', 'Lilith', 'Oliver K', 'Oscar Niczzo']
# []
# ['Frank Vespari ']
# []
# ['Davix', 'Valerio Raponi']
# []
# ["Gold N' Silver", 'Mucho Stylez']
# []
# ['P-Ben (KMS Records', 'Did Low (Helvet Underground) ', ' Elevated)', 'Paul Eg (KMS Records', ' Ovum', ' Time Has Changed)', ' Minimo Imprint']
# []
# ['Lee Webster (Gruuv', ' Time Has Changed) ', 'Jeff Swing (Plastic City)']
# []
# ['Tanua (Neopren Records)', 'Puma (Les Arts Minis)']
# []
# ['Lando (Clarisse Records) ', 'Central Rodeo (Chronovision Ibiza)']
# []
# ['Cab Drivers  (live) - (Highgrade', 'DJ Dub (Minimo Imprint)', ' Cabinet Records) ']
# []
# ['Gel Abril']
# []
# ['VAlpen aka Dachshund & Dave The Hustler (Clapper)']
# []
# ['Stassy (Watergate Records)', 'Paul Eg (KMS Records', ' Time Has Changed)', ' Minimo Imprint']
# []
# ['Azimute', 'Garance', 'LAD']
# []
# ['Nicolas Duvoisin ', 'Gel Abril ']
# []
# ['Ki.Mi. ', 'DJ Dub ']
# []
# ['Byzance', 'Magit Cacoon']
# []
# ['Dany Movida (La Chambre)', 'Daniel Branco (La Cmabre)']
# []
# ['TomTeeT ', 'Paul Eg', 'Wehbba ']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-91bbd38cec1a> in <module>()
#      22         #ClubDataFrame.loc[ClubDataFrame.index==i,'Location'] = str(location)
#      23
# ---> 24 extractGenreFromLineUps(ClubDataFrame)
#
# <ipython-input-27-91bbd38cec1a> in extractGenreFromLineUps(df)
#      17     indices = df.index
#      18     for i in indices:
# ---> 19         genre = getGenreByLineUp(df[df.index==i])
#      20         #print(str(df[df.index==i])+" - "+ str(genre))
#      21         #print(str(i)+";"+str(location))
#
# <ipython-input-27-91bbd38cec1a> in getGenreByLineUp(s)
#       6     for artist in LineUp:
#       7         print(artist)
# ----> 8         genre = AE.getGenre(artist)
#       9         if(a!=None):
#      10             listGenres.append(genre)
#
# C:\Users\Simon\Documents\EPFL\Master\Semestre1\Applied Data Analysis\SMM\Scripts\ArtistExtractor.py in getGenre(Artist, dictionnary, Year, debug)
#     190 	gets the most representative genre of the artist across time.'''
#     191         if(dictionnary==None):
# --> 192                 dictionnary = createDictionnary()
#     193
#     194         genres = getGenresFromSpotify(Artist)
#
# C:\Users\Simon\Documents\EPFL\Master\Semestre1\Applied Data Analysis\SMM\Scripts\ArtistExtractor.py in createDictionnary(debug)
#      69                                                 for a in groups:
#      70                                                         b = str(a)
# ---> 71                                                         soup2 = bs4.BeautifulSoup(b,"html5lib")
#      72                                                         if(len(soup2.text)>0 and soup2.text.count("\n")<2):
#      73                                                                 mainList.append(soup2.text)
#
# C:\Users\Simon\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     213             self.reset()
#     214             try:
# --> 215                 self._feed()
#     216                 break
#     217             except ParserRejectedMarkup:
#
# C:\Users\Simon\Anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     237         self.builder.reset()
#     238
# --> 239         self.builder.feed(self.markup)
#     240         # Close out any unfinished strings and close all the open tags.
#     241         self.endData()
#
# C:\Users\Simon\Anaconda3\lib\site-packages\bs4\builder\_html5lib.py in feed(self, markup)
#      48             warnings.warn("You provided a value for parse_only, but the html5lib tree builder doesn't support parse_only. The entire document will be parsed.")
#      49         parser = html5lib.HTMLParser(tree=self.create_treebuilder)
# ---> 50         doc = parser.parse(markup, encoding=self.user_specified_encoding)
#      51
#      52         # Set the character encoding detected by the tokenizer.
#
# C:\Users\Simon\Anaconda3\lib\site-packages\html5lib\html5parser.py in parse(self, stream, encoding, parseMeta, useChardet)
#     234         """
#     235         self._parse(stream, innerHTML=False, encoding=encoding,
# --> 236                     parseMeta=parseMeta, useChardet=useChardet)
#     237         return self.tree.getDocument()
#     238
#
# C:\Users\Simon\Anaconda3\lib\site-packages\html5lib\html5parser.py in _parse(self, stream, innerHTML, container, encoding, parseMeta, useChardet, **kwargs)
#      92         while True:
#      93             try:
# ---> 94                 self.mainLoop()
#      95                 break
#      96             except ReparseException:
#
# C:\Users\Simon\Anaconda3\lib\site-packages\html5lib\html5parser.py in mainLoop(self)
#     164         ParseErrorToken = tokenTypes["ParseError"]
#     165
# --> 166         for token in self.normalizedTokens():
#     167             new_token = token
#     168             while new_token is not None:
#
# C:\Users\Simon\Anaconda3\lib\site-packages\html5lib\html5parser.py in normalizedTokens(self)
#     220
#     221     def normalizedTokens(self):
# --> 222         for token in self.tokenizer:
#     223             yield self.normalizeToken(token)
#     224
#
# C:\Users\Simon\Anaconda3\lib\site-packages\html5lib\tokenizer.py in __iter__(self)
#      65         # Start processing. When EOF is reached self.state will return False
#      66         # instead of True and the loop will terminate.
# ---> 67         while self.state():
#      68             while self.stream.errors:
#      69                 yield {"type": tokenTypes["ParseError"], "data": self.stream.errors.pop(0)}
#
# C:\Users\Simon\Anaconda3\lib\site-packages\html5lib\tokenizer.py in dataState(self)
#     250     # Below are the various tokenizer states worked out.
#     251     def dataState(self):
# --> 252         data = self.stream.char()
#     253         if data == "&":
#     254             self.state = self.entityDataState
#
# C:\Users\Simon\Anaconda3\lib\site-packages\html5lib\inputstream.py in char(self)
#     252         chunkOffset = self.chunkOffset
#     253         char = self.chunk[chunkOffset]
# --> 254         self.chunkOffset = chunkOffset + 1
#     255
#     256         return char
#
# KeyboardInterrupt:

# %%
AE.getGenre("Nicolas Duvoisin")

# %% [markdown]
# ### Grouping by date

# %% [markdown]
# ## <font color='red'> TODO </font color>

# %%
ClubDataFrame.to_csv("ClubDataGeo/ClubDataFrame.csv", encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-20-2f64bfdffe1f> in <module>()
# ----> 1 ClubDataFrame.to_csv("ClubDataGeo/ClubDataFrame.csv", encoding='utf-8')
#
# C:\Users\Simon\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal, **kwds)
#    1342                                      doublequote=doublequote,
#    1343                                      escapechar=escapechar, decimal=decimal)
# -> 1344         formatter.save()
#    1345
#    1346         if path_or_buf is None:
#
# C:\Users\Simon\Anaconda3\lib\site-packages\pandas\formats\format.py in save(self)
#    1524             f = _get_handle(self.path_or_buf, self.mode,
#    1525                             encoding=self.encoding,
# -> 1526                             compression=self.compression)
#    1527             close = True
#    1528
#
# C:\Users\Simon\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path, mode, encoding, compression)
#     420         if compat.PY3:
#     421             if encoding:
# --> 422                 f = open(path, mode, encoding=encoding)
#     423             else:
#     424                 f = open(path, mode, errors='replace')
#
# PermissionError: [Errno 13] Permission denied: 'ClubDataGeo/ClubDataFrame.csv'

# %% [markdown]
# We need to group by date in order to get an evolution by year.
