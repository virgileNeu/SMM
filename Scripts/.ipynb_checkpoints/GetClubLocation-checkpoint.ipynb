# %% [markdown]
# # Plotting on the Map

# %% [markdown]
# 1. Create Dataframe of the clubs

# %%
import glob
import numpy as np
import pandas as pd
import json
import requests
import ArtistExtractor as AE

#place 	address 	location 	event 	date 	artists 	genre 	coordinates
a = pd.read_csv("ClubData/TestClubData.csv")
a
# Out:
#     Unnamed: 0  Unnamed: 0.1                     place  \
# 0            0             0   2. Akt Restaurant & Bar
# 1            1             1   2. Akt Restaurant & Bar
# 2            2             2   2. Akt Restaurant & Bar
# 3            3             3   2. Akt Restaurant & Bar
# 4            4             4   2. Akt Restaurant & Bar
# 5            5             5   2. Akt Restaurant & Bar
# 6            6             6   2. Akt Restaurant & Bar
# 7            7             7   2. Akt Restaurant & Bar
# 8            8             8   2. Akt Restaurant & Bar
# 9            9             9   2. Akt Restaurant & Bar
# 10          10            10   2. Akt Restaurant & Bar
# 11          11            11   2. Akt Restaurant & Bar
# 12          12            12   2. Akt Restaurant & Bar
# 13          13            13   2. Akt Restaurant & Bar
# 14          14            14   2. Akt Restaurant & Bar
# 15          15            15   2. Akt Restaurant & Bar
# 16          16            16   2. Akt Restaurant & Bar
# 17          17             0   2. Akt Restaurant & Bar
# 18          18             1   2. Akt Restaurant & Bar
# 19          19             2   2. Akt Restaurant & Bar
# 20          20             3   2. Akt Restaurant & Bar
# 21          21             4   2. Akt Restaurant & Bar
# 22          22             5   2. Akt Restaurant & Bar
# 23          23             6   2. Akt Restaurant & Bar
# 24          24             7   2. Akt Restaurant & Bar
# 25          25             8   2. Akt Restaurant & Bar
# 26          26             9   2. Akt Restaurant & Bar
# 27          27            10   2. Akt Restaurant & Bar
# 28          28            11   2. Akt Restaurant & Bar
# 29          29            12   2. Akt Restaurant & Bar
# 30          30            13   2. Akt Restaurant & Bar
# 31          31            14   2. Akt Restaurant & Bar
# 32          32            15   2. Akt Restaurant & Bar
# 33          33            16   2. Akt Restaurant & Bar
# 34          34             0     25 Hours Hotel Zürich
# 35          35             1     25 Hours Hotel Zürich
#
#                                 address  location  \
# 0                       Selnaustrasse 2       NaN
# 1                       Selnaustrasse 2       NaN
# 2                       Selnaustrasse 2       NaN
# 3                       Selnaustrasse 2       NaN
# 4                       Selnaustrasse 2       NaN
# 5                       Selnaustrasse 2       NaN
# 6                       Selnaustrasse 2       NaN
# 7                       Selnaustrasse 2       NaN
# 8                       Selnaustrasse 2       NaN
# 9                       Selnaustrasse 2       NaN
# 10                      Selnaustrasse 2       NaN
# 11                      Selnaustrasse 2       NaN
# 12                      Selnaustrasse 2       NaN
# 13                      Selnaustrasse 2       NaN
# 14                      Selnaustrasse 2       NaN
# 15                      Selnaustrasse 2       NaN
# 16                      Selnaustrasse 2       NaN
# 17                      Selnaustrasse 2       NaN
# 18                      Selnaustrasse 2       NaN
# 19                      Selnaustrasse 2       NaN
# 20                      Selnaustrasse 2       NaN
# 21                      Selnaustrasse 2       NaN
# 22                      Selnaustrasse 2       NaN
# 23                      Selnaustrasse 2       NaN
# 24                      Selnaustrasse 2       NaN
# 25                      Selnaustrasse 2       NaN
# 26                      Selnaustrasse 2       NaN
# 27                      Selnaustrasse 2       NaN
# 28                      Selnaustrasse 2       NaN
# 29                      Selnaustrasse 2       NaN
# 30                      Selnaustrasse 2       NaN
# 31                      Selnaustrasse 2       NaN
# 32                      Selnaustrasse 2       NaN
# 33                      Selnaustrasse 2       NaN
# 34  Pfingstweidstrasse 102, 8005 Zürich       NaN
# 35  Pfingstweidstrasse 102, 8005 Zürich       NaN
#
#                                             event        date  \
# 0                         Deeptown Music Showcase  2017-01-29
# 1                                    Mucho Stylez  2017-01-29
# 2                                   Mucho Stylez   2017-01-29
# 3                                     Zweiter Akt  2017-01-29
# 4                                  Deeptown Night  2017-01-29
# 5                                  Deeptown Night  2017-01-29
# 6                       Tonka UND 3333 Tage Saxer  2017-01-29
# 7                                  Deeptown Night  2017-01-29
# 8                                 Deeptown Parade  2017-01-29
# 9                            Deeptown Music Night  2017-01-29
# 10   Deeptown Music Night Featuring Niall Redmond  2017-01-29
# 11                Deeptown Music Night Pres. Anëk  2017-01-29
# 12                           Deeptown Music Night  2017-01-29
# 13                           Deeptown Music Night  2017-01-29
# 14                  Party Rolf Feat. Steven Stone  2017-01-29
# 15                           Deeptown Music Night  2017-01-29
# 16               5 Years Place 2 Be - Akt Edition  2017-01-29
# 17                        Deeptown Music Showcase  2017-01-29
# 18                                   Mucho Stylez  2017-01-29
# 19                                  Mucho Stylez   2017-01-29
# 20                                    Zweiter Akt  2017-01-29
# 21                                 Deeptown Night  2017-01-29
# 22                                 Deeptown Night  2017-01-29
# 23                      Tonka UND 3333 Tage Saxer  2017-01-29
# 24                                 Deeptown Night  2017-01-29
# 25                                Deeptown Parade  2017-01-29
# 26                           Deeptown Music Night  2017-01-29
# 27   Deeptown Music Night Featuring Niall Redmond  2017-01-29
# 28                Deeptown Music Night Pres. Anëk  2017-01-29
# 29                           Deeptown Music Night  2017-01-29
# 30                           Deeptown Music Night  2017-01-29
# 31                  Party Rolf Feat. Steven Stone  2017-01-29
# 32                           Deeptown Music Night  2017-01-29
# 33               5 Years Place 2 Be - Akt Edition  2017-01-29
# 34                      De Mes Amis Welcomes Guti  2017-01-29
# 35  Lange Nacht der Hotelbars + der Sonntag Dazu.  2017-01-29
#
#                                               artists  genre  coordinates
# 0                         ['Mark Faermont', 'Affani']    NaN          NaN
# 1                                    ['Mucho Stylez']    NaN          NaN
# 2                                    ['Mucho Stylez']    NaN          NaN
# 3                                    ['Mucho Stylez']    NaN          NaN
# 4                    [' Sonny Dima', 'Mark Faermont']    NaN          NaN
# 5                  ['Carlos Russo', ' Mark Faermont']    NaN          NaN
# 6       ['Tonka', ' Mark Faermont', ' Danny Coleman']    NaN          NaN
# 7                      ['Carlos Russo', ' David Eye']    NaN          NaN
# 8   [' Niall Redmond', ' Mark Faermont', 'Elektros...    NaN          NaN
# 9                   [' DJ Le Baron', 'Mark Faermont']    NaN          NaN
# 10  ['Niall Redmond', ' Danny Coleman', ' Mirco Es...    NaN          NaN
# 11  ['Anek', ' Sven The Freak', ' Mark Faermont', ...    NaN          NaN
# 12              [' Michael Canzian', 'Mark Faermont']    NaN          NaN
# 13                                  ['Mark Faermont']    NaN          NaN
# 14                    [' Steven Stone', 'Rolf Imhof']    NaN          NaN
# 15                    ['Progamode', ' Mark Faermont']    NaN          NaN
# 16  ['Belair', 'Juzz', 'SCP Dance Project', 'Ryan ...    NaN          NaN
# 17                        ['Mark Faermont', 'Affani']    NaN          NaN
# 18                                   ['Mucho Stylez']    NaN          NaN
# 19                                   ['Mucho Stylez']    NaN          NaN
# 20                                   ['Mucho Stylez']    NaN          NaN
# 21                   [' Sonny Dima', 'Mark Faermont']    NaN          NaN
# 22                 ['Carlos Russo', ' Mark Faermont']    NaN          NaN
# 23      ['Tonka', ' Mark Faermont', ' Danny Coleman']    NaN          NaN
# 24                     ['Carlos Russo', ' David Eye']    NaN          NaN
# 25  [' Niall Redmond', ' Mark Faermont', 'Elektros...    NaN          NaN
# 26                  [' DJ Le Baron', 'Mark Faermont']    NaN          NaN
# 27  ['Niall Redmond', ' Danny Coleman', ' Mirco Es...    NaN          NaN
# 28  ['Anek', ' Sven The Freak', ' Mark Faermont', ...    NaN          NaN
# 29              [' Michael Canzian', 'Mark Faermont']    NaN          NaN
# 30                                  ['Mark Faermont']    NaN          NaN
# 31                    [' Steven Stone', 'Rolf Imhof']    NaN          NaN
# 32                    ['Progamode', ' Mark Faermont']    NaN          NaN
# 33  ['Belair', 'Juzz', 'SCP Dance Project', 'Ryan ...    NaN          NaN
# 34  ['Guti (Desolat)', ' Nicolaj (Miteinander Musi...    NaN          NaN
# 35  ['Juen & Bach', 'Criss', 'Pazkal', 'Urbanbassi...    NaN          NaN

# %%
GOOGLE_API_KEY = open("KEY.txt").read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2b04a0f86c13> in <module>()
# ----> 1 GOOGLE_API_KEY = open("KEY.txt").read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'KEY.txt'

# %%
import glob
import numpy as np
import pandas as pd
import json
import requests
import ArtistExtractor as AE

files = []
files = glob.glob("ClubData0/*.csv")+glob.glob("ClubData1/*.csv")+glob.glob("ClubData2/*.csv")+glob.glob("ClubData3/*.csv")
print(len(files))
ClubDataFrame = pd.read_csv(files[0],sep="\t")

for file in files:
    df= pd.read_csv(file,sep ="\t")
    ClubDataFrame = ClubDataFrame.append(df,ignore_index = True)
    
print(ClubDataFrame.shape)
ClubDataFrame.head(10)
# Out:
# 1312
# (10069, 8)
#    Unnamed: 0    ClubID        ClubName  \
# 0         0.0  100121.0      Cyclo Café
# 1         1.0  100121.0      Cyclo Café
# 2         2.0  100121.0      Cyclo Café
# 3         0.0  100121.0      Cyclo Café
# 4         1.0  100121.0      Cyclo Café
# 5         2.0  100121.0      Cyclo Café
# 6         0.0   10186.0   Rocking Chair
# 7         1.0   10186.0   Rocking Chair
# 8         2.0   10186.0   Rocking Chair
# 9         0.0  102059.0    Acapella Bar
#
#                                         Address   EventID  \
# 0            Boulevard de Pérolles 91, Fribourg  707619.0
# 1            Boulevard de Pérolles 91, Fribourg  673119.0
# 2            Boulevard de Pérolles 91, Fribourg  672938.0
# 3            Boulevard de Pérolles 91, Fribourg  707619.0
# 4            Boulevard de Pérolles 91, Fribourg  673119.0
# 5            Boulevard de Pérolles 91, Fribourg  672938.0
# 6            Avenue de Gilamont 60; 1800, Vevey  365245.0
# 7            Avenue de Gilamont 60; 1800, Vevey  284885.0
# 8            Avenue de Gilamont 60; 1800, Vevey   49151.0
# 9  Place de la Gare, 1957 Ardon, Valais, Suisse  693409.0
#
#                                            EventName                Date  \
# 0  Light My Fridays: with Ariane Effect, DJ H-ERA...      10 April 2015
# 1                    Chris Ahn's 4AM Mixtape - Ep. 4   14 November 2014
# 2                Chris Ahn's 4AM Mixtape - Episode 1        16 May 2014
# 3  Light My Fridays: with Ariane Effect, DJ H-ERA...      10 April 2015
# 4                    Chris Ahn's 4AM Mixtape - Ep. 4   14 November 2014
# 5                Chris Ahn's 4AM Mixtape - Episode 1        16 May 2014
# 6                        Hacienda 30th Birthday Tour        05 May 2012
# 7                                Black & White Party       30 June 2010
# 8                                       Jamie Lidell      23 April 2008
# 9                          The Future Color Of Sound      17 April 2015
#
#                                               LineUp
# 0         ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 1                                      ['Chris Ahn']
# 2                                      ['Chris Ahn']
# 3         ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 4                                      ['Chris Ahn']
# 5                                      ['Chris Ahn']
# 6  ['', ' New Order) >>>Andrew Weatherall (Two Lo...
# 7                                       ['Lemonick']
# 8                                   ['Jamie Lidell']
# 9        ['Dj Never Die', 'Jack Demon', 'Vitronic ']

# %%
ClubDataFrame[ClubDataFrame.Address.isnull()]
# Out:
#        Unnamed: 0   ClubID            ClubName Address   EventID  \
# 1111          0.0  41096.0     Uber Naturapura     NaN  334841.0
# 1112          1.0  41096.0     Uber Naturapura     NaN  310686.0
# 1113          2.0  41096.0     Uber Naturapura     NaN  270162.0
# 1114          3.0  41096.0     Uber Naturapura     NaN  247665.0
# 1115          4.0  41096.0     Uber Naturapura     NaN  225559.0
# 1116          5.0  41096.0     Uber Naturapura     NaN   70634.0
# 1662          0.0   6613.0   Streets of Zurich     NaN  866903.0
# 1663          1.0   6613.0   Streets of Zurich     NaN  860048.0
# 1664          2.0   6613.0   Streets of Zurich     NaN  727062.0
# 1665          3.0   6613.0   Streets of Zurich     NaN  749500.0
# 1666          4.0   6613.0   Streets of Zurich     NaN  619561.0
# 1667          5.0   6613.0   Streets of Zurich     NaN  389979.0
# 1668          6.0   6613.0   Streets of Zurich     NaN  112168.0
# 1669          7.0   6613.0   Streets of Zurich     NaN   99417.0
# 1670          8.0   6613.0   Streets of Zurich     NaN   61790.0
# 1671          9.0   6613.0   Streets of Zurich     NaN   32350.0
# 1672         10.0   6613.0   Streets of Zurich     NaN   27129.0
# 3781          0.0  41096.0     Uber Naturapura     NaN  334841.0
# 3782          1.0  41096.0     Uber Naturapura     NaN  310686.0
# 3783          2.0  41096.0     Uber Naturapura     NaN  270162.0
# 3784          3.0  41096.0     Uber Naturapura     NaN  247665.0
# 3785          4.0  41096.0     Uber Naturapura     NaN  225559.0
# 3786          5.0  41096.0     Uber Naturapura     NaN   70634.0
# 4353          0.0   6613.0   Streets of Zurich     NaN  866903.0
# 4354          1.0   6613.0   Streets of Zurich     NaN  860048.0
# 4355          2.0   6613.0   Streets of Zurich     NaN  727062.0
# 4356          3.0   6613.0   Streets of Zurich     NaN  749500.0
# 4357          4.0   6613.0   Streets of Zurich     NaN  619561.0
# 4358          5.0   6613.0   Streets of Zurich     NaN  389979.0
# 4359          6.0   6613.0   Streets of Zurich     NaN  112168.0
# 4360          7.0   6613.0   Streets of Zurich     NaN   99417.0
# 4361          8.0   6613.0   Streets of Zurich     NaN   61790.0
# 4362          9.0   6613.0   Streets of Zurich     NaN   32350.0
# 4363         10.0   6613.0   Streets of Zurich     NaN   27129.0
# 7468          0.0   9864.0               Shark     NaN   46928.0
# 10049         0.0   9864.0               Shark     NaN   46928.0
#
#                                                EventName                 Date  \
# 1111                                                 K36       24 March 2012
# 1112                         Bizeligeburitanzen Mit Hugo    19 November 2011
# 1113                          Bizeliafter Ar Natura Pura      21 August 2011
# 1114                                         Dolce, Sisi       09 April 2011
# 1115                Bizeligeburi vor Natura Pura Zum 5te    12 February 2011
# 1116                       Naturapura - Bern / Gäbelbach    02 November 2008
# 1662                           Hvitling at Street Parade      13 August 2016
# 1663                        Street Parade Zürich - Olymp      13 August 2016
# 1664             Mimmo and Friends - Streetparade Zurich   29 September 2015
# 1665                            Sonidy on The Lovemobile      27 August 2015
# 1666                     Love Mobile Vo Züri, Für Züri 2      02 August 2014
# 1667                    Street Parade 2012 - Kongreshaus      11 August 2012
# 1668               Street Parade 2009 - Official Line Up      08 August 2009
# 1669        Streetparade 2009 Boyz Don't Cry Love Mobile      08 August 2009
# 1670                                Zurich Street Parade      09 August 2008
# 1671                                           Flugstund     28 October 2007
# 1672                                Zürich Street Parade      11 August 2007
# 3781                                                 K36       24 March 2012
# 3782                         Bizeligeburitanzen Mit Hugo    19 November 2011
# 3783                          Bizeliafter Ar Natura Pura      21 August 2011
# 3784                                         Dolce, Sisi       09 April 2011
# 3785                Bizeligeburi vor Natura Pura Zum 5te    12 February 2011
# 3786                       Naturapura - Bern / Gäbelbach    02 November 2008
# 4353                           Hvitling at Street Parade      13 August 2016
# 4354                        Street Parade Zürich - Olymp      13 August 2016
# 4355             Mimmo and Friends - Streetparade Zurich   29 September 2015
# 4356                            Sonidy on The Lovemobile      27 August 2015
# 4357                     Love Mobile Vo Züri, Für Züri 2      02 August 2014
# 4358                    Street Parade 2012 - Kongreshaus      11 August 2012
# 4359               Street Parade 2009 - Official Line Up      08 August 2009
# 4360        Streetparade 2009 Boyz Don't Cry Love Mobile      08 August 2009
# 4361                                Zurich Street Parade      09 August 2008
# 4362                                           Flugstund     28 October 2007
# 4363                                Zürich Street Parade      11 August 2007
# 7468   No Ny A One Night Show By Art Group Klat with ...       13 March 2008
# 10049  No Ny A One Night Show By Art Group Klat with ...       13 March 2008
#
#                                                   LineUp
# 1111                                         ['Paul Eg']
# 1112   [' Mastra .................', ' Bang Goes', 'R...
# 1113   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 1114      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 1115   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 1116   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 1662                                        ['Hvitling']
# 1663   [' MYKE', ' DANI FABREGA', ' DEYAN', ' INTRESS...
# 1664   ['Mirco Esposito', 'George Lamell', 'Steven St...
# 1665   ['Steven Davis', 'MAXXDRUMS', 'Tito Torres', '...
# 1666   [' Danny Coleman', ' Alex Austin', ' Coast', '...
# 1667   ['21.30 Sir Collin', '13.00 Dj Phala', '22.45 ...
# 1668   ['', '14:30 – 16:00 Stimming', '14:00 – 15:30 ...
# 1669   [" Maho & Jackin (Boyz Don't Cry)", " Tonic & ...
# 1670   ['', 'Playlove/81 (D/CH)', 'One:Shot:Ochestra ...
# 1671   [' Chris de Rebel', 'Gleichschritt', ' Tomy Gi...
# 1672   ['', '14.00-15.00 Sander van Doorn (NL)', 'Lim...
# 3781                                         ['Paul Eg']
# 3782   [' Mastra .................', ' Bang Goes', 'R...
# 3783   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 3784      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 3785   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 3786   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 4353                                        ['Hvitling']
# 4354   [' MYKE', ' DANI FABREGA', ' DEYAN', ' INTRESS...
# 4355   ['Mirco Esposito', 'George Lamell', 'Steven St...
# 4356   ['Steven Davis', 'MAXXDRUMS', 'Tito Torres', '...
# 4357   [' Danny Coleman', ' Alex Austin', ' Coast', '...
# 4358   ['21.30 Sir Collin', '13.00 Dj Phala', '22.45 ...
# 4359   ['', '14:30 – 16:00 Stimming', '14:00 – 15:30 ...
# 4360   [" Maho & Jackin (Boyz Don't Cry)", " Tonic & ...
# 4361   ['', 'Playlove/81 (D/CH)', 'One:Shot:Ochestra ...
# 4362   [' Chris de Rebel', 'Gleichschritt', ' Tomy Gi...
# 4363   ['', '14.00-15.00 Sander van Doorn (NL)', 'Lim...
# 7468   ['', 'Peter Stoffel & Cobeia > Electronic boog...
# 10049  ['', 'Peter Stoffel & Cobeia > Electronic boog...

# %% [markdown]
# ### Adding informations

# %% [markdown]
# We need to add some informations, such as the location of the club, and parsing the date.

# %%
#Adding location of the "club"
def getLocation(clubName,dictionnary =None,SwissSafety=True):
    '''Returns the location of the club with a tuple (lat,lng)'''
    
    location = None
    lat = None
    lng = None
    
    if(dictionnary != None and (clubName in dictionnary)):
        return dictionnary[clubName],dictionnary
    else:
        if(location==None): #Try with geoCodeAPI
            baseURL1 = 'https://maps.googleapis.com/maps/api/place/textsearch/json'
            try:
                location = getFromAPI(clubName,baseURL1)
            except:
                location = None
            
        if(location==None): #Try with textSearchAPI
            baseURL2 = 'https://maps.googleapis.com/maps/api/geocode/json'
            try:
                location = getFromAPI(clubName,baseURL2)
            except:
                location = None
            
        if(location == None): #Try usingAddressAPI
            #Try with address 
            address = getAddress(clubName)
            if(address!=None):
                (lat,lng) = getLocation(address)
            
        else:
            #print("location is "+str(location))
            if(location!="ERROR"):
                lat = location['lat']
                lng = location['lng']
            else:
                lat = "ERROR"
                lng = "ERROR"
        
        #Checks if the club is in Switzerland
        if(SwissSafety and lat!=None and lng!=None):
            if(lng<5.7 or lng>10.73 or lat<45.6 or lat>47.9):
                #Out of Switzerland
                print("out of bounds")
                (lat,lng) = getLocation(clubName+", Switzerland")
            
        if(dictionnary!=None):
            dictionnary.update({clubName : (lat,lng)})
            return (lat,lng),dictionnary

    return (lat,lng)

# %%
def getFromAPI(clubName,baseURL):
    param={}
    if("geocode" in baseURL):
        param = {'address': str(clubName),
             'region':'ch',
             'key': GOOGLE_API_KEY}
    else:
        param = {'query': str(clubName),
                 #'keyword':'Switzerland',
                 'key': GOOGLE_API_KEY}
    
    #baseURL = 'https://maps.googleapis.com/maps/api/geocode/json' #Get JSON for Geocode
    content = json.loads(requests.get(baseURL, params = param).text)
    
    if('error_message' in content):
        raise Exception()
    
    location = None
    if(len(content['results'])>0):
        location = content['results'][0]['geometry']['location']
        #print("ContentFound:"+str(location))
    
    return location

# %%
def getAddress(address,count=1):
    count = count-1
    #print(address)
    '''Returns the address of the club with a tuple'''
    param = {'address': str(address),
             'region':'ch',
             'key': GOOGLE_API_KEY}
    
    baseURL = 'https://maps.googleapis.com/maps/api/geocode/json' #Get JSON for Geocode
    content = json.loads(requests.get(baseURL, params = param).text)
    addressRes = None
    
    if(len(content['results'])>0):
        addressRes = content['results'][0]['formatted_address']
        print("result using geocode")
    else:
        #print("No result using geocode")
    #If no results, try another API to find the postal code and retry.
        param2 = {'query': str(address),
                 'key': GOOGLE_API_KEY}    

        baseURL2 = 'https://maps.googleapis.com/maps/api/place/textsearch/json'

        content2 = json.loads(requests.get(baseURL2, params = param2).text)
        if(len(content2['results'])>0):
            addressRes = content2['results'][0]['formatted_address']
            print("result using textsearch")
        #else:
            #print("No result using TextSearch and GeoCode")

    #if(addressRes!=None and "Switzerland" not in addressRes[1:]):
        if(addressRes==None and count>=0):
            addressRes = getAddress(str(address)+", Switzerland",count)
        else:
            #print("No results but : "+str(addressRes))
            return addressRes
    
    return addressRes

# %%
indices = list(ClubDataFrame[ClubDataFrame.Address.isnull()].index)
dicname = {}

for indice in indices:
    name = ClubDataFrame[ClubDataFrame.index == indice]["ClubName"]
    if(name.values[0] not in dicname):
        dicname.update({name.values[0]:getAddress(name)})
    address = dicname[name.values[0]]
    ClubDataFrame.loc[ClubDataFrame.index == indice,"Address"] = address
    
ClubDataFrame[ClubDataFrame.Address.isnull()]
# Out:
# result using geocode
#        Unnamed: 0   ClubID          ClubName Address   EventID  \
# 1111          0.0  41096.0   Uber Naturapura    None  334841.0
# 1112          1.0  41096.0   Uber Naturapura    None  310686.0
# 1113          2.0  41096.0   Uber Naturapura    None  270162.0
# 1114          3.0  41096.0   Uber Naturapura    None  247665.0
# 1115          4.0  41096.0   Uber Naturapura    None  225559.0
# 1116          5.0  41096.0   Uber Naturapura    None   70634.0
# 3781          0.0  41096.0   Uber Naturapura    None  334841.0
# 3782          1.0  41096.0   Uber Naturapura    None  310686.0
# 3783          2.0  41096.0   Uber Naturapura    None  270162.0
# 3784          3.0  41096.0   Uber Naturapura    None  247665.0
# 3785          4.0  41096.0   Uber Naturapura    None  225559.0
# 3786          5.0  41096.0   Uber Naturapura    None   70634.0
# 7468          0.0   9864.0             Shark    None   46928.0
# 10049         0.0   9864.0             Shark    None   46928.0
#
#                                                EventName                Date  \
# 1111                                                 K36      24 March 2012
# 1112                         Bizeligeburitanzen Mit Hugo   19 November 2011
# 1113                          Bizeliafter Ar Natura Pura     21 August 2011
# 1114                                         Dolce, Sisi      09 April 2011
# 1115                Bizeligeburi vor Natura Pura Zum 5te   12 February 2011
# 1116                       Naturapura - Bern / Gäbelbach   02 November 2008
# 3781                                                 K36      24 March 2012
# 3782                         Bizeligeburitanzen Mit Hugo   19 November 2011
# 3783                          Bizeliafter Ar Natura Pura     21 August 2011
# 3784                                         Dolce, Sisi      09 April 2011
# 3785                Bizeligeburi vor Natura Pura Zum 5te   12 February 2011
# 3786                       Naturapura - Bern / Gäbelbach   02 November 2008
# 7468   No Ny A One Night Show By Art Group Klat with ...      13 March 2008
# 10049  No Ny A One Night Show By Art Group Klat with ...      13 March 2008
#
#                                                   LineUp
# 1111                                         ['Paul Eg']
# 1112   [' Mastra .................', ' Bang Goes', 'R...
# 1113   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 1114      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 1115   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 1116   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 3781                                         ['Paul Eg']
# 3782   [' Mastra .................', ' Bang Goes', 'R...
# 3783   ['', '*noe weigl ', '*litle lu', 'wo? genau dö...
# 3784      ['Support: Princess P & J_Sanders', 'DJ Hell']
# 3785   ['SHABBA luzern', 'RINO züri', 'Tadeo Doberska...
# 3786   ['Andrés Marcos (live) PA (miniatura rec)', 'T...
# 7468   ['', 'Peter Stoffel & Cobeia > Electronic boog...
# 10049  ['', 'Peter Stoffel & Cobeia > Electronic boog...

# %% [markdown]
# There is still some clubs without an address. We can drop them.

# %%
ClubDataFrame = ClubDataFrame[~ClubDataFrame.Address.isnull()]

# %%
dic={}
print(getLocation("Zone Industrielle du Verdel, Route de l'Étang 21, 1630 Bulle, Switzerland"))
# Out:
# (46.6263926, 7.066865399999999)

# %%
a = getAddress("Globull")
print(a)
# Out:
# result using textsearch
# Zone Industrielle du Verdel, Route de l'Étang 21, 1630 Bulle, Switzerland

# %% [markdown]
# ### Adding the location

# %%
import datetime
def computeDictionaryOfLocations(df,debug=False):
    '''Map each club to a location'''
    dictionary = {}
    allClubs = set(df["Address"])
    nbClubs = len(allClubs)
    i = 0
    
    
    #Computing dictionnary
    if(debug):
        print("NbClubs : "+str(nbClubs))
        print("Begin mapping...")
    bTime = datetime.datetime.now()
    estimate = 123456
    
    for c in allClubs:
        locC = getLocation(c,dictionary)
        if(locC!=None):
            dictionary.update({c : locC[0]})
        else:
            dictionary.update({c : locC})
            
        if(debug and i%30==1):
            delta = datetime.datetime.now()-bTime
            estimate = (nbClubs-i)*delta/30
            timeLeft = bTime+estimate-datetime.datetime.now()
            print("{nb}/{to}, time left = {t}".format(nb = i, to = nbClubs, t=timeLeft))
            bTime = datetime.datetime.now()
        i = i+1

        
    if(debug):
        print("Computation finished!")
    return dictionary

# %%
#dic = computeDictionaryOfLocations(ClubDataFrame,debug=True)

# %%
def saveDictionary(dic, filename):
    outfile = open('ClubDataGeo/'+filename+'.txt', 'w' )
    for key, value in sorted( dic.items() ):
        outfile.write( str(key) + '\t' + str(value) + '\n' )

# %%
def loadDictionary(filename):
    inp = open('ClubDataGeo/'+filename+'.txt', 'r' )
    dic = {}
    for l in inp:
        line = inp.readline()
        s = line.split("\t")
        if(len(s)>1):
            s[1] = s[1].replace("\n","")
            dic.update({s[0]:s[1]})
        else:
            print(s)
    return dic

# %%
dic = loadDictionary("ClubsGeo")
a = dic.get("Lagerplatz 18; 8400, Winterthur")
print(a)
# Out:
# (47.49477690000001, 8.717943900000002)

# %% [raw]
# def locate(s,dictionary):
#     try:
#         if(dictionary == None):
#             print("NONE ")
#         (lat,lng) = dictionary.get(str(s["Address"]))
#         return (lat,lng)
#     except Exception as e:
#         print(e)
#         print("except : "+str(s["Address"]))
#         (lat,lng) = getLocation(s["Address"])
#
#     return (lat,lng)
#
# ClubDataFrame["Location"] = ClubDataFrame.apply(locate,args=(dic,),axis=1)
# ClubDataFrame

# %%
a = dic.get("Cyclo Café")
print(a)
# Out:
# None

# %%
ClubDataFrame.head()
# Out:
#    Unnamed: 0    ClubID     ClubName                             Address  \
# 0         0.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 1         1.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 2         2.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 3         0.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
# 4         1.0  100121.0   Cyclo Café  Boulevard de Pérolles 91, Fribourg
#
#     EventID                                          EventName  \
# 0  707619.0  Light My Fridays: with Ariane Effect, DJ H-ERA...
# 1  673119.0                    Chris Ahn's 4AM Mixtape - Ep. 4
# 2  672938.0                Chris Ahn's 4AM Mixtape - Episode 1
# 3  707619.0  Light My Fridays: with Ariane Effect, DJ H-ERA...
# 4  673119.0                    Chris Ahn's 4AM Mixtape - Ep. 4
#
#                  Date                                      LineUp
# 0      10 April 2015   ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 1   14 November 2014                                ['Chris Ahn']
# 2        16 May 2014                                ['Chris Ahn']
# 3      10 April 2015   ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 4   14 November 2014                                ['Chris Ahn']

# %% [raw]
# saveDictionary(dic,"ClubsGeoU")
# dic = loadDictionary("ClubsGeo")
#
# for i in ClubDataFrame.index:
#     addr = (ClubDataFrame[ClubDataFrame.index==i]["Address"]).values[0]
#     location = dic.get(addr)
#     if(location == None):
#         location = getLocation(addr)
#         dic.update({addr : location})
#         saveDictionary(dic,"ClubsGeoU")
#
#     #print(str(i)+";"+str(location))
#     ClubDataFrame.loc[ClubDataFrame.index==i,'Location'] = str(location)
#     #dic.get(ClubDataFrame[ClubDataFrame.index==i]["Address"])
#
# ClubDataFrame

# %% [markdown]
# ### Adding main genre for each event

# %%
ClubDataFrame = pd.read_csv("ClubDataGeo/ClubDataFrame.csv", encoding='utf-8')
ClubDataFrame = ClubDataFrame.drop_duplicates()

#Drop Useless columns
ClubDataFrame = ClubDataFrame.drop('Unnamed: 0', 1)
ClubDataFrame = ClubDataFrame.drop_duplicates()
ClubDataFrame.head(20)
# Out:
#       ClubID        ClubName                                       Address  \
# 0   100121.0      Cyclo Café            Boulevard de Pérolles 91, Fribourg
# 1   100121.0      Cyclo Café            Boulevard de Pérolles 91, Fribourg
# 2   100121.0      Cyclo Café            Boulevard de Pérolles 91, Fribourg
# 3    10186.0   Rocking Chair            Avenue de Gilamont 60; 1800, Vevey
# 4    10186.0   Rocking Chair            Avenue de Gilamont 60; 1800, Vevey
# 5    10186.0   Rocking Chair            Avenue de Gilamont 60; 1800, Vevey
# 6   102059.0    Acapella Bar  Place de la Gare, 1957 Ardon, Valais, Suisse
# 7    10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 8    10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 9    10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 10   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 11   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 12   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 13   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 14   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 15   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 16   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 17   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 18   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
# 19   10242.0       Kraftfeld               Lagerplatz 18; 8400, Winterthur
#
#      EventID                                          EventName        Date  \
# 0   707619.0  Light My Fridays: with Ariane Effect, DJ H-ERA...  2015-04-10
# 1   673119.0                    Chris Ahn's 4AM Mixtape - Ep. 4  2014-11-14
# 2   672938.0                Chris Ahn's 4AM Mixtape - Episode 1  2014-05-16
# 3   365245.0                        Hacienda 30th Birthday Tour  2012-05-05
# 4   284885.0                                Black & White Party  2010-06-30
# 5    49151.0                                       Jamie Lidell  2008-04-23
# 6   693409.0                          The Future Color Of Sound  2015-04-17
# 7   881381.0                                   Lila mit Serafin  2016-09-23
# 8   862135.0                     Backstreet Noise x Sunday Mess  2016-07-31
# 9   832959.0                               Phantom Island Night  2016-05-06
# 10  796715.0  Heute Tanz mit Jan Schulte aka Bufiman aka Wol...  2016-02-20
# 11  776346.0                              Heute Tanz mit Khidja  2015-11-28
# 12  767162.0  Sunday Mess with Daniele Cosmo, Marc D'arrigo ...  2015-11-22
# 13  748880.0                         Heute Tanz mit Disco Halal  2015-09-26
# 14  752699.0                  10 Jahre Verein Radio Stadtfilter  2015-09-18
# 15  715622.0                Heute Tanz mit Timothy J. Fairplay   2015-05-23
# 16  687027.0                          Heute Tanz mit Alma Negra  2015-03-28
# 17  681287.0                     Heute Tanz mit Lexx & Kejeblos  2015-02-21
# 18  639235.0                                   Lux Rec presents  2014-10-18
# 19  639185.0                Larytta (Creaked Records, Lausanne)  2014-10-10
#
#                                                LineUp  \
# 0          ['DJ H.ERA', 'Ariane Effect', 'Chris Ahn']
# 1                                       ['Chris Ahn']
# 2                                       ['Chris Ahn']
# 3   ['', ' New Order) >>>Andrew Weatherall (Two Lo...
# 4                                        ['Lemonick']
# 5                                    ['Jamie Lidell']
# 6         ['Dj Never Die', 'Jack Demon', 'Vitronic ']
# 7   [' Christian Elefante', ' Emre', ' Valentin', ...
# 8   [' Beppe Loda (Invisible City Editions)', ' Of...
# 9   ['Lexx (ESP Institute', ' Permanent Vacation',...
# 10  ['Jan Schulte', ' El Tigre Sound (zweikommasie...
# 11                                         ['Khidja']
# 12       ["Marc D'Arrigo", 'Herman', 'Daniele Cosmo']
# 13  ['Kaan Düzarat (FOC Edits/Istanbul)', ' Mehmet...
# 14       ['Dave Eleanor', 'Lord Kesseli & The Drums']
# 15  [' DJ Aunt One & Napoleton (Talen/Laserwolf)',...
# 16  ['Alma Negra (Sofrito', ' Basic Fingers', ' Hi...
# 17  ['Lexx (Permanent Vacation)', ' Kejeblos (Phan...
# 18              [' Cosmo & Faber', 'Cold Colors (F)']
# 19  [' Tako & Jamie Tiller (Redlight Records', ' L...
#
#                                   Location
# 0                  (46.7947773, 7.1568081)
# 1                  (46.7947773, 7.1568081)
# 2                  (46.7947773, 7.1568081)
# 3          (46.4720036, 6.852230199999998)
# 4          (46.4720036, 6.852230199999998)
# 5          (46.4720036, 6.852230199999998)
# 6          (46.2084859, 7.270119599999999)
# 7   (47.49477690000001, 8.717943900000002)
# 8   (47.49477690000001, 8.717943900000002)
# 9   (47.49477690000001, 8.717943900000002)
# 10  (47.49477690000001, 8.717943900000002)
# 11  (47.49477690000001, 8.717943900000002)
# 12  (47.49477690000001, 8.717943900000002)
# 13  (47.49477690000001, 8.717943900000002)
# 14  (47.49477690000001, 8.717943900000002)
# 15  (47.49477690000001, 8.717943900000002)
# 16  (47.49477690000001, 8.717943900000002)
# 17  (47.49477690000001, 8.717943900000002)
# 18  (47.49477690000001, 8.717943900000002)
# 19  (47.49477690000001, 8.717943900000002)

# %% [markdown]
# ### Reformating Dates

# %% [raw]
# from dateutil.parser import parse
#
# def reformatDate(value):
#     #a = ClubDataFrame["Date"]
#     d = parse(value["Date"])
#     date = d.strftime('%Y-%m-%d')
#     return date
#
# ClubDataFrame["Date"] = ClubDataFrame.apply(reformatDate,axis=1)
# ClubDataFrame

# %%
#ClubDataFrame.to_csv("ClubDataGeo/ClubDataFrame.csv", encoding='utf-8')
ClubDataFrame[ClubDataFrame.EventID==881381.0]
import ArtistExtractor as AE
AE.getGenre("EMRE")
# Out:
# 'turkish pop'

# %%
import ArtistExtractor as AE
import re

ARTIST_GENRE = {}
BUG_ARTISTS = {}

def getGenreByLineUp(s):
    LineUp = str(s['LineUp'])
    
    #Sanitize
    LineUp = LineUp.replace("\"","")
    LineUp = LineUp.replace("[","")
    LineUp = LineUp.replace("]","")
    LineUp = LineUp.replace("'","")
    LineUpSplit = re.split(",|>",LineUp)
    #print(LineUp)
    
    listGenres = []
    listLabels = []
    for artist in LineUpSplit:
        labels = artist.split("(")
        artist = labels[0]
        if(len(labels)>1):
            label = labels[1]
            label = label.replace("(","").replace(")","")
            #print(label)
            listLabels.append(label)
        
        artist = artist.strip() #Remove whitespaces
        artist = artist.replace("(","").replace(")","").replace("'","").replace(">","")

        if(len(artist)>2 and artist not in ARTIST_GENRE):
            genre = AE.getGenre(artist)
            #print(genre)
            if(genre==None):
                print(str(s["EventID"])+" Bug Artist : "+str(artist))
                BUG_ARTISTS.update({artist : str(s["EventID"])})
                
            ARTIST_GENRE.update({artist : genre})
            
        genre = ARTIST_GENRE.get(artist)
        listGenres.append(genre)
   
    return AE.getMaxGenre(listGenres)

def extractGenreFromLineUps(df):
    indices = df.index
    for i in indices:
        genre = getGenreByLineUp(df[df.index==i])
        #print(str(df[df.index==i])+" - "+ str(genre))
        #print(str(i)+";"+str(location))
        #ClubDataFrame.loc[ClubDataFrame.index==i,'Location'] = str(location)
    return genre


ClubDataFrame["EventGenre"] = ClubDataFrame.apply(getGenreByLineUp,axis=1)
# Out:
# 707619.0 Bug Artist : DJ H.ERA
# 365245.0 Bug Artist : Peter Hook
# 693409.0 Bug Artist : Jack Demon
# 693409.0 Bug Artist : Vitronic
# 881381.0 Bug Artist : Christian Elefante
# 881381.0 Bug Artist : Guel
# 862135.0 Bug Artist : Beppe Loda
# 862135.0 Bug Artist : Offen Music
# 862135.0 Bug Artist : Vladimir Ivkovic
# 832959.0 Bug Artist : Kejeblos
# 832959.0 Bug Artist : DFA
# 796715.0 Bug Artist : Jan Schulte
# 796715.0 Bug Artist : El Tigre Sound
# 767162.0 Bug Artist : Daniele Cosmo
# 748880.0 Bug Artist : Kaan Düzarat
# 752699.0 Bug Artist : Lord Kesseli & The Drums
# 715622.0 Bug Artist : DJ Aunt One & Napoleton
# 715622.0 Bug Artist : Timothy J. Fairplay
# 687027.0 Bug Artist : Alma Negra
# 687027.0 Bug Artist : Basic Fingers
# 687027.0 Bug Artist : Highlife
# 639185.0 Bug Artist : Lausanne
# 639185.0 Bug Artist : Music From Memory / Amsterdam
# 639185.0 Bug Artist : J. Sayne
# 639183.0 Bug Artist : DJ P-Tess
# 602242.0 Bug Artist : Fabio Riccio
# 589987.0 Bug Artist : Raban
# 589987.0 Bug Artist : TNT
# 589987.0 Bug Artist : LichtDEFEKTE von Van Nutt.
# 569536.0 Bug Artist : Twoets
# 569536.0 Bug Artist : LIVE: Alessandro Parisi
# 569536.0 Bug Artist : D Cosmo
# 529736.0 Bug Artist : Das Pferd
# 538495.0 Bug Artist : D Cosmo & Faber
# 513379.0 Bug Artist : Das HOUSE
# 513379.0 Bug Artist : Berber & Pasta
# 513379.0 Bug Artist : Hermansson & Martinez
# 513379.0 Bug Artist : Baile Musik - DE
# 457465.0 Bug Artist : P.Bell
# 455872.0 Bug Artist : Akt
# 455872.0 Bug Artist : MALEKOS BEUTEL & AMARU
# 437522.0 Bug Artist : DJs: Nik!
# 437522.0 Bug Artist : P-Tess
# 329750.0 Bug Artist : hypnorex
# 232906.0 Bug Artist : Wicked Wilma
# 107550.0 Bug Artist : Styro 2000
# 107550.0 Bug Artist : Goldoni
# 86419.0 Bug Artist : Marc Fuhrmann
# 59625.0 Bug Artist : Live: Pitsch & Magnano
# 59625.0 Bug Artist : Fehlfunktion
# 49625.0 Bug Artist : DJs Eli Verveine
# 49625.0 Bug Artist : Pochatz
# 876620.0 Bug Artist : Caslau / Luke Haslau
# 876620.0 Bug Artist : Ikosa
# 876620.0 Bug Artist : Mafou
# 876620.0 Bug Artist : Mukuna
# 876620.0 Bug Artist : Clearvision
# 876620.0 Bug Artist : Hund Koecket
# 876620.0 Bug Artist : Kombé
# 880817.0 Bug Artist : Garçon
# 880817.0 Bug Artist : Cepheì
# 880817.0 Bug Artist : Hfs Dub
# 880817.0 Bug Artist : Trauminic
# 859506.0 Bug Artist : Gabriel Pellicano aka DJ Pellicano
# 859506.0 Bug Artist : Kaschemme Basel
# 859506.0 Bug Artist : DJ STEEL
# 859506.0 Bug Artist : Mark Lamski
# 859506.0 Bug Artist : Edward Classen aka EDI LE CHEF
# 859506.0 Bug Artist : Drinks & Food:
# 859506.0 Bug Artist : Michel Mathis aka DJ Pun
# 859506.0 Bug Artist : Iyad El Qirinawi aka EL Q
# 859506.0 Bug Artist : Live:
# 859506.0 Bug Artist : BLACK TIGER Basel City
# 859506.0 Bug Artist : DJ Tray
# 859506.0 Bug Artist : DJ Moishe
# 859506.0 Bug Artist : Venti
# 842072.0 Bug Artist : Radio Ghost Town // Basel
# 842072.0 Bug Artist : Timnah Sommerfeldt
# 842072.0 Bug Artist : Dubhead // Istein
# 842072.0 Bug Artist : Subotagerecords / Density Radio X // Basel
# 792798.0 Bug Artist : Kairo Is Koming
# 785015.0 Bug Artist : Cutkachi // re:st // dubtopia /// Bern
# 785015.0 Bug Artist : Dj Montes // Goldfinger Brothers /// Basel
# 772327.0 Bug Artist : Deep n Dub
# 742535.0 Bug Artist : Aust
# 742535.0 Bug Artist : Aware
# 713368.0 Bug Artist : The Name Game
# 713368.0 Bug Artist : DJ Fett Burger
# 713368.0 Bug Artist : elias3O8
# 715652.0 Bug Artist : Elrino
# 715652.0 Bug Artist : Ayhasca Ernesto
# 718139.0 Bug Artist : Larry King
# 718139.0 Bug Artist : Prop&Lean
# 718139.0 Bug Artist : Getting Any?
# 718139.0 Bug Artist : Ostbahnhof
# 697045.0 Bug Artist : Truce
# 699986.0 Bug Artist : Oscar Niczzo
# 697487.0 Bug Artist : Frank Vespari
# 700045.0 Bug Artist : Davix
# 701838.0 Bug Artist : Gold N Silver
# 894785.0 Bug Artist : Did Low
# 894785.0 Bug Artist : Elevated
# 894785.0 Bug Artist : Ovum
# 894785.0 Bug Artist : Time Has Changed
# 894785.0 Bug Artist : Minimo Imprint
# 889628.0 Bug Artist : Cab Drivers
# 889628.0 Bug Artist : Cabinet Records
# 887658.0 Bug Artist : VAlpen aka Dachshund & Dave The Hustler
# 887656.0 Bug Artist : Stassy
# 882021.0 Bug Artist : Byzance
# 882020.0 Bug Artist : Dany Movida
# 882020.0 Bug Artist : Daniel Branco
# 879560.0 Bug Artist : TomTeeT
# 877821.0 Bug Artist : Smos
# 889029.0 Bug Artist : James Mc Hale
# 874069.0 Bug Artist : Lesnicar
# 874069.0 Bug Artist : Chad Andrew
# 788549.0 Bug Artist : Jame Mc Hale
# 788544.0 Bug Artist : Jame McHale
# 835580.0 Bug Artist : Purpurea
# 835580.0 Bug Artist : Adva
# 720128.0 Bug Artist : Sandro Kuhne
# 840218.0 Bug Artist : Der Dirigent
# 840218.0 Bug Artist : Jam On
# 724486.0 Bug Artist : Marco Silva
# 740666.0 Bug Artist : EnzoMr.TrendPianzola
# 735483.0 Bug Artist : MR.TREND
# 743281.0 Bug Artist : JOHNY BLAZE
# 743281.0 Bug Artist : FABIAN BINKERT
# 743281.0 Bug Artist : MARQUE AUREL & MUSIC P
# 743281.0 Bug Artist : Mike Kay
# 743281.0 Bug Artist : ANDREW THE GRAND
# 743281.0 Bug Artist : FRED LICCI
# 743281.0 Bug Artist : OTIST RIDDIM
# 743281.0 Bug Artist : DANIEL BROESECKE
# 811545.0 Bug Artist : Special Guest: Mia Kaltes
# 811545.0 Bug Artist : Markus haZe
# 811545.0 Bug Artist : Intro by Meschuggo
# 761680.0 Bug Artist : Sanmon
# 761680.0 Bug Artist : Die Kistenkerle
# 761680.0 Bug Artist : Peter Szanto
# 743478.0 Bug Artist : Bonafide 3000 ISR live. Support: FEA Soundsytem BE
# 759992.0 Bug Artist : Rio Wolta
# 759992.0 Bug Artist : Delorian Cloud Fire
# 750212.0 Bug Artist : Neevo
# 750212.0 Bug Artist : Perlon - Berlin
# 701698.0 Bug Artist : Actamin
# 701698.0 Bug Artist : Adolpho & Franky
# 597694.0 Bug Artist : Azimute aka Quenum & Cesare vs Disorder
# 597694.0 Bug Artist : Dacid
# 155194.0 Bug Artist : Floor 2 : Miss Flora
# 155194.0 Bug Artist : Darko Stronqvist
# 155194.0 Bug Artist : Konpiuta
# 155194.0 Bug Artist : D-Andy vs T-Rony
# 155194.0 Bug Artist : Floor 1 : Shrubbn!!
# 155194.0 Bug Artist : Skizofred
# 155194.0 Bug Artist : Copains Sauvages
# 112785.0 Bug Artist : Main Floor :
# 112785.0 Bug Artist : Dr. Fad-R
# 112785.0 Bug Artist : Chic Miniature aka Guillaume & The Coutu-Dumonts & Ernesto Ferreyra
# 53465.0 Bug Artist : Ramon Lorenzo
# 53465.0 Bug Artist : Léonard de Léonard
# 53465.0 Bug Artist : G Work
# 53465.0 Bug Artist : Chris de Luca vs Phon.o
# 53465.0 Bug Artist : 2nd Floor :
# 53465.0 Bug Artist : Edivad
# 53465.0 Bug Artist : Swit Honey
# 53465.0 Bug Artist : Ki-Yota
# 765070.0 Bug Artist : Perry Pierce & Doncivico
# 754432.0 Bug Artist : Dead As Disco
# 754432.0 Bug Artist : Nabin
# 757032.0 Bug Artist : Jaso LIVE
# 757032.0 Bug Artist : Symphonix LIVE
# 757032.0 Bug Artist : Kufanya
# 757032.0 Bug Artist : Oli Allen
# 757032.0 Bug Artist : Abstract
# 757032.0 Bug Artist : GetBuzz
# 809405.0 Bug Artist : Claude Laurier
# 809405.0 Bug Artist : Los Wenamigos
# 809405.0 Bug Artist : MARC BENZ
# 779541.0 Bug Artist : Fantastic Friends - Highgrade - Metroline Limited
# 779541.0 Bug Artist : LA MINE EXPRESS
# 844562.0 Bug Artist : Extrastunden
# 767991.0 Bug Artist : Bfly
# 561051.0 Bug Artist : Desolat
# 561051.0 Bug Artist : Moonharbour
# 555236.0 Bug Artist : Oram Modular
# 555236.0 Bug Artist : ZOO
# 555236.0 Bug Artist : Greg la Brelle
# 535742.0 Bug Artist : RA.PU B2B Nekow
# 535742.0 Bug Artist : EXTRASTUNDEN JONATHAN SOLO
# 401552.0 Bug Artist : Angelo B
# 349857.0 Bug Artist : Nelson De Jesus
# 356476.0 Bug Artist : Mia Kaltes | Finefood Records | Switzerland
# 364988.0 Bug Artist : Mirax
# 364988.0 Bug Artist : Michael Fate
# 364988.0 Bug Artist : Jay Mas
# 349806.0 Bug Artist : USA Live
# 349806.0 Bug Artist : Fourth Kind
# 349806.0 Bug Artist : Divided Rec
# 349806.0 Bug Artist : Reloading rec.
# 299257.0 Bug Artist : Ghetto Po
# 269849.0 Bug Artist : KONPIUTALIVE
# 269849.0 Bug Artist : GHETTO PO
# 269849.0 Bug Artist : SIMON EFFECT
# 259318.0 Bug Artist : Dineo
# 259318.0 Bug Artist : Franck C
# 186785.0 Bug Artist : G!L Everest
# 259325.0 Bug Artist : Intro by: Rocca & Dineo
# 127678.0 Bug Artist : M.A.N.D.Y. - Patrick
# 127678.0 Bug Artist : Luca de Grandis
# 127678.0 Bug Artist : JD Hakulinen
# 259512.0 Bug Artist : Enzo di Caprio
# 102266.0 Bug Artist : Club Q
# 131414.0 Bug Artist : Huazee
# 131414.0 Bug Artist : Marco da Mata
# 91103.0 Bug Artist : Contexterrior
# 91103.0 Bug Artist : Crosstown Rebels/FR
# 91103.0 Bug Artist : Dan Welton and Edgar Jack
# 87798.0 Bug Artist : Edgar Jack and Marrocco
# 74916.0 Bug Artist : Leke da Loco
# 74916.0 Bug Artist : DJ Ass
# 70281.0 Bug Artist : Timbee Rec
# 70281.0 Bug Artist : Marrocco
# 67535.0 Bug Artist : Residents:
# 67535.0 Bug Artist : Timbee/SUI
# 67535.0 Bug Artist : BP Zulauf
# 63446.0 Bug Artist : Stealth Records/UK
# 63446.0 Bug Artist : System Rec/SUI
# 63446.0 Bug Artist : Daley Padley
# 63446.0 Bug Artist : Twisted Frequency/SUI
# 107425.0 Bug Artist : J.D Hakulinen
# 765450.0 Bug Artist : Marosh Kopp
# 765450.0 Bug Artist : Andrés Marcos
# 800641.0 Bug Artist : Marque Aurel
# 774905.0 Bug Artist : MC Jay
# 767898.0 Bug Artist : Le Citadin
# 767898.0 Bug Artist : Ari Onni
# 767898.0 Bug Artist : Schwebekasten
# 767898.0 Bug Artist : König Balthasar
# 771253.0 Bug Artist : Dj Kulturshock
# 113221.0 Bug Artist : 24.00 Romanesko
# 113221.0 Bug Artist : 03.00 Juan Veloz
# 113221.0 Bug Artist : 01.30 Klaus Frauenholz
# 113221.0 Bug Artist : 21.30 Jazz T
# 113221.0 Bug Artist : 23.00 PeeKay
# 820465.0 Bug Artist : Cosi Dee
# 820465.0 Bug Artist : Don Vincent
# 820465.0 Bug Artist : DK13
# 820465.0 Bug Artist : Lino Loud
# 820465.0 Bug Artist : Marvin J
# 820465.0 Bug Artist : Betolicious
# 820465.0 Bug Artist : Nikos Voutsas
# 820465.0 Bug Artist : Luca F
# 820465.0 Bug Artist : Jibone
# 778380.0 Bug Artist : Sebastian Wojkowski
# 778380.0 Bug Artist : Gleichschritt
# 778380.0 Bug Artist : S. Rubinfeld Live Act & Vinyl only
# 895836.0 Bug Artist : / Lukie Wyniger a.k.a Uncle Peng Peng
# 895836.0 Bug Artist : / ruffPack international
# 885503.0 Bug Artist : // Dinan
# 885503.0 Bug Artist : // Strassenmajor
# 880924.0 Bug Artist : XOSE
# 880924.0 Bug Artist : Arutani
# 885055.0 Bug Artist : DJ Bazooka
# 885056.0 Bug Artist : Nik Frankenberg
# 885053.0 Bug Artist : DJ Deenasty
# 885053.0 Bug Artist : Andrew The Grand
# 885053.0 Bug Artist : Armonica
# 885053.0 Bug Artist : MAX CELLI
# 885050.0 Bug Artist : Lukie Wyniger a.k.a UNCLE PENG PENG
# 885050.0 Bug Artist : Supersonic Sound
# 885046.0 Bug Artist : HiGY
# 885046.0 Bug Artist : Aalbou
# 879771.0 Bug Artist : DuoRhythm
# 879769.0 Bug Artist : SNARDI
# 879769.0 Bug Artist : Avem
# 879765.0 Bug Artist : Instant Rave
# 879765.0 Bug Artist : Vlnolam Kawumski
# 879763.0 Bug Artist : Strassenmajor
# 879762.0 Bug Artist : Franky Fourfingers
# 879762.0 Bug Artist : Alex Anderst
# 824221.0 Bug Artist : Cipmo
# 824221.0 Bug Artist : Yare
# 828801.0 Bug Artist : DJ Jamie Lewis
# 796330.0 Bug Artist : Servet Argin
# 796330.0 Bug Artist : Xose
# 846442.0 Bug Artist : Georg Stuby
# 846442.0 Bug Artist : Masa Saji
# 846442.0 Bug Artist : Timoteo L.E.T
# 846442.0 Bug Artist : Andreas Ramos Baked ZH
# 827121.0 Bug Artist : ■ James Mc Hale Sunday Breakfast
# 827121.0 Bug Artist : ■ Mandar
# 827121.0 Bug Artist : ■ Georg Stuby Naturklang
# 827121.0 Bug Artist : ■ Nekow Newfact Music
# 815178.0 Bug Artist : ■ Sam Bangura Half Baked
# 815178.0 Bug Artist : ■ Gunnar Guess Naturklang
# 815178.0 Bug Artist : ■ Rhadoo a:rpia:r
# 815178.0 Bug Artist : ■ Greg Brockmann Half Baked
# 809469.0 Bug Artist : Stipé
# 809469.0 Bug Artist : Hug & Schiemann
# 809469.0 Bug Artist : Raresh
# 793889.0 Bug Artist : Timoteo Les Enfants Terribles
# 793889.0 Bug Artist : Flavio Sunday Breakfast
# 793889.0 Bug Artist : Ian F. Colours
# 793889.0 Bug Artist : Ajele Naturklang
# 793889.0 Bug Artist : Praslea a:rpia:r
# 781435.0 Bug Artist : Petre Inspirescu
# 784889.0 Bug Artist : FLINKE FINGER
# 784889.0 Bug Artist : AL SENTO
# 789079.0 Bug Artist : Adam Winston
# 789079.0 Bug Artist : Gypsis
# 789079.0 Bug Artist : Diego Indigo
# 789079.0 Bug Artist : Salzunpepper
# 844809.0 Bug Artist : OstGut Ton/Edinburgh
# 844809.0 Bug Artist : Morard
# 825837.0 Bug Artist : Junior-B
# 805474.0 Bug Artist : Bruno Pronsato
# 805474.0 Bug Artist : Nico Wilde
# 791266.0 Bug Artist : Oliver Aden & Luis Cruz
# 791266.0 Bug Artist : Oliver Spiess
# 831927.0 Bug Artist : Jihell
# 831927.0 Bug Artist : ManuHeme
# 823350.0 Bug Artist : YONI BANKS & YAN KA
# 823350.0 Bug Artist : BIFASICO
# 823374.0 Bug Artist : - Tanua
# 823374.0 Bug Artist : - Skail Master M
# 823374.0 Bug Artist : - El Alusinante
# 823374.0 Bug Artist : - BASSnSMILE Crew
# 823324.0 Bug Artist : CENACLE CREW
# 823324.0 Bug Artist : Hexler
# 823322.0 Bug Artist : ERISU - Artjacking et F&S
# 823322.0 Bug Artist : LoveME_Alex b2b MAD - Deep Tech Records / Malicious Smile
# 797060.0 Bug Artist : Roman Klinger
# 797060.0 Bug Artist : Juli Lee
# 797060.0 Bug Artist : She Nionika
# 798275.0 Bug Artist : Nicola Zoli
# 798275.0 Bug Artist : Giusi Consoli
# 798275.0 Bug Artist : Marco Capone
# 798753.0 Bug Artist : Cascandy live!
# 798753.0 Bug Artist : Sascha Stohler
# 790499.0 Bug Artist : 4057 BASEL
# 790499.0 Bug Artist : NEW LOCATION!! Roter Korsar UFERSTRASSE 40
# 790499.0 Bug Artist : Xetal
# 790499.0 Bug Artist : BPM | BS
# 790499.0 Bug Artist : Simon Lemont
# 802125.0 Bug Artist : Enzo Pianzola aka Mr.trend
# 803333.0 Bug Artist : Modulaw
# 803333.0 Bug Artist : La Vie Cest Facile
# 56923.0 Bug Artist : Live: Digitalism / Gus Gus / Lexy & K-Paul / The Advent / Dapayk & Padberg / Dusty Kid / Heartthrob / Einzelkind
# 56923.0 Bug Artist : DJs: Green Velvet / DJ Rush / Monika Kruse / Felix Kröcher / Moonbootica / Raudive/Oliver Ho / D.I.M. / Shonky / Xenia Beliayeva / Steve Land aka Randy / Hannah Holland / Dachshund / Agnès / Smilla / Phuture Traxx / Turntable-Babes / Ulli & Maesoo / Banga / Beda / Sandro Kühne and others to be confirmed
# 807936.0 Bug Artist : Allegra Lusini
# 809510.0 Bug Artist : Mater Fader
# 809510.0 Bug Artist : Lo2
# 811133.0 Bug Artist : GEOERGE LAMELL
# 811383.0 Bug Artist : Weith.
# 811383.0 Bug Artist : Mokship
# 811383.0 Bug Artist : Lacrema
# 811383.0 Bug Artist : Layer V
# 811383.0 Bug Artist : Hetan
# 811383.0 Bug Artist : Ito
# 830633.0 Bug Artist : Start 22:00
# 830633.0 Bug Artist : Dancehall // Hip-hop
# 830633.0 Bug Artist : DJ POSTMAN
# 825627.0 Bug Artist : DJ TASTY
# 825626.0 Bug Artist : DJ KOSMICK
# 820287.0 Bug Artist : DJ LAFOLIE ON THE MIX
# 820285.0 Bug Artist : DJ MoRFiN
# 820279.0 Bug Artist : DJ JEAN BALAISE
# 820278.0 Bug Artist : DJ SF12 & DJ LYPTIC ONE
# 818608.0 Bug Artist : DJ ST XAVIER
# 813998.0 Bug Artist : DJ Oxyxa
# 823380.0 Bug Artist : GUEST: Sebas O Verde
# 823380.0 Bug Artist : BIFASICO aka ManuHeme & LITCH
# 822705.0 Bug Artist : manuheme & Litch aka BIFASICO + Guest
# 831786.0 Bug Artist : Yann Detroit
# 831786.0 Bug Artist : Manuheme
# 827793.0 Bug Artist : Nicos Oldies
# 828781.0 Bug Artist : Luca Parravicini
# 828781.0 Bug Artist : Sandro Kühne
# 834881.0 Bug Artist : DJ Spiri
# 834881.0 Bug Artist : Fannik&Phil
# 834881.0 Bug Artist : Spaghuzz
# 834881.0 Bug Artist : Nico Audiowave
# 834881.0 Bug Artist : FS Bart
# 834881.0 Bug Artist : Insel
# 843114.0 Bug Artist : Dario La Mazza
# 843114.0 Bug Artist : Aaron Khaleian
# 843114.0 Bug Artist : Sunday:
# 843114.0 Bug Artist : Bonny & Clyde
# 843114.0 Bug Artist : Fabri
# 843114.0 Bug Artist : Friday:
# 843114.0 Bug Artist : Mic Drive
# 843114.0 Bug Artist : Enzo Lo Conte
# 843114.0 Bug Artist : Saturday:
# 843114.0 Bug Artist : Fulvio Cala
# 843114.0 Bug Artist : Andhazel
# 843114.0 Bug Artist : Juen & Bach
# 866387.0 Bug Artist : ENØS
# 866387.0 Bug Artist : Ben Def
# 866387.0 Bug Artist : WAREHOUSE :
# 866387.0 Bug Artist : Pranava
# 866387.0 Bug Artist : iiiü
# 866387.0 Bug Artist : Figure/ Düsseldorf
# 866387.0 Bug Artist : Figure/ Francfort
# 866387.0 Bug Artist : BUNKER :
# 889024.0 Bug Artist : Dejan
# 851225.0 Bug Artist : and more TBA
# 870107.0 Bug Artist : Pasci
# 870107.0 Bug Artist : Bonjour Ben
# 866715.0 Bug Artist : ScheSche & Mismo
# 846177.0 Bug Artist : Itiswhatitis
# 846177.0 Bug Artist : Barbir
# 850913.0 Bug Artist : Pender Street Steppers
# 850913.0 Bug Artist : ALON LEVI
# 850913.0 Bug Artist : CNDR
# 838844.0 Bug Artist : Brothers in Arms
# 838844.0 Bug Artist : Thomas Wood & Alon Levi
# 846814.0 Bug Artist : Nahste Oner
# 886958.0 Bug Artist : Bedran.
# 847577.0 Bug Artist : Lilly Palmer
# 847577.0 Bug Artist : Marvin Aloys
# 847577.0 Bug Artist : Fabian Ulmer & more
# 847577.0 Bug Artist : Sprout Haris
# 849745.0 Bug Artist : Reklok
# 849745.0 Bug Artist : Nomarel
# 849745.0 Bug Artist : R.M.E.K
# 849745.0 Bug Artist : Mov Elan
# 849745.0 Bug Artist : The Chronics
# 849745.0 Bug Artist : Albert & Hofmann
# 852173.0 Bug Artist : Ismail & Clive
# 852173.0 Bug Artist : Valentin Boesch
# 852173.0 Bug Artist : Zurich
# 852173.0 Bug Artist : Burt Cobain & Ali - Alburt
# 852169.0 Bug Artist : London
# 852169.0 Bug Artist : Zürich
# 852165.0 Bug Artist : Âme
# 852165.0 Bug Artist : Masaya - Official Fanpage
# 181746.0 Bug Artist : MANDEG ZH
# 181746.0 Bug Artist : Partikel ZH
# 181746.0 Bug Artist : Lineas De Nazca MEX
# 181746.0 Bug Artist : Dualism ZH
# 181746.0 Bug Artist : FREITAG & FREINACHT ZH
# 853101.0 Bug Artist : ◘ JOSKO ANTEK
# 853101.0 Bug Artist : ◘ NICKY F
# 853101.0 Bug Artist : ◘ HERTS
# 853101.0 Bug Artist : Dropout Agency
# 853101.0 Bug Artist : Baile Musik / BE
# 853101.0 Bug Artist : Dropout Agency / BE
# 853101.0 Bug Artist : ◘ OLIVER CLICHÉ
# 853101.0 Bug Artist : Noel Audio
# 853101.0 Bug Artist : ◘ JOHN TAALSBERG
# 853101.0 Bug Artist : D-Vision / BE
# 853101.0 Bug Artist : ◘ A-SON
# 853101.0 Bug Artist : ◘ Accama
# 853101.0 Bug Artist : ◘ Bfly Steiner / Nahste Oner
# 853101.0 Bug Artist : ◘ ?!
# 853101.0 Bug Artist : ◘ Phil Cole
# 853101.0 Bug Artist : ◘ Thom Mayr
# 853101.0 Bug Artist : ◘ Chuck Poland
# 853101.0 Bug Artist : skurill / BE
# 853101.0 Bug Artist : Yourube Grooves / BE
# 853101.0 Bug Artist : ◘ DON CREEK / Freaky A
# 853101.0 Bug Artist : ◘ MÉNAGE À TROIS
# 853101.0 Bug Artist : Dubculture / BE
# 853101.0 Bug Artist : ◘ FLYING AWAY
# 853101.0 Bug Artist : ◘ Nicola Koch
# 853101.0 Bug Artist : Get Funky / BE
# 853101.0 Bug Artist : ◘ PEDRAM
# 202640.0 Bug Artist : Sdanke
# 854368.0 Bug Artist : Signor Rossi
# 854368.0 Bug Artist : Domenico Dagnelli
# 857102.0 Bug Artist : Strange Loving
# 857102.0 Bug Artist : Visionkids
# 865204.0 Bug Artist : Tristan Bohn
# 865204.0 Bug Artist : Yves Helbling
# 865204.0 Bug Artist : First Claz
# 865204.0 Bug Artist : Get Physical
# 861403.0 Bug Artist : Raphaello
# 864099.0 Bug Artist : Ronald Grauer
# 864099.0 Bug Artist : Dejan // Cityfox
# 864099.0 Bug Artist : Dario DAttis Official
# 864099.0 Bug Artist : Hernan Cayetano
# 864099.0 Bug Artist : San Francisco
# 864099.0 Bug Artist : Hive Audio
# 860265.0 Bug Artist : Manuel Fischer
# 860265.0 Bug Artist : Alex Dallas
# 860263.0 Bug Artist : Phil zviel
# 860260.0 Bug Artist : Mad-o
# 860260.0 Bug Artist : Heartleader
# 860260.0 Bug Artist : Calado
# 860257.0 Bug Artist : SHKAMB
# 860257.0 Bug Artist : Robby Naish
# 860256.0 Bug Artist : Camiolo
# 860256.0 Bug Artist : Gallo
# 860256.0 Bug Artist : Soulmate
# 861390.0 Bug Artist : Modnar
# 857342.0 Bug Artist : Sentiment
# 857342.0 Bug Artist : SK Supreme
# 857342.0 Bug Artist : Emage
# 860253.0 Bug Artist : Dani Nydegger
# 860253.0 Bug Artist : Herr Müller
# 857438.0 Bug Artist : Ilona Maras
# 865927.0 Bug Artist : Scissor me Senseless
# 865927.0 Bug Artist : Stefano Ritteri
# 865927.0 Bug Artist : Tatum Rush
# 865990.0 Bug Artist : SonerTshichek
# 866950.0 Bug Artist : Roberta Nicholls all Day
# 866210.0 Bug Artist : Marco Folli
# 869254.0 Bug Artist : DJ Coma
# 869254.0 Bug Artist : Psycho Weazel
# 869254.0 Bug Artist : Mia Kaltes
# 869254.0 Bug Artist : Speedrax
# 869254.0 Bug Artist : Boloko
# 869085.0 Bug Artist : Michel Cleis
# 869085.0 Bug Artist : Rainer Trüby
# 871645.0 Bug Artist : Ajele
# 107469.0 Bug Artist : Mental X
# 107469.0 Bug Artist : Tim Davidson
# 107469.0 Bug Artist : + Support
# 63216.0 Bug Artist : DJ Tomic
# 63216.0 Bug Artist : Peter Lavelle
# 697479.0 Bug Artist : Little Victor
# 697476.0 Bug Artist : Swissdeep
# 635507.0 Bug Artist : Music selected by
# 635507.0 Bug Artist : Special Guest
# 635507.0 Bug Artist : Frank Vespari & Little Victor
# 131922.0 Bug Artist : Session Deluxe
# 63453.0 Bug Artist : DJs René S.
# 63453.0 Bug Artist : other location
# 63453.0 Bug Artist : P. Carrado
# 63453.0 Bug Artist : Ivan R.
# 833809.0 Bug Artist : PSYCHO WEAZEL
# 411982.0 Bug Artist : X BADKLAAT
# 411982.0 Bug Artist : http://soundcloud.com/mr-pigman
# 411982.0 Bug Artist : UK Dubstar/Bassclash
# 411982.0 Bug Artist : CH Tomorrow Is Today
# 411982.0 Bug Artist : X MR.PIGMAN
# 411982.0 Bug Artist : X DUBDAVE
# 373645.0 Bug Artist : Konpiuta Live
# 373645.0 Bug Artist : David Fjörgenson Live
# 373645.0 Bug Artist : Finefood
# 373645.0 Bug Artist : 237
# 374351.0 Bug Artist : David Fjörgenson
# 374351.0 Bug Artist : 237 Family
# 263142.0 Bug Artist : LUDOVIC B
# 263142.0 Bug Artist : SUPERMAFIA
# 254311.0 Bug Artist : Zenit / Faust / Raphallus
# 254311.0 Bug Artist : T. Williams
# 257132.0 Bug Artist : CASQUE -
# 257132.0 Bug Artist : Julien Aubert
# 257132.0 Bug Artist : JOE GALEN
# 240079.0 Bug Artist : Nik! dj
# 240079.0 Bug Artist : .Suffix visuals
# 240079.0 Bug Artist : Feldermelder
# 200576.0 Bug Artist : Vacintosh
# 200576.0 Bug Artist : Beats On Demand
# 64325.0 Bug Artist : Grnd lop prod.
# 64325.0 Bug Artist : Toppaz / Berlin
# 64325.0 Bug Artist : Custom Tea
# 897418.0 Bug Artist : Wunschkinder
# 897418.0 Bug Artist : MAUVE
# 897418.0 Bug Artist : Florian Defunes
# 897418.0 Bug Artist : Miniload
# 897418.0 Bug Artist : Dj Toy-o
# 897418.0 Bug Artist : Oliver K.
# 897418.0 Bug Artist : Ling & Mexx
# 885089.0 Bug Artist : Amsterdam
# 885089.0 Bug Artist : ✘ Local Support:
# 885089.0 Bug Artist : Franky Fiction
# 885089.0 Bug Artist : André Galluzzi
# 885089.0 Bug Artist : ✘ Lineup:
# 885089.0 Bug Artist : Berghain Ostgut
# 885089.0 Bug Artist : KE:NT
# 885089.0 Bug Artist : Michael Seelenruhig
# 878363.0 Bug Artist : Ninette
# 878363.0 Bug Artist : Steffen Flum
# 878363.0 Bug Artist : Lineup:
# 878363.0 Bug Artist : Local Support:
# 867001.0 Bug Artist : Nikolaj Tange Lange
# 867001.0 Bug Artist : Raw Vox
# 867001.0 Bug Artist : Florian MSK
# 861230.0 Bug Artist : FREDi Salomon
# 861230.0 Bug Artist : PHILLIP INÄBNIT
# 861230.0 Bug Artist : JOHN MAD & NORA
# 861230.0 Bug Artist : NED ONEAL
# 861230.0 Bug Artist : BJÖRN LOMAR
# 861230.0 Bug Artist : LAMPENFIEBER
# 861230.0 Bug Artist : NESHA
# 861230.0 Bug Artist : Mike Väth
# 861230.0 Bug Artist : THEX
# 861230.0 Bug Artist : SONABZ
# 859962.0 Bug Artist : Xander Valley
# 859962.0 Bug Artist : Sonabz
# 856550.0 Bug Artist : RJR
# 856550.0 Bug Artist : ✘ Lineup Indoor / Mainfloor:
# 856550.0 Bug Artist : ✘ Lineup Open Air:
# 856550.0 Bug Artist : Borderliners Rec.
# 856550.0 Bug Artist : The M&B Experiment!
# 856550.0 Bug Artist : Chris Koegler
# 856550.0 Bug Artist : Ned O Neal
# 856550.0 Bug Artist : Johny Blaze
# 856550.0 Bug Artist : Marcos Del Sol
# 856550.0 Bug Artist : Björn Lomar
# 856550.0 Bug Artist : Deeperfect
# 847417.0 Bug Artist : Me Dro
# 847417.0 Bug Artist : Rick Even
# 847417.0 Bug Artist : KK3D
# 847417.0 Bug Artist : Pfeffy
# 847417.0 Bug Artist : Tschespito
# 847417.0 Bug Artist : Marcos del Sol
# 847417.0 Bug Artist : Azzuro
# 847417.0 Bug Artist : Tom H
# 847416.0 Bug Artist : Guzzle
# 847416.0 Bug Artist : Azoth
# 847416.0 Bug Artist : Gobbit
# 847416.0 Bug Artist : Kopfkino 3D
# 847413.0 Bug Artist : Centaury
# 847413.0 Bug Artist : Madwave
# 847413.0 Bug Artist : Magicstone
# 847413.0 Bug Artist : Proud
# 847413.0 Bug Artist : Neutronix
# 847413.0 Bug Artist : Carl Jack aka Abdomen
# 847413.0 Bug Artist : Nemok6
# 829221.0 Bug Artist : Rusconi
# 829221.0 Bug Artist : Kiril Bikov
# 829221.0 Bug Artist : Luis Roza
# 829221.0 Bug Artist : Boris Dolinski
# 829221.0 Bug Artist : Nina Nana
# 834274.0 Bug Artist : Toy - O
# 834274.0 Bug Artist : Italoboyz - Marco Donato
# 834274.0 Bug Artist : Albi
# 834273.0 Bug Artist : Sternenwanderer
# 834273.0 Bug Artist : Doppelpack
# 867551.0 Bug Artist : Monaberry
# 874363.0 Bug Artist : Nicola Noir
# 874356.0 Bug Artist : Bassbüro
# 874355.0 Bug Artist : Bas Ibellini
# 868741.0 Bug Artist : Hot Trax
# 868741.0 Bug Artist : Mother Recordings - DE
# 850856.0 Bug Artist : Permanent Triangle
# 850856.0 Bug Artist : Techrifice
# 850856.0 Bug Artist : Morgan Button
# 848932.0 Bug Artist : Steven Wallace
# 848932.0 Bug Artist : Lejuste
# 838814.0 Bug Artist : DRESSCODE: all in white!
# 838814.0 Bug Artist : DISCOfloor
# 838814.0 Bug Artist : Electronica Floor:
# 838814.0 Bug Artist : Animation by:Anish & The PDG
# 838814.0 Bug Artist : Muri
# 838814.0 Bug Artist : GREEKfloor
# 838814.0 Bug Artist : House Floor
# 841208.0 Bug Artist : Gil Glaze
# 832248.0 Bug Artist : Qebeq
# 832248.0 Bug Artist : Lost at
# 820927.0 Bug Artist : Stil vor Talent
# 822295.0 Bug Artist : Gunes Ergun
# 822295.0 Bug Artist : Costa Del Soul DJ Team
# 236255.0 Bug Artist : Profondo
# 236255.0 Bug Artist : Robel
# 357264.0 Bug Artist : Miss Peel
# 357264.0 Bug Artist : Alice Hänsenberger
# 181158.0 Bug Artist : fabien
# 150946.0 Bug Artist : ANDON
# 150946.0 Bug Artist : JAN-K
# 124478.0 Bug Artist : Harry Klein
# 117775.0 Bug Artist : Ez Raidler
# 117775.0 Bug Artist : Knut2010
# 116041.0 Bug Artist : Der Junge mit der Trompete
# 116041.0 Bug Artist : Chris Air
# 71320.0 Bug Artist : Makau AND FILAFERRO
# 71320.0 Bug Artist : Shimono
# 289647.0 Bug Artist : and others ....
# 289647.0 Bug Artist : Piratenkind
# 149308.0 Bug Artist : Franz Filter
# 149308.0 Bug Artist : Shahira
# 149308.0 Bug Artist : Pixelpunks
# 139495.0 Bug Artist : Tracknics
# 139495.0 Bug Artist : more tba
# 121575.0 Bug Artist : Daniel Marrone
# 121575.0 Bug Artist : Attilio
# 121575.0 Bug Artist : TUBA
# 121575.0 Bug Artist : Radro
# 121575.0 Bug Artist : Dean Breda
# 121061.0 Bug Artist : Ben Purple
# 121061.0 Bug Artist : Alphajet
# 78477.0 Bug Artist : Radro & DANIEL MARRONE
# 78477.0 Bug Artist : TROMBETA
# 78477.0 Bug Artist : CLAUDE STAFFIERI
# 86163.0 Bug Artist : Dj RP
# 46479.0 Bug Artist : Philip G. Cifuentes
# 260668.0 Bug Artist : Don Tetris
# 260668.0 Bug Artist : Razha
# 260668.0 Bug Artist : Dicke Lauscher
# 260668.0 Bug Artist : Chris de Rebel
# 260668.0 Bug Artist : Jutzi
# 95234.0 Bug Artist : Wicked Wiggler and later Fa_bien!
# 90614.0 Bug Artist : Fa.bien
# 879939.0 Bug Artist : Dr!ve
# 879939.0 Bug Artist : Bowser
# 771577.0 Bug Artist : David Suivez
# 771577.0 Bug Artist : Spectron
# 771577.0 Bug Artist : Nkelo Live
# 771577.0 Bug Artist : Boumi B
# 759987.0 Bug Artist : LUKII
# 759987.0 Bug Artist : FORSITION
# 759987.0 Bug Artist : FRANK RICH
# 759987.0 Bug Artist : MAKA
# 759987.0 Bug Artist : C-FLOW
# 759987.0 Bug Artist : RICO LOCO
# 759987.0 Bug Artist : MORGANJ
# 759987.0 Bug Artist : LUKAS FREUDENBERGER
# 759987.0 Bug Artist : TOM BLAKE
# 759987.0 Bug Artist : LARS LINDENBERG
# 661306.0 Bug Artist : ---Meerganglied
# 641603.0 Bug Artist : Nikola Kotevski
# 641603.0 Bug Artist : Mareena
# 641597.0 Bug Artist : Enrico Valenti
# 641597.0 Bug Artist : Marion K.
# 641597.0 Bug Artist : Double & Parkz
# 641597.0 Bug Artist : M+M
# 641597.0 Bug Artist : Simply Simon
# 641597.0 Bug Artist : C-Flow
# 641597.0 Bug Artist : Lukii
# 641597.0 Bug Artist : Bruno Minimal
# 641597.0 Bug Artist : Forsition
# 641597.0 Bug Artist : Frank Rich
# 641594.0 Bug Artist : Moinsen
# 641594.0 Bug Artist : Chipe
# 641594.0 Bug Artist : Ziiva aka Lukii
# 641594.0 Bug Artist : Tom Blake
# 641594.0 Bug Artist : Wiggaz
# 642834.0 Bug Artist : Mischkultur
# 642834.0 Bug Artist : Bern
# 642834.0 Bug Artist : Rico Rausch b2b der Dirigent
# 642834.0 Bug Artist : Nicola Koch b2b Peter Szanto
# 642834.0 Bug Artist : Baile Musik
# 642834.0 Bug Artist : Stuart Hawkins
# 629468.0 Bug Artist : Das Balz b2b Adrian Bergmann
# 629468.0 Bug Artist : Vanita b2b Low.Tales
# 629468.0 Bug Artist : Mira b2b Chris Schwarzwälder
# 608437.0 Bug Artist : Konvex 2:
# 608437.0 Bug Artist : Thomas Mayr
# 608437.0 Bug Artist : Konvex 1:
# 601807.0 Bug Artist : Sav Manganaro
# 601807.0 Bug Artist : Rich vom Dorf
# 593567.0 Bug Artist : Rodri
# 581769.0 Bug Artist : Rennie Røyma & Kåre Kyl
# 581769.0 Bug Artist : Frankfurt
# 581769.0 Bug Artist : Das Balz b2b Amelié
# 581769.0 Bug Artist : Rico Rausch
# 576990.0 Bug Artist : Marcel Vivo aka mr.rox
# 576990.0 Bug Artist : Marco Di Natale
# 576990.0 Bug Artist : Dj Faith
# 576987.0 Bug Artist : Plassix
# 576987.0 Bug Artist : Le Bérger
# 576987.0 Bug Artist : Maurer & Toepfer
# 570690.0 Bug Artist : Rico Rausch b2b Der Dirigent
# 853109.0 Bug Artist : Thom Mayr
# 853109.0 Bug Artist : Dubculture ∆ Event
# 853109.0 Bug Artist : Lesničar
# 165103.0 Bug Artist : Soleyu
# 94182.0 Bug Artist : Atol
# 93443.0 Bug Artist : stefano m.
# 92681.0 Bug Artist : DJs Atol
# 830068.0 Bug Artist : Apollonia
# 852982.0 Bug Artist : VJing by Maak
# 852982.0 Bug Artist : Eevy
# 852982.0 Bug Artist : Orsett
# 847301.0 Bug Artist : Mobilee - Zurich
# 847301.0 Bug Artist : Cityfox - Zurich
# 847301.0 Bug Artist : SK Supreme - Zurich
# 847301.0 Bug Artist : Poker Flat
# 847301.0 Bug Artist : Strictly Rhythm - Zurich
# 847040.0 Bug Artist : Alex Dallas b2b Kalabrese
# 847037.0 Bug Artist : Electron - Geneva
# 847035.0 Bug Artist : Ripperton b2b Deetron
# 846937.0 Bug Artist : Reklok live
# 846937.0 Bug Artist : Clarisse - Lausanne
# 846937.0 Bug Artist : Berghain - Berlin
# 846937.0 Bug Artist : Djerry C
# 846937.0 Bug Artist : MDR
# 846933.0 Bug Artist : mOOving
# 846933.0 Bug Artist : Cadenza - Lausanne
# 846933.0 Bug Artist : Soulfooled - Geneva
# 846933.0 Bug Artist : Dirty Flav
# 846930.0 Bug Artist : SuCré SaLé
# 846930.0 Bug Artist : Fantastic Friends Recordings - Lausanne
# 846930.0 Bug Artist : Bar25 - Berlin
# 846634.0 Bug Artist : Jeremy Underground
# 846634.0 Bug Artist : Bauchamp
# 846603.0 Bug Artist : Dement3d - Geneva
# 846603.0 Bug Artist : Techno Venus - Lausanne
# 846603.0 Bug Artist : Drumcode - Firenze
# 846592.0 Bug Artist : Diynamic - Lausanne
# 846570.0 Bug Artist : Sonny Catanese b2b Lucas Ramirez
# 846570.0 Bug Artist : Alex Mota
# 846570.0 Bug Artist : Lost Heritage live
# 846553.0 Bug Artist : Saved - Switzerland
# 846553.0 Bug Artist : Clarisse
# 846553.0 Bug Artist : Watergate - Switzerland
# 730303.0 Bug Artist : FlexFab
# 460681.0 Bug Artist : Salidamusic
# 460676.0 Bug Artist : elex morano & sandro s.
# 460676.0 Bug Artist : deep bros
# 460676.0 Bug Artist : daniele zaccone
# 460676.0 Bug Artist : danielson & norbert.to
# 460676.0 Bug Artist : tanzsubstanz
# 460676.0 Bug Artist : Mike & Nika
# 443350.0 Bug Artist : Francesco Ballato
# 261166.0 Bug Artist : Baschgi Schuub
# 261166.0 Bug Artist : Scody live
# 182313.0 Bug Artist : and Guest
# 118343.0 Bug Artist : Fran-G and Bee Lincoln!
# 93565.0 Bug Artist : Mr Pablo & guests.
# 781035.0 Bug Artist : Sonja Moonear
# 650045.0 Bug Artist : Nastia
# 536950.0 Bug Artist : 21:00 - 23:00 Animal Trainer
# 536950.0 Bug Artist : 15:00 - 17:00 Sascha Braemer & Niconé
# 536950.0 Bug Artist : 19:00 - 21:00 TBA
# 536950.0 Bug Artist : 17:00 - 19:00 Monkey Safari
# 536950.0 Bug Artist : 14:00 - 15:00 Kyrill & Redford
# 536950.0 Bug Artist : 23:00 - 00:00 David August
# 536950.0 Bug Artist : 13:00 - 14:00 TBA
# 536948.0 Bug Artist : 17:00 - 19:00 Adana Twins
# 536948.0 Bug Artist : 14:00 - 14:30 Betty & Ford
# 536948.0 Bug Artist : 15:00 - 17:00 Adriatique
# 536948.0 Bug Artist : 21:00 - 23:00 Nina Kraviz
# 536948.0 Bug Artist : 23:00 - 00:00 Kollektiv Turmstrasse
# 536948.0 Bug Artist : 14:30 - 15:00 James Mc Hale
# 536948.0 Bug Artist : 19:00 - 21:00 Oliver Koletzki
# 94660.0 Bug Artist : S-Biene
# 94660.0 Bug Artist : pasci
# 94660.0 Bug Artist : Marco Repetto
# 94660.0 Bug Artist : P. Bell
# 94660.0 Bug Artist : Technik
# 94660.0 Bug Artist : thomonn
# 94660.0 Bug Artist : ladybruce und monair
# 94660.0 Bug Artist : Bang Goes
# 597078.0 Bug Artist : marco k
# 597078.0 Bug Artist : Mr.Lucky
# 597078.0 Bug Artist : tom tek
# 597078.0 Bug Artist : techno machine
# 597078.0 Bug Artist : minitek
# 97686.0 Bug Artist : Mirk Oh
# 97686.0 Bug Artist : Rock Artisti
# 539988.0 Bug Artist : dj Zest
# 416565.0 Bug Artist : Zest half-hours
# 363280.0 Bug Artist : Dj Zest
# 344860.0 Bug Artist : DJ ZEST
# 272633.0 Bug Artist : Peter D.
# 167664.0 Bug Artist : Freshmint
# 167664.0 Bug Artist : Magic Mixers
# 167664.0 Bug Artist : Dave Dalux
# 167935.0 Bug Artist : dj lynn jordan
# 150541.0 Bug Artist : DJ Lynn Jordan
# 134407.0 Bug Artist : Le Petit Lutin
# 134407.0 Bug Artist : Nahoma
# 99074.0 Bug Artist : StatedLife
# 99074.0 Bug Artist : Chaton
# 853103.0 Bug Artist : * The Siegfrieds & Toys
# 290551.0 Bug Artist : Cosmic / Bern
# 290551.0 Bug Artist : LARA feat. Babag&Cholon
# 290551.0 Bug Artist : TOILET ACOUSTIC
# 200575.0 Bug Artist : Space Rangerz
# 125476.0 Bug Artist : The Proxy
# 125476.0 Bug Artist : Kid Silly
# 125476.0 Bug Artist : Kenjiro Ultramagnetic
# 101186.0 Bug Artist : Slapdance & Sandy Pants.
# 101186.0 Bug Artist : DMT Synth
# 121512.0 Bug Artist : LeLe
# 121512.0 Bug Artist : Parra Soundsystem
# 770691.0 Bug Artist : DEJAN
# 733811.0 Bug Artist : THOMAS WOOD
# 733811.0 Bug Artist : DZANIN
# 733811.0 Bug Artist : JOHN CATALANO
# 733811.0 Bug Artist : EMETERIA
# 341261.0 Bug Artist : Kara_Maehl
# 341261.0 Bug Artist : PERFECT STRANGER Live
# 341261.0 Bug Artist : BOUNCER aka Marcosis
# 344420.0 Bug Artist : Uhuruku
# 344420.0 Bug Artist : Zodiak
# 344420.0 Bug Artist : Chris Hoever
# 232792.0 Bug Artist : DAVID FRAKA
# 232792.0 Bug Artist : Electribe Germany
# 232792.0 Bug Artist : Echoes CH
# 232792.0 Bug Artist : ANDERSEN
# 232792.0 Bug Artist : FRANK BECKERS
# 200507.0 Bug Artist : www.myspace.com/mapusamapusa
# 200507.0 Bug Artist : Kinky Beats
# 200507.0 Bug Artist : Dänemark
# 200507.0 Bug Artist : www.myspace.com/ibogaemok
# 200507.0 Bug Artist : N.O.I.A. Italy
# 200507.0 Bug Artist : MAPUSA MAPUSA
# 200507.0 Bug Artist : Italy
# 200507.0 Bug Artist : DekaDance
# 200507.0 Bug Artist : www.myspace.com/djs2dirty
# 200507.0 Bug Artist : www.myspace.com/djmanon
# 200507.0 Bug Artist : www.myspace.com/piatto
# 200507.0 Bug Artist : Nuuktal Rec. CH
# 200507.0 Bug Artist : FREITAG & FREINACHT
# 200507.0 Bug Artist : www.myspace.com/moosfiebr
# 186494.0 Bug Artist : P-frequency
# 186494.0 Bug Artist : Dj Soulgear
# 186494.0 Bug Artist : Neil Landstrumm vs. Bill Youngman
# 186494.0 Bug Artist : T.S.B.I.N. aka T.S.N. and SBI
# 171939.0 Bug Artist : MIK MAROO kumquat ZURICH
# 171939.0 Bug Artist : MAY KAY pincode - minimal-mood BELLINZONA
# 171939.0 Bug Artist : Click Click kassette records BERLIN
# 171939.0 Bug Artist : Gleichschritt esance - grundton ZURICH
# 215177.0 Bug Artist : Beckers
# 215177.0 Bug Artist : Yuli
# 215177.0 Bug Artist : Pat Patrisha
# 103151.0 Bug Artist : Simian Keiser
# 699958.0 Bug Artist : Kev the Head
# 420819.0 Bug Artist : soleyu
# 420819.0 Bug Artist : djs tinib.erneoptimist
# 278371.0 Bug Artist : berneoptimist-allstarz
# 207653.0 Bug Artist : Tini B.
# 736464.0 Bug Artist : Floriano Albertini
# 419484.0 Bug Artist : D-Andy & J Rony
# 419484.0 Bug Artist : Metanoize
# 419484.0 Bug Artist : djs Biodan
# 419484.0 Bug Artist : Alek Sys
# 419484.0 Bug Artist : Nora Bora
# 417056.0 Bug Artist : Fine selection of tartineurs
# 488401.0 Bug Artist : Doppel Dipp
# 488401.0 Bug Artist : Mokic
# 488401.0 Bug Artist : aka Seb & GaLaBar
# 488398.0 Bug Artist : Sins
# 337578.0 Bug Artist : Laurent Charbon Hummingbird / Lausanne
# 337578.0 Bug Artist : Rainer Desolat / Barcelone
# 326764.0 Bug Artist : Chris Bailey
# 334956.0 Bug Artist : Chris Bailey Ultimate Groove
# 326819.0 Bug Artist : Daniel DB
# 326566.0 Bug Artist : Chris Bailey all night long
# 324743.0 Bug Artist : Tony-P
# 311380.0 Bug Artist : Friedas Büxe
# 311380.0 Bug Artist : D-andy & T-rony
# 311380.0 Bug Artist : Jean Meyer
# 311379.0 Bug Artist : Freiberg
# 311379.0 Bug Artist : Motel Campo
# 311377.0 Bug Artist : Yan Ka
# 311377.0 Bug Artist : Schaermoments
# 311377.0 Bug Artist : Dadive
# 306285.0 Bug Artist : Chris Bailley
# 306285.0 Bug Artist : Mat Kay
# 304429.0 Bug Artist : 22:00 - 00:30 Max Nero
# 304429.0 Bug Artist : 00:30 - 02:30 La Fée Verte
# 304429.0 Bug Artist : 02:30 - 05:00 Valentino
# 303235.0 Bug Artist : Gepe Tuzzo
# 300483.0 Bug Artist : 22h00-00h00 Pandallougi
# 300483.0 Bug Artist : LoMidHigh
# 300483.0 Bug Artist : 00h00-02h00 Emmat
# 300483.0 Bug Artist : 02h00-04h45 Franco Cinelli
# 297917.0 Bug Artist : 02h30 - 05h00 Pasci
# 297917.0 Bug Artist : 00h30 - 02h30 D-andy & T-rony
# 297917.0 Bug Artist : 22h00 - 00h30 Mia Kaltes
# 294807.0 Bug Artist : 03h00-04h45 Jacqui
# 294807.0 Bug Artist : 01h00-03h00 Bruno Pronsato
# 294807.0 Bug Artist : 22h00-01h00 Felipe Acevedo
# 259392.0 Bug Artist : Benja
# 259392.0 Bug Artist : Hive Audio showcase with :
# 260666.0 Bug Artist : DIRTYMADSOUND
# 260666.0 Bug Artist : GOLD HANGOVER
# 260666.0 Bug Artist : SHAKE IT MASCHINE & MR. PIGMAN
# 260666.0 Bug Artist : Cosmic Bastards
# 226045.0 Bug Artist : Raphael Prest
# 226045.0 Bug Artist : - Warm up -
# 201080.0 Bug Artist : Chapelier fou
# 201080.0 Bug Artist : Sam Ka
# 196663.0 Bug Artist : YANN STUCKI
# 221544.0 Bug Artist : Lil Fry
# 147429.0 Bug Artist : Pryus & Psyon
# 147429.0 Bug Artist : DrumnBass / Breaks
# 147429.0 Bug Artist : TAZ
# 147429.0 Bug Artist : VJs: Namo & Dr. Tintenblut
# 147429.0 Bug Artist : MC Stone
# 129774.0 Bug Artist : DJ Fever
# 129774.0 Bug Artist : Honeya
# 129774.0 Bug Artist : MC Yasmine
# 113347.0 Bug Artist : Ast
# 113347.0 Bug Artist : Harry Klein- Lausanne
# 82626.0 Bug Artist : 03:00-05:00 : Limic -aka Lio M-
# 82626.0 Bug Artist : 23h-05h00
# 82626.0 Bug Artist : 23:00-01:00 : Pedro Andrade
# 82626.0 Bug Artist : Entrée 10.-
# 82626.0 Bug Artist : 00:01-03:00 : Bjorn Born -DJ-
# 545639.0 Bug Artist : Tom Bosson
# 252933.0 Bug Artist : TITTO LA ROCKA
# 252933.0 Bug Artist : NICOLA SIMIONATO
# 252933.0 Bug Artist : DAVID JIMEZ
# 252933.0 Bug Artist : VOCAL LIVE:
# 252933.0 Bug Artist : PERFORMANCE: YUNELLESKA
# 252933.0 Bug Artist : CHOREGRAPHY: ANDRE MINKUS
# 252933.0 Bug Artist : MARCO NAVARRO
# 252933.0 Bug Artist : SPECIAL VOICE:
# 252933.0 Bug Artist : ARCHIMEDE
# 252933.0 Bug Artist : SPECIAL GUEST: SHOW GIRLS VERNICE
# 252933.0 Bug Artist : ANGY DEE
# 252933.0 Bug Artist : MISS VIVIAN KANT
# 252933.0 Bug Artist : NEW YORK
# 252933.0 Bug Artist : SPECIAL GUEST DJS:
# 252933.0 Bug Artist : NALAYA BROWN
# 216609.0 Bug Artist : Zongamin
# 139669.0 Bug Artist : Simon S
# 139669.0 Bug Artist : Philipp Aregger
# 123492.0 Bug Artist : DJ Dubstep
# 837494.0 Bug Artist : Oxyd
# 837494.0 Bug Artist : Dj T.A.G. - Tresor / Berlin - Tresor.Berlin
# 837494.0 Bug Artist : The Acid hotel
# 837494.0 Bug Artist : DAN KOOK
# 456418.0 Bug Artist : Rice & Beans
# 329904.0 Bug Artist : DJ Zest
# 128911.0 Bug Artist : Onkin
# 127282.0 Bug Artist : ...
# 127280.0 Bug Artist : Keith Worthy
# 127278.0 Bug Artist : dessous
# 150808.0 Bug Artist : George Lamell
# 150808.0 Bug Artist : Cris P.
# 128584.0 Bug Artist : Transport USA
# 128584.0 Bug Artist : CRIS P.
# 128584.0 Bug Artist : DANIEL MARRONE & Radro
# 128584.0 Bug Artist : Supermarket
# 128584.0 Bug Artist : Starhouse
# 301099.0 Bug Artist : Norbert Davenport
# 247300.0 Bug Artist : Andy Forrest
# 247300.0 Bug Artist : Mas Ricardo
# 252513.0 Bug Artist : http://www.myspace.com/djbrainstormmusik
# 252513.0 Bug Artist : S2 Records
# 252513.0 Bug Artist : http://www.myspace.com/nukemproduction
# 252513.0 Bug Artist : http://www.facebook.com/djandyforrest
# 252513.0 Bug Artist : http://www.myspace.com/djskaos
# 252513.0 Bug Artist : http://www.myspace.com/djmasricardo
# 252513.0 Bug Artist : http://www.myspace.com/dj_tintin
# 252513.0 Bug Artist : minimal techhouse Floor 2
# 252513.0 Bug Artist : minimal techno Floor 1
# 252513.0 Bug Artist : http://www.myspace.com/positive-force
# 252513.0 Bug Artist : On the wheels of steel:
# 252513.0 Bug Artist : OXA
# 240893.0 Bug Artist : ukem
# 129016.0 Bug Artist : Mano Jay
# 129016.0 Bug Artist : ITALY
# 129016.0 Bug Artist : Ilanè
# 129016.0 Bug Artist : B-Light
# 129016.0 Bug Artist : Dee Martinez
# 129016.0 Bug Artist : Don Davide
# 129016.0 Bug Artist : Guisy S
# 438929.0 Bug Artist : Just like that!
# 438929.0 Bug Artist : ConAction
# 438929.0 Bug Artist : Minimalfraktion
# 248793.0 Bug Artist : Trenton
# 248793.0 Bug Artist : Treibstoff
# 248793.0 Bug Artist : Nooncat aka Alex Meshkov
# 248793.0 Bug Artist : Dilek
# 246174.0 Bug Artist : 4Line
# 246174.0 Bug Artist : Acktivism
# 246174.0 Bug Artist : Wuzz Täzz Universal
# 248753.0 Bug Artist : Mindtrip
# 248753.0 Bug Artist : Darek
# 174001.0 Bug Artist : Mafi-Ozee
# 157767.0 Bug Artist : - Dj Albee
# 157767.0 Bug Artist : - Eleminal
# 157762.0 Bug Artist : Eleminal 4h Set
# 134224.0 Bug Artist : Ned O`Neal
# 134224.0 Bug Artist : BASCHGI SCHUUB
# 134224.0 Bug Artist : MODESTINO
# 134797.0 Bug Artist : - Damien / White Lights
# 134797.0 Bug Artist : - Ned O`Neal / MinimalFraktion
# 134797.0 Bug Artist : - Angelo Gallo / Focus on Ibiza
# 134797.0 Bug Artist : Tonstau
# 134797.0 Bug Artist : - Dlo / Harrem Resident
# 134797.0 Bug Artist : - Marcos del Sol / Noches con Sol
# 134797.0 Bug Artist : - Proud / White Lights
# 134797.0 Bug Artist : - Adrian Martin / Pazzoide
# 134797.0 Bug Artist : - Fabio Tamborrini / Cocomania
# 134796.0 Bug Artist : Hureca / Crazy Hours Italy
# 134796.0 Bug Artist : Angelo Gallo / Focus on Ibiza
# 134796.0 Bug Artist : Ned O`Neal / MinimalFraktion
# 134796.0 Bug Artist : Claudio Carrera / New Star Production
# 401199.0 Bug Artist : FRQNCY
# 401199.0 Bug Artist : Liebkind
# 401199.0 Bug Artist : Hecht&Zander
# 401199.0 Bug Artist : Fukuro
# 136499.0 Bug Artist : Ryan K
# 136499.0 Bug Artist : Joe Janell
# 136499.0 Bug Artist : FreakBoutiqe
# 646930.0 Bug Artist : Volkan Ocak Official
# 646930.0 Bug Artist : Fabric London
# 626700.0 Bug Artist : To:Be
# 626700.0 Bug Artist : Durdek
# 626700.0 Bug Artist : Mickail
# 626700.0 Bug Artist : Dario Todorovic
# 626700.0 Bug Artist : Nenad J
# 626700.0 Bug Artist : Circus Company
# 517151.0 Bug Artist : Kubin
# 512073.0 Bug Artist : https://www.facebook.com/bassportcheckin?fref=ts
# 512073.0 Bug Artist : Jan Penarrubia b2b Mike Teixeira
# 470394.0 Bug Artist : SunSun Rec
# 470394.0 Bug Artist : Bassport
# 464572.0 Bug Artist : Mathieu Kubin
# 440739.0 Bug Artist : DURDEK
# 423916.0 Bug Artist : Philip Ort
# 422496.0 Bug Artist : Mathieu Kubin // REGIORAVE // AG
# 422496.0 Bug Artist : Christian Durdek // BLEIMAGNET // AG
# 396419.0 Bug Artist : Tel Aviv Israel
# 396419.0 Bug Artist : Groove On
# 396419.0 Bug Artist : Terminus Olten
# 396419.0 Bug Artist : Christian Durdek
# 361349.0 Bug Artist : Smuda
# 361349.0 Bug Artist : BANG GOES
# 360069.0 Bug Artist : Acoustic Nerds
# 360069.0 Bug Artist : Luc André
# 360201.0 Bug Artist : Kris Elements
# 360201.0 Bug Artist : Terry ONeil
# 299617.0 Bug Artist : DeeJay Q
# 299617.0 Bug Artist : PolluX
# 299617.0 Bug Artist : Dee-liver
# 299617.0 Bug Artist : Mc Annie Jacklin
# 299617.0 Bug Artist : Darius D
# 288105.0 Bug Artist : LINE-UP
# 226831.0 Bug Artist : Sa. 19 märz 2011
# 226831.0 Bug Artist : BLEIMAGNET
# 226831.0 Bug Artist : style: techhouse/minimal/techno/electronica
# 226831.0 Bug Artist : VISUALS by motionblur !!
# 226831.0 Bug Artist : eintritt: Fr. 15.-
# 226831.0 Bug Artist : Cadenza  http://www.myspace.com/tolgafidan
# 226831.0 Bug Artist : Knackig-Saftig-Wohltuned präsentiert:
# 226831.0 Bug Artist : magnetisches feld aktiv: 22:00 - 04:00Uhr
# 266856.0 Bug Artist : DjaneLaRouge
# 266856.0 Bug Artist : Steven Fox
# 266856.0 Bug Artist : Deejay Q
# 266856.0 Bug Artist : Steven Traffic
# 221933.0 Bug Artist : VISUALS by motionblu
# 221933.0 Bug Artist : Quitim
# 196991.0 Bug Artist : DeeNelli
# 192957.0 Bug Artist : Matija
# 192957.0 Bug Artist : Marco Falkone
# 165965.0 Bug Artist : Massive Jay
# 165965.0 Bug Artist : uvm
# 265490.0 Bug Artist : MC Annie Jaklin
# 265490.0 Bug Artist : MinimalistiX-Project
# 136895.0 Bug Artist : SUPERMARKET
# 136895.0 Bug Artist : Dee Nelli
# 136895.0 Bug Artist : ROHSTOFFLAGER
# 888454.0 Bug Artist : Luca Gerosa
# 888454.0 Bug Artist : Timowood.TV
# 876420.0 Bug Artist : Visuals vom Timowood.TV
# 876420.0 Bug Artist : JONES b2b LEFTHAND
# 876420.0 Bug Artist : ARTISAN
# 881301.0 Bug Artist : Marco Tegui
# 881301.0 Bug Artist : Susie Star
# 838856.0 Bug Artist : Unite Family
# 838856.0 Bug Artist : Burt Cobain
# 824783.0 Bug Artist : LUCA GEROSA
# 824783.0 Bug Artist : MALBEC
# 827309.0 Bug Artist : Francesco De Bellis
# 827309.0 Bug Artist : Am Khamsaa
# 814891.0 Bug Artist : Dave Lozano
# 805131.0 Bug Artist : Beez & Simo
# 790103.0 Bug Artist : MALEKOS BEUTEL
# 790103.0 Bug Artist : TIMWOOD.TV
# 790103.0 Bug Artist : MATIJA
# 749845.0 Bug Artist : Intro by ATA
# 708540.0 Bug Artist : Selim & Armin
# 708540.0 Bug Artist : TIMOWOOD.TV
# 708540.0 Bug Artist : THE TOYBOYS
# 702758.0 Bug Artist : 5 h Set
# 694369.0 Bug Artist : POSSA
# 694369.0 Bug Artist : FABRI
# 661278.0 Bug Artist : https://www.facebook.com/TIMOWOODtv?fref=ts
# 661278.0 Bug Artist : FELIX FOSSIL
# 661278.0 Bug Artist : GINO - Special 3 h Christmas Intro Set!
# 661278.0 Bug Artist : TIMOWOOD.TV - Visuals & Deko!
# 661278.0 Bug Artist : TOYBOYS
# 652471.0 Bug Artist : Cadenza Music
# 652471.0 Bug Artist : BERBER & PASTA
# 652471.0 Bug Artist : ARNIKA
# 641509.0 Bug Artist : Low.Tales
# 572697.0 Bug Artist : MONSIEUR MELANGE b2b KORNY
# 585358.0 Bug Artist : RA.PU & Nekow
# 585358.0 Bug Artist : BERNARDO & LOZANO
# 584307.0 Bug Artist : Buoyancy
# 576456.0 Bug Artist : HERMANSSON & MARTINEZ
# 576456.0 Bug Artist : PASCI
# 560567.0 Bug Artist : Licht im Dunkel
# 560567.0 Bug Artist : Sebastian Eduardo
# 560567.0 Bug Artist : Cherosa
# 544840.0 Bug Artist : Malekos Beutel
# 544840.0 Bug Artist : Polonium 88 b2b Tonga aka Toyboys
# 534543.0 Bug Artist : Sandro Kühne b2b Marco Trinkler
# 534543.0 Bug Artist : glas.raum
# 526138.0 Bug Artist : Styro2000
# 526138.0 Bug Artist : David Lozano
# 140506.0 Bug Artist : SOMEAIR
# 140506.0 Bug Artist : JOHAN MÖVE
# 533394.0 Bug Artist : Guy Joshua
# 533394.0 Bug Artist : Ugly Kids
# 533394.0 Bug Artist : Michael Taschinski
# 533394.0 Bug Artist : Mauro Muratti
# 244119.0 Bug Artist : Visuals: Pizz
# 244119.0 Bug Artist : Pakalolo
# 196093.0 Bug Artist : visuals by Pizz
# 154318.0 Bug Artist : Co.Mini / Betty&Ford
# 142876.0 Bug Artist : sdanke
# 879974.0 Bug Artist : Nathanael
# 879974.0 Bug Artist : CHATEAU CHEPERE ALL STAR
# 879974.0 Bug Artist : Starsand
# 833473.0 Bug Artist : Basses Terres
# 833473.0 Bug Artist : Judaah
# 833473.0 Bug Artist : The Pilotwings
# 811116.0 Bug Artist : DJ MARABOUT
# 811116.0 Bug Artist : MAXIM MAILLET
# 811116.0 Bug Artist : Space Factory
# 810185.0 Bug Artist : Nkisi
# 810185.0 Bug Artist : DAVID LAMON
# 802239.0 Bug Artist : BRU/T - DE
# 802239.0 Bug Artist : Digitalo Enterprises - NO
# 703301.0 Bug Artist : Marlon
# 686472.0 Bug Artist : Horasse
# 686472.0 Bug Artist : Tissu
# 655630.0 Bug Artist : Apron Records - USA
# 655630.0 Bug Artist : Structure and VJing by Maak
# 639866.0 Bug Artist : Babo
# 482495.0 Bug Artist : Otavio
# 482495.0 Bug Artist : Schnautzi
# 482495.0 Bug Artist : Gertude Tuning
# 474601.0 Bug Artist : Pierre Raboud
# 474601.0 Bug Artist : Julien Gremaud
# 474601.0 Bug Artist : Dracula Lewis
# 462923.0 Bug Artist : J Velez aka Professor Genius
# 404402.0 Bug Artist : Joe Galen
# 404402.0 Bug Artist : Visuals by Sophie Le Meillour
# 348834.0 Bug Artist : Eric A. - Simple & Sans Prétention / CH / House
# 348834.0 Bug Artist : Ngoc Lan - CH / HipHop
# 146160.0 Bug Artist : VJing Performance by Kreutzfeld & JJJakkob
# 146160.0 Bug Artist : Littlehouse
# 885275.0 Bug Artist : ══════ Shows & Performances ══════
# 885275.0 Bug Artist : ══════ DJ Lineup ══════
# 885275.0 Bug Artist : BEN MANSON
# 885275.0 Bug Artist : ANDROMEDA CIRCUS
# 577101.0 Bug Artist : Bardo & Salazar
# 577101.0 Bug Artist : Aftergrauer
# 577101.0 Bug Artist : Visuals by Dario DeSiena
# 486897.0 Bug Artist : Modis Chrisha
# 412025.0 Bug Artist : SheDj Sabi
# 412025.0 Bug Artist : Wide Soul
# 412025.0 Bug Artist : Dj Gaspard
# 412025.0 Bug Artist : DJ Sets
# 412025.0 Bug Artist : Shore Bar Axel
# 412025.0 Bug Artist : Zimon
# 412025.0 Bug Artist : Amazon
# 412025.0 Bug Artist : YabYum
# 412025.0 Bug Artist : Ectocasmic
# 412025.0 Bug Artist : SheDj Naima
# 412025.0 Bug Artist : The Peaking Goddess Collective Outro Concert
# 412025.0 Bug Artist : Altius
# 412025.0 Bug Artist : INFX
# 412025.0 Bug Artist : Conxion
# 412025.0 Bug Artist : XV Killist & Rocco
# 412025.0 Bug Artist : Tagtra3umer
# 412025.0 Bug Artist : SheDj Meenakshi
# 412025.0 Bug Artist : Marcosis
# 412025.0 Bug Artist : Ajja vs. Cosmosis
# 412025.0 Bug Artist : Imox
# 363603.0 Bug Artist : Boris Werner b2b Lauhaus
# 363603.0 Bug Artist : Detroit
# 363603.0 Bug Artist : FIMO feat MANOLO
# 363603.0 Bug Artist : Dan Andrei
# 378128.0 Bug Artist : Aaah Club
# 378128.0 Bug Artist : Dachkantine
# 378128.0 Bug Artist : Cristan
# 378128.0 Bug Artist : VJ Le Chat
# 378128.0 Bug Artist : Damiano Pappada
# 378128.0 Bug Artist : Limmatbeatz
# 378128.0 Bug Artist : Ringo Moon
# 377905.0 Bug Artist : MARCO P / TURNING WEEL REC/CH
# 377905.0 Bug Artist : RINGO MOON / LIMMATBEATZ/CH
# 377905.0 Bug Artist : C-PLAY/DEJAVU/CH
# 377905.0 Bug Artist : TOLYA SUHAR /NOVOTECH/KAZANTIP/KISS FM/UA
# 377905.0 Bug Artist : L.A.Williams /DJAX-UP/KUMBA REC./USA
# 377905.0 Bug Artist : PLAY TECHNO/ODESSA / UA
# 377905.0 Bug Artist : PASCAL PROSPER / TANZNATUR/BOLLWERK/CH
# 377905.0 Bug Artist : MARC FUHRMANN /PANTHERA REC/ILLUSIONROOM/CH
# 298150.0 Bug Artist : RINGO MOON
# 201712.0 Bug Artist : Jestics
# 201712.0 Bug Artist : Mainfloor: Sven Väth
# 587572.0 Bug Artist : SCHAED
# 548215.0 Bug Artist : Schaed
# 417999.0 Bug Artist : Jeff Swing b2b Cosmokolor all night long
# 389105.0 Bug Artist : - Zest
# 288568.0 Bug Artist : http://soundcloud.com/schaed
# 288568.0 Bug Artist : Schaed all night long
# 275162.0 Bug Artist : Dj Fil from 10pm to 2am
# 258557.0 Bug Artist : 22h-2h
# 189842.0 Bug Artist : -Jeff Swing
# 189842.0 Bug Artist : -Clem
# 156663.0 Bug Artist : dj Lynn Jordan
# 456094.0 Bug Artist : Quentin Mosimann
# 151077.0 Bug Artist : Sebatien B.
# 892366.0 Bug Artist : GIL live
# 892366.0 Bug Artist : Danse Noire DJs
# 892366.0 Bug Artist : Endgame
# 825836.0 Bug Artist : Mon Mec & Jean Charles de Monte Carlo
# 795905.0 Bug Artist : Fez Momo
# 714754.0 Bug Artist : DJ Bolumar
# 714754.0 Bug Artist : Think Tank DJs
# 561215.0 Bug Artist : Lucerne
# 561215.0 Bug Artist : Peak b2b Marc DArrigo
# 472936.0 Bug Artist : Danse Noire
# 472936.0 Bug Artist : Fichtre
# 446232.0 Bug Artist : TESTOSTERONE CLUB
# 446232.0 Bug Artist : Chapkmace
# 423390.0 Bug Artist : Et Vous
# 404404.0 Bug Artist : Scout Klas
# 243753.0 Bug Artist : Tim Exile LIVE
# 243753.0 Bug Artist : AEED LIVE
# 229161.0 Bug Artist : DJ Les Filles Affranchies
# 205309.0 Bug Artist : DJs O-El & Kama
# 183912.0 Bug Artist : BIS-CAR-DONG
# 183912.0 Bug Artist : Max Tundra
# 183904.0 Bug Artist : Walls
# 183904.0 Bug Artist : FICHTRE + Feldermelder
# 151109.0 Bug Artist : Monpetitponey
# 151109.0 Bug Artist : DJ O-EL & KAMA
# 151109.0 Bug Artist : Otto Von Schirach feat. Notorious Nastie
# 698112.0 Bug Artist : Helder Costa b2b Lee Low
# 698112.0 Bug Artist : Navi Playful
# 698112.0 Bug Artist : El Alusinante
# 673969.0 Bug Artist : Sound of Neptune
# 673969.0 Bug Artist : La fine équipe
# 643438.0 Bug Artist : Winter in Deutschland
# 643438.0 Bug Artist : Antipods
# 154192.0 Bug Artist : Phil Parnell
# 154192.0 Bug Artist : FR::YK
# 154192.0 Bug Artist : Damon Irving
# 154192.0 Bug Artist : Casserolband
# 313487.0 Bug Artist : Flink
# 313487.0 Bug Artist : Havanna Sound
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384             try:  # Python 2.7, use buffering of HTTP responses
# --> 385                 httplib_response = conn.getresponse(buffering=True)
#     386             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f6a137ad4289> in <module>()
#      54
#      55
# ---> 56 ClubDataFrame["EventGenre"] = ClubDataFrame.apply(getGenreByLineUp,axis=1)
#
# C:\Users\Simon\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4059                     if reduce is None:
#    4060                         reduce = True
# -> 4061                     return self._apply_standard(f, axis, reduce=reduce)
#    4062             else:
#    4063                 return self._apply_broadcast(f, axis)
#
# C:\Users\Simon\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4115                     labels = self._get_agg_axis(axis)
#    4116                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4117                                         labels=labels)
#    4118                     return Series(result, index=labels)
#    4119                 except Exception:
#
# pandas\src\reduce.pyx in pandas.lib.reduce (pandas\lib.c:43539)()
#
# pandas\src\reduce.pyx in pandas.lib.Reducer.get_result (pandas\lib.c:33736)()
#
# <ipython-input-24-f6a137ad4289> in getGenreByLineUp(s)
#      31
#      32         if(len(artist)>2 and artist not in ARTIST_GENRE):
# ---> 33             genre = AE.getGenre(artist)
#      34             #print(genre)
#      35             if(genre==None):
#
# C:\Users\Simon\Documents\EPFL\Master\Semestre1\Applied Data Analysis\SMM\Scripts\ArtistExtractor.py in getGenre(Artist, dictionnary, Year, debug)
#     216                 dictionnary = createDictionnary()
#     217
# --> 218         genres = getGenresFromWeb(Artist,dictionnary)
#     219         if(len(genres)>0):
#     220                 genres = sanitize(genres)
#
# C:\Users\Simon\Documents\EPFL\Master\Semestre1\Applied Data Analysis\SMM\Scripts\ArtistExtractor.py in getGenresFromWeb(Artist, dictionnary)
#     203                 genresSPOT= genresSPOT + content['artists']['items'][0]['genres']
#     204
# --> 205         genresRA = extractGenresFromRA(Artist,dictionnary)
#     206
#     207         genres = genres + genresSPOT +genresRA
#
# C:\Users\Simon\Documents\EPFL\Master\Semestre1\Applied Data Analysis\SMM\Scripts\ArtistExtractor.py in extractGenresFromRA(Artist, dic)
#     171         artist = Artist.lower().replace(" ","")
#     172         URL = "https://www.residentadvisor.net/dj/"+artist+"/biography"
# --> 173         content = requests.get(URL).text
#     174
#     175         soup = bs4.BeautifulSoup(content, "html5lib")
#
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      69
#      70     kwargs.setdefault('allow_redirects', True)
# ---> 71     return request('get', url, params=params, **kwargs)
#      72
#      73
#
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      55     # cases, and look like a memory leak in others.
#      56     with sessions.Session() as session:
# ---> 57         return session.request(method=method, url=url, **kwargs)
#      58
#      59
#
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     583
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#     587         # Total elapsed time of the request (approximately)
#
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     401                     decode_content=False,
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#     405
#
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     576                                                   timeout=timeout_obj,
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#     580             # If we're going to release the connection in ``finally:``, then
#
# C:\Users\Simon\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385                 httplib_response = conn.getresponse(buffering=True)
#     386             except TypeError:  # Python 2.6 and older
# --> 387                 httplib_response = conn.getresponse()
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     389             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\Users\Simon\Anaconda3\lib\http\client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# C:\Users\Simon\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\Simon\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\Simon\Anaconda3\lib\socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# C:\Users\Simon\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     927                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#     931             return socket.recv_into(self, buffer, nbytes, flags)
#
# C:\Users\Simon\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     789             raise ValueError("Read on closed or unwrapped SSL socket.")
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#     793             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# C:\Users\Simon\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     573         """
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#     577             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
AE.getGenre("Diams",debug=True)

# %% [markdown]
# ### Grouping by date

# %% [markdown]
# ## <font color='red'> TODO </font color>

# %% [markdown]
# We need to group by date in order to get an evolution by year.

# %%
ClubDataFrame.to_csv("ClubDataGeo/ClubDataFrameGenre.csv", encoding='utf-8')
saveDictionary(BUG_ARTISTS,"BUG_ARTISTS")
saveDictionary(ARTIST_GENRE,"ARTIST_GENRE")

# %%
print("finished!")
