# %%
import pandas as pd

pd.read_csv("sampleDF.csv",index_col=0,encoding="utf-8")
# Out:
#                           place       src  \
# 0                           NaN  EventsCh
# 100                         NaN  EventsCh
# 200                         NaN  EventsCh
# 300                         NaN  EventsCh
# 400                         NaN  EventsCh
# 500                         NaN  EventsCh
# 600                         NaN  EventsCh
# 700                         NaN  EventsCh
# 800                         NaN  EventsCh
# 900                         NaN  EventsCh
# 1000                        NaN  EventsCh
# 1100                        NaN  EventsCh
# 1200                        NaN  EventsCh
# 1300                        NaN  EventsCh
# 1400                        NaN  EventsCh
# 1500                        NaN  EventsCh
# 1600                        NaN  EventsCh
# 1700                        NaN  EventsCh
# 1800                        NaN  EventsCh
# 1900                        NaN  EventsCh
# 2000                        NaN  EventsCh
# ...
