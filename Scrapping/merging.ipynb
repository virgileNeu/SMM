# %%
import pandas as pd

# %%
RA_DF_NAME = 'ResidentAdvisor/ClubData/RA.csv'
EVENTS_DF_NAME = 'events.ch/EventsCh.csv'
RDF_DF_NAME = 'RouteDesFestivals/RDF.csv'

ra_df = pd.read_csv(RA_DF_NAME)
events_df = pd.read_csv(EVENTS_DF_NAME)
rdf_df = pd.read_csv(RDF_DF_NAME)

# Add source of origin of the events : [RA, EventsCh, RDF]
ra_df['src'] = 'RA'
events_df['src'] = 'EventsCh'
rdf_df['src'] = 'RDF'

# %%
len(events_df[events_df['date'] == '2015-02-06'])
# Out:
# 37

# %%
len(rdf_df[rdf_df['date'] == '2015-02-06'])
# Out:
# 1

# %%
print len(rdf_df) + len(events_df)
# Out:
# 38050

# %%
half_df = events_df.merge(rdf_df, how='outer')

# %%
del half_df['Unnamed: 0']
#del half_df['Unnamed: 0.1']

# %%
len(half_df[half_df['date'] == '2015-02-06'])
# Out:
# 38

# %%
# C'est bien 37 + 1

# %%
print len(half_df) + len(ra_df)
# Out:
# 38096

# %%
full_df = half_df.merge(ra_df, how='outer')

# %%
len(full_df)
# Out:
# 38096

# %%
del full_df['Unnamed: 0']

# %%
sample_df = full_df[full_df.index % 20 == 0]

# %%
len(sample_df)
# Out:
# 1905

# %%
sample_df
# Out:
#                    location                                        event  \
# 0                Pontresina                              Neujahrskonzert
# 20     Kulturfabrik-Kofmehl                                    Solothurn
# 40                    Basel                                         Pyro
# 60                   Zürich                             Organ-Meets-Jazz
# 80                    Aarau             Shakuhachi-Flöten-und-Elektronik
# 100                   Basel                    Orgelspiel-zum-Feierabend
# 120                   Basel                           David-Helbock-Trio
# 140                   Basel                           David-Helbock-Trio
# 160                  Zürich                                     Ron-Pope
# 180                  Zürich                                Enter-Shikari
# 200              Winterthur               New-Orleans-Soirée-Liquid-Land
# 220               Reussbühl                           Caprice-Frauenrock
# ...

# %%
sample_df.to_csv('sampleDF.csv')

# %%
sample_df['coordinates'] = None
# Out:
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sample_df
# Out:
#                    location                                        event  \
# 0                Pontresina                              Neujahrskonzert
# 20     Kulturfabrik-Kofmehl                                    Solothurn
# 40                    Basel                                         Pyro
# 60                   Zürich                             Organ-Meets-Jazz
# 80                    Aarau             Shakuhachi-Flöten-und-Elektronik
# 100                   Basel                    Orgelspiel-zum-Feierabend
# 120                   Basel                           David-Helbock-Trio
# 140                   Basel                           David-Helbock-Trio
# 160                  Zürich                                     Ron-Pope
# 180                  Zürich                                Enter-Shikari
# 200              Winterthur               New-Orleans-Soirée-Liquid-Land
# 220               Reussbühl                           Caprice-Frauenrock
# ...

# %%
import Pipepline

# %%
sample_df_with_coordinates = Pipepline.completeGeographicData(sample_df)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# Pipepline.py:108: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dataframe['canton'] = None

# %%
sample_df_with_coordinates_2 = sample_df_with_coordinates[0]

# %%
sample_df_with_coordinates_2
# Out:
#                           place       src                         address  \
# 0                           NaN  EventsCh                             NaN
# 20                          NaN  EventsCh                             NaN
# 40                          NaN  EventsCh                             NaN
# 60                          NaN  EventsCh                             NaN
# 80                          NaN  EventsCh                             NaN
# 100                         NaN  EventsCh                             NaN
# 120                         NaN  EventsCh                             NaN
# 140                         NaN  EventsCh                             NaN
# 160                         NaN  EventsCh                             NaN
# 180                         NaN  EventsCh                             NaN
# 200                         NaN  EventsCh                             NaN
# 220                         NaN  EventsCh                             NaN
# ...
