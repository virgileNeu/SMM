# %%
import pandas as pd

pd.read_csv("ClubData\RA.csv",index_col=0)
# Out:
#                           place  \
# 0                    La Tanière
# 1                    La Tanière
# 2                    La Tanière
# 3                    La Tanière
# 4                    La Tanière
# 5                    La Tanière
# 6                    La Tanière
# 7                    La Tanière
# 8                    La Tanière
# 9                    La Tanière
# 10                   La Tanière
# 11                   La Tanière
# 12                   Cyclo Café
# 13                   Cyclo Café
# 14                   Cyclo Café
# 15               Café Le Tunnel
# 16               Café Le Tunnel
# 17               Café Le Tunnel
# 18               Café Le Tunnel
# 19               Café Le Tunnel
# 20               Café Le Tunnel
# 21                   Fribowling
# 22                   Fribowling
# 23                   Fribowling
# 24                      MiniMax
# 25                       Tresor
# 26                       Tresor
# 27              Schlaflos Aarau
# ...
